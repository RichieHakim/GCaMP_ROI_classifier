# %%
import glob
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import torchvision
import torch

# %%
import numpy as np

# %%
class ModelTackOn(torch.nn.Module):
    def __init__(self, base_model, un_modified_model, pre_head_fc_sizes=[100], post_head_fc_sizes=[100], classifier_fc_sizes=None):
            super(ModelTackOn, self).__init__()
            self.base_model = base_model
            final_base_layer = list(un_modified_model.children())[-1]
            # final_base_layer = list(list(model.children())[-1].children())[-1]
            # print(final_base_layer)

            self.pre_head_fc_lst = []
            self.post_head_fc_lst = []
            self.classifier_fc_lst = []

            self.init_prehead(final_base_layer, pre_head_fc_sizes)
            self.init_posthead(pre_head_fc_sizes[-1], post_head_fc_sizes)
            if classifier_fc_sizes is not None:
                self.init_classifier(pre_head_fc_sizes[-1], classifier_fc_sizes)
    
    def init_prehead(self, prv_layer, pre_head_fc_sizes):
        for i, pre_head_fc in enumerate(pre_head_fc_sizes):
            if i == 0:
                in_features = prv_layer.in_features if hasattr(prv_layer,'in_features') else 1280
            else:
                in_features = pre_head_fc_sizes[i - 1]
            fc_layer = torch.nn.Linear(in_features=in_features, out_features=pre_head_fc)
            self.add_module(f'PreHead_{i}', fc_layer)
            self.pre_head_fc_lst.append(fc_layer)

#             if i < len(pre_head_fc_sizes) - 1:
            non_linearity = torch.nn.ReLU()
            self.add_module(f'PreHead_{i}_NonLinearity', non_linearity)
            self.pre_head_fc_lst.append(non_linearity)

    def init_posthead(self, prv_size, post_head_fc_sizes):
        for i, post_head_fc in enumerate(post_head_fc_sizes):
            if i == 0:
                in_features = prv_size
            else:
                in_features = post_head_fc_sizes[i - 1]
            fc_layer = torch.nn.Linear(in_features=in_features, out_features=post_head_fc)
            self.add_module(f'PostHead_{i}', fc_layer)
            self.post_head_fc_lst.append(fc_layer)

            if i < len(post_head_fc_sizes) - 1:
                non_linearity = torch.nn.ReLU()
                self.add_module(f'PostHead_{i}_NonLinearity', non_linearity)
                self.pre_head_fc_lst.append(non_linearity)
    
    def init_classifier(self, prv_size, classifier_fc_sizes):
            for i, classifier_fc in enumerate(classifier_fc_sizes):
                if i == 0:
                    in_features = prv_size
                else:
                    in_features = classifier_fc_sizes[i - 1]
            fc_layer = torch.nn.Linear(in_features=in_features, out_features=classifier_fc)
            self.add_module(f'Classifier_{i}', fc_layer)
            self.classifier_fc_lst.append(fc_layer)

    def reinit_classifier(self):
        for i_layer, layer in enumerate(self.classifier_fc_lst):
            layer.reset_parameters()
    
#     def forward(self, X):
#         interim = self.base_model(X)
#         interim = self.get_head(interim)
#         interim = self.get_latent(interim)
#         return interim

    def forward_classifier(self, X):
        interim = self.base_model(X)
        interim = self.get_head(interim)
        interim = self.classify(interim)
        return interim

    def forward_latent(self, X):
        interim = self.base_model(X)
        interim = self.get_head(interim)
        interim = self.get_latent(interim)
        return interim


    def get_head(self, base_out):
        # print('base_out', base_out.shape)
        head = base_out
        for pre_head_layer in self.pre_head_fc_lst:
          # print('pre_head_layer', pre_head_layer.in_features)
          head = pre_head_layer(head)
          # print('head', head.shape)
        return head

    def get_latent(self, head):
        latent = head
        for post_head_layer in self.post_head_fc_lst:
            latent = post_head_layer(latent)
        return latent

    def classify(self, head):
        logit = head
        for classifier_layer in self.classifier_fc_lst:
            logit = classifier_layer(logit)
        return logit

    def set_pre_head_grad(self, requires_grad=True):
        for layer in self.pre_head_fc_lst:
            for param in layer.parameters():
                param.requires_grad = requires_grad
                
    def set_post_head_grad(self, requires_grad=True):
        for layer in self.post_head_fc_lst:
            for param in layer.parameters():
                param.requires_grad = requires_grad

    def set_classifier_grad(self, requires_grad=True):
        for layer in self.classifier_fc_lst:
            for param in layer.parameters():
                param.requires_grad = requires_grad

    def prep_contrast(self):
        self.set_pre_head_grad(requires_grad=True)
        self.set_post_head_grad(requires_grad=True)
        self.set_classifier_grad(requires_grad=False)

    def prep_classifier(self):
        self.set_pre_head_grad(requires_grad=False)
        self.set_post_head_grad(requires_grad=False)
        self.set_classifier_grad(requires_grad=True)

# %%
import torchvision.models

# base_model_frozen = torchvision.models.resnet101(pretrained=True)
# base_model_frozen = torchvision.models.resnet18(pretrained=True)
# base_model_frozen = torchvision.models.wide_resnet50_2(pretrained=True)
# base_model_frozen = torchvision.models.resnet50(pretrained=True)

base_model_frozen = torchvision.models.efficientnet_b0(pretrained=True)

# %%
# unfreeze particular blocks in ResNet model
base_model_frozen = torchvision.models.efficientnet_b0(pretrained=True)
model_chopped = torch.nn.Sequential(*(list(base_model_frozen.children())[:-1] + [torch.nn.Flatten()]))
model = ModelTackOn(model_chopped, base_model_frozen, pre_head_fc_sizes=[1024, 512], post_head_fc_sizes=[64], classifier_fc_sizes=[4])
model.train();

base_dir = '/Users/josh/Documents'
model_file_name = 'ResNet18_simCLR_model_202112078_EOD_transfmod=efficient2'
model.load_state_dict(torch.load(f'{base_dir}/github_repos/GCaMP_ROI_classifier/new_stuff/models/{model_file_name}.pth', map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
# unfreeze particular blocks in ResNet model
base_model_frozen = torchvision.models.efficientnet_b0(pretrained=True)
model_chopped = torch.nn.Sequential(*(list(base_model_frozen.children())[:-1] + [torch.nn.Flatten()]))
model2 = ModelTackOn(model_chopped, base_model_frozen, pre_head_fc_sizes=[1024, 512], post_head_fc_sizes=[64], classifier_fc_sizes=[4])
model2.train();

base_dir = '/Users/josh/Documents'
model_file_name = 'ResNet18_simCLR_model_202112078_EOD_transfmod=efficient'
model2.load_state_dict(torch.load(f'{base_dir}/github_repos/GCaMP_ROI_classifier/new_stuff/models/{model_file_name}.pth', map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
# unfreeze particular blocks in ResNet model
base_model_frozen = torchvision.models.efficientnet_b0(pretrained=True)
model_chopped = torch.nn.Sequential(*(list(base_model_frozen.children())[:-1] + [torch.nn.Flatten()]))
model3 = ModelTackOn(model_chopped, base_model_frozen, pre_head_fc_sizes=[1024, 512], post_head_fc_sizes=[64], classifier_fc_sizes=[4])
model3.train();

base_dir = '/Users/josh/Documents'
model_file_name = 'ResNet18_simCLR_model_202112078_EOD_transfmod=efficient2-only7unfrozen'
model3.load_state_dict(torch.load(f'{base_dir}/github_repos/GCaMP_ROI_classifier/new_stuff/models/{model_file_name}.pth', map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
# unfreeze particular blocks in ResNet model
base_model_frozen = torchvision.models.efficientnet_b0(pretrained=True)
model_chopped = torch.nn.Sequential(*(list(base_model_frozen.children())[:-1] + [torch.nn.Flatten()]))
model4 = ModelTackOn(model_chopped, base_model_frozen, pre_head_fc_sizes=[1024, 512], post_head_fc_sizes=[64], classifier_fc_sizes=[4])
model4.train();

# %%
model_params = list(model.named_parameters())
model2_params = list(model2.named_parameters())
model3_params = list(model3.named_parameters())
model4_params = list(model4.named_parameters())

for i, (name, param) in enumerate(model_params):
    param_1 = model_params[i][1]
    param_2 = model2_params[i][1]
    param_3 = model3_params[i][1]
    param_4 = model4_params[i][1]
    
    print(i,'1=4',model_params[i][0],np.all(param_1.detach().numpy() == param_4.detach().numpy()))
    print(i,'2=4',model2_params[i][0],np.all(param_2.detach().numpy() == param_4.detach().numpy()))  
    print(i,'3=4',model3_params[i][0],np.all(param_3.detach().numpy() == param_4.detach().numpy()))
# Out:
# 0 1=4 base_model.0.0.0.weight True
# 0 2=4 base_model.0.0.0.weight True
# 0 3=4 base_model.0.0.0.weight True
# 1 1=4 base_model.0.0.1.weight True
# 1 2=4 base_model.0.0.1.weight True
# 1 3=4 base_model.0.0.1.weight True
# 2 1=4 base_model.0.0.1.bias True
# 2 2=4 base_model.0.0.1.bias True
# 2 3=4 base_model.0.0.1.bias True
# 3 1=4 base_model.0.1.0.block.0.0.weight True
# 3 2=4 base_model.0.1.0.block.0.0.weight True
# 3 3=4 base_model.0.1.0.block.0.0.weight True
# 4 1=4 base_model.0.1.0.block.0.1.weight True
# 4 2=4 base_model.0.1.0.block.0.1.weight True
# 4 3=4 base_model.0.1.0.block.0.1.weight True
# 5 1=4 base_model.0.1.0.block.0.1.bias True
# 5 2=4 base_model.0.1.0.block.0.1.bias True
# 5 3=4 base_model.0.1.0.block.0.1.bias True
# 6 1=4 base_model.0.1.0.block.1.fc1.weight True
# 6 2=4 base_model.0.1.0.block.1.fc1.weight True
# 6 3=4 base_model.0.1.0.block.1.fc1.weight True
# 7 1=4 base_model.0.1.0.block.1.fc1.bias True
# 7 2=4 base_model.0.1.0.block.1.fc1.bias True
# 7 3=4 base_model.0.1.0.block.1.fc1.bias True
# 8 1=4 base_model.0.1.0.block.1.fc2.weight True
# 8 2=4 base_model.0.1.0.block.1.fc2.weight True
# 8 3=4 base_model.0.1.0.block.1.fc2.weight True
# 9 1=4 base_model.0.1.0.block.1.fc2.bias True
# 9 2=4 base_model.0.1.0.block.1.fc2.bias True
# 9 3=4 base_model.0.1.0.block.1.fc2.bias True
# 10 1=4 base_model.0.1.0.block.2.0.weight True
# 10 2=4 base_model.0.1.0.block.2.0.weight True
# 10 3=4 base_model.0.1.0.block.2.0.weight True
# 11 1=4 base_model.0.1.0.block.2.1.weight True
# 11 2=4 base_model.0.1.0.block.2.1.weight True
# 11 3=4 base_model.0.1.0.block.2.1.weight True
# 12 1=4 base_model.0.1.0.block.2.1.bias True
# 12 2=4 base_model.0.1.0.block.2.1.bias True
# 12 3=4 base_model.0.1.0.block.2.1.bias True
# 13 1=4 base_model.0.2.0.block.0.0.weight True
# 13 2=4 base_model.0.2.0.block.0.0.weight True
# 13 3=4 base_model.0.2.0.block.0.0.weight True
# 14 1=4 base_model.0.2.0.block.0.1.weight True
# 14 2=4 base_model.0.2.0.block.0.1.weight True
# 14 3=4 base_model.0.2.0.block.0.1.weight True
# 15 1=4 base_model.0.2.0.block.0.1.bias True
# 15 2=4 base_model.0.2.0.block.0.1.bias True
# 15 3=4 base_model.0.2.0.block.0.1.bias True
# 16 1=4 base_model.0.2.0.block.1.0.weight True
# 16 2=4 base_model.0.2.0.block.1.0.weight True
# 16 3=4 base_model.0.2.0.block.1.0.weight True
# 17 1=4 base_model.0.2.0.block.1.1.weight True
# 17 2=4 base_model.0.2.0.block.1.1.weight True
# 17 3=4 base_model.0.2.0.block.1.1.weight True
# 18 1=4 base_model.0.2.0.block.1.1.bias True
# 18 2=4 base_model.0.2.0.block.1.1.bias True
# 18 3=4 base_model.0.2.0.block.1.1.bias True
# 19 1=4 base_model.0.2.0.block.2.fc1.weight True
# 19 2=4 base_model.0.2.0.block.2.fc1.weight True
# 19 3=4 base_model.0.2.0.block.2.fc1.weight True
# 20 1=4 base_model.0.2.0.block.2.fc1.bias True
# 20 2=4 base_model.0.2.0.block.2.fc1.bias True
# 20 3=4 base_model.0.2.0.block.2.fc1.bias True
# 21 1=4 base_model.0.2.0.block.2.fc2.weight True
# 21 2=4 base_model.0.2.0.block.2.fc2.weight True
# 21 3=4 base_model.0.2.0.block.2.fc2.weight True
# 22 1=4 base_model.0.2.0.block.2.fc2.bias True
# 22 2=4 base_model.0.2.0.block.2.fc2.bias True
# 22 3=4 base_model.0.2.0.block.2.fc2.bias True
# 23 1=4 base_model.0.2.0.block.3.0.weight True
# 23 2=4 base_model.0.2.0.block.3.0.weight True
# 23 3=4 base_model.0.2.0.block.3.0.weight True
# 24 1=4 base_model.0.2.0.block.3.1.weight True
# 24 2=4 base_model.0.2.0.block.3.1.weight True
# 24 3=4 base_model.0.2.0.block.3.1.weight True
# 25 1=4 base_model.0.2.0.block.3.1.bias True
# 25 2=4 base_model.0.2.0.block.3.1.bias True
# 25 3=4 base_model.0.2.0.block.3.1.bias True
# 26 1=4 base_model.0.2.1.block.0.0.weight True
# 26 2=4 base_model.0.2.1.block.0.0.weight True
# 26 3=4 base_model.0.2.1.block.0.0.weight True
# 27 1=4 base_model.0.2.1.block.0.1.weight True
# 27 2=4 base_model.0.2.1.block.0.1.weight True
# 27 3=4 base_model.0.2.1.block.0.1.weight True
# 28 1=4 base_model.0.2.1.block.0.1.bias True
# 28 2=4 base_model.0.2.1.block.0.1.bias True
# 28 3=4 base_model.0.2.1.block.0.1.bias True
# 29 1=4 base_model.0.2.1.block.1.0.weight True
# 29 2=4 base_model.0.2.1.block.1.0.weight True
# 29 3=4 base_model.0.2.1.block.1.0.weight True
# 30 1=4 base_model.0.2.1.block.1.1.weight True
# 30 2=4 base_model.0.2.1.block.1.1.weight True
# 30 3=4 base_model.0.2.1.block.1.1.weight True
# 31 1=4 base_model.0.2.1.block.1.1.bias True
# 31 2=4 base_model.0.2.1.block.1.1.bias True
# 31 3=4 base_model.0.2.1.block.1.1.bias True
# 32 1=4 base_model.0.2.1.block.2.fc1.weight True
# 32 2=4 base_model.0.2.1.block.2.fc1.weight True
# 32 3=4 base_model.0.2.1.block.2.fc1.weight True
# 33 1=4 base_model.0.2.1.block.2.fc1.bias True
# 33 2=4 base_model.0.2.1.block.2.fc1.bias True
# 33 3=4 base_model.0.2.1.block.2.fc1.bias True
# 34 1=4 base_model.0.2.1.block.2.fc2.weight True
# 34 2=4 base_model.0.2.1.block.2.fc2.weight True
# 34 3=4 base_model.0.2.1.block.2.fc2.weight True
# 35 1=4 base_model.0.2.1.block.2.fc2.bias True
# 35 2=4 base_model.0.2.1.block.2.fc2.bias True
# 35 3=4 base_model.0.2.1.block.2.fc2.bias True
# 36 1=4 base_model.0.2.1.block.3.0.weight True
# 36 2=4 base_model.0.2.1.block.3.0.weight True
# 36 3=4 base_model.0.2.1.block.3.0.weight True
# 37 1=4 base_model.0.2.1.block.3.1.weight True
# 37 2=4 base_model.0.2.1.block.3.1.weight True
# 37 3=4 base_model.0.2.1.block.3.1.weight True
# 38 1=4 base_model.0.2.1.block.3.1.bias True
# 38 2=4 base_model.0.2.1.block.3.1.bias True
# 38 3=4 base_model.0.2.1.block.3.1.bias True
# 39 1=4 base_model.0.3.0.block.0.0.weight True
# 39 2=4 base_model.0.3.0.block.0.0.weight True
# 39 3=4 base_model.0.3.0.block.0.0.weight True
# 40 1=4 base_model.0.3.0.block.0.1.weight True
# 40 2=4 base_model.0.3.0.block.0.1.weight True
# 40 3=4 base_model.0.3.0.block.0.1.weight True
# 41 1=4 base_model.0.3.0.block.0.1.bias True
# 41 2=4 base_model.0.3.0.block.0.1.bias True
# 41 3=4 base_model.0.3.0.block.0.1.bias True
# 42 1=4 base_model.0.3.0.block.1.0.weight True
# 42 2=4 base_model.0.3.0.block.1.0.weight True
# 42 3=4 base_model.0.3.0.block.1.0.weight True
# 43 1=4 base_model.0.3.0.block.1.1.weight True
# 43 2=4 base_model.0.3.0.block.1.1.weight True
# 43 3=4 base_model.0.3.0.block.1.1.weight True
# 44 1=4 base_model.0.3.0.block.1.1.bias True
# 44 2=4 base_model.0.3.0.block.1.1.bias True
# 44 3=4 base_model.0.3.0.block.1.1.bias True
# 45 1=4 base_model.0.3.0.block.2.fc1.weight True
# 45 2=4 base_model.0.3.0.block.2.fc1.weight True
# 45 3=4 base_model.0.3.0.block.2.fc1.weight True
# 46 1=4 base_model.0.3.0.block.2.fc1.bias True
# 46 2=4 base_model.0.3.0.block.2.fc1.bias True
# 46 3=4 base_model.0.3.0.block.2.fc1.bias True
# 47 1=4 base_model.0.3.0.block.2.fc2.weight True
# 47 2=4 base_model.0.3.0.block.2.fc2.weight True
# 47 3=4 base_model.0.3.0.block.2.fc2.weight True
# 48 1=4 base_model.0.3.0.block.2.fc2.bias True
# 48 2=4 base_model.0.3.0.block.2.fc2.bias True
# 48 3=4 base_model.0.3.0.block.2.fc2.bias True
# 49 1=4 base_model.0.3.0.block.3.0.weight True
# 49 2=4 base_model.0.3.0.block.3.0.weight True
# 49 3=4 base_model.0.3.0.block.3.0.weight True
# 50 1=4 base_model.0.3.0.block.3.1.weight True
# 50 2=4 base_model.0.3.0.block.3.1.weight True
# 50 3=4 base_model.0.3.0.block.3.1.weight True
# 51 1=4 base_model.0.3.0.block.3.1.bias True
# 51 2=4 base_model.0.3.0.block.3.1.bias True
# 51 3=4 base_model.0.3.0.block.3.1.bias True
# 52 1=4 base_model.0.3.1.block.0.0.weight True
# 52 2=4 base_model.0.3.1.block.0.0.weight True
# 52 3=4 base_model.0.3.1.block.0.0.weight True
# 53 1=4 base_model.0.3.1.block.0.1.weight True
# 53 2=4 base_model.0.3.1.block.0.1.weight True
# 53 3=4 base_model.0.3.1.block.0.1.weight True
# 54 1=4 base_model.0.3.1.block.0.1.bias True
# 54 2=4 base_model.0.3.1.block.0.1.bias True
# 54 3=4 base_model.0.3.1.block.0.1.bias True
# 55 1=4 base_model.0.3.1.block.1.0.weight True
# 55 2=4 base_model.0.3.1.block.1.0.weight True
# 55 3=4 base_model.0.3.1.block.1.0.weight True
# 56 1=4 base_model.0.3.1.block.1.1.weight True
# 56 2=4 base_model.0.3.1.block.1.1.weight True
# 56 3=4 base_model.0.3.1.block.1.1.weight True
# 57 1=4 base_model.0.3.1.block.1.1.bias True
# 57 2=4 base_model.0.3.1.block.1.1.bias True
# 57 3=4 base_model.0.3.1.block.1.1.bias True
# 58 1=4 base_model.0.3.1.block.2.fc1.weight True
# 58 2=4 base_model.0.3.1.block.2.fc1.weight True
# 58 3=4 base_model.0.3.1.block.2.fc1.weight True
# 59 1=4 base_model.0.3.1.block.2.fc1.bias True
# 59 2=4 base_model.0.3.1.block.2.fc1.bias True
# 59 3=4 base_model.0.3.1.block.2.fc1.bias True
# 60 1=4 base_model.0.3.1.block.2.fc2.weight True
# 60 2=4 base_model.0.3.1.block.2.fc2.weight True
# 60 3=4 base_model.0.3.1.block.2.fc2.weight True
# 61 1=4 base_model.0.3.1.block.2.fc2.bias True
# 61 2=4 base_model.0.3.1.block.2.fc2.bias True
# 61 3=4 base_model.0.3.1.block.2.fc2.bias True
# 62 1=4 base_model.0.3.1.block.3.0.weight True
# 62 2=4 base_model.0.3.1.block.3.0.weight True
# 62 3=4 base_model.0.3.1.block.3.0.weight True
# 63 1=4 base_model.0.3.1.block.3.1.weight True
# 63 2=4 base_model.0.3.1.block.3.1.weight True
# 63 3=4 base_model.0.3.1.block.3.1.weight True
# 64 1=4 base_model.0.3.1.block.3.1.bias True
# 64 2=4 base_model.0.3.1.block.3.1.bias True
# 64 3=4 base_model.0.3.1.block.3.1.bias True
# 65 1=4 base_model.0.4.0.block.0.0.weight True
# 65 2=4 base_model.0.4.0.block.0.0.weight True
# 65 3=4 base_model.0.4.0.block.0.0.weight True
# 66 1=4 base_model.0.4.0.block.0.1.weight True
# 66 2=4 base_model.0.4.0.block.0.1.weight True
# 66 3=4 base_model.0.4.0.block.0.1.weight True
# 67 1=4 base_model.0.4.0.block.0.1.bias True
# 67 2=4 base_model.0.4.0.block.0.1.bias True
# 67 3=4 base_model.0.4.0.block.0.1.bias True
# 68 1=4 base_model.0.4.0.block.1.0.weight True
# 68 2=4 base_model.0.4.0.block.1.0.weight True
# 68 3=4 base_model.0.4.0.block.1.0.weight True
# 69 1=4 base_model.0.4.0.block.1.1.weight True
# 69 2=4 base_model.0.4.0.block.1.1.weight True
# 69 3=4 base_model.0.4.0.block.1.1.weight True
# 70 1=4 base_model.0.4.0.block.1.1.bias True
# 70 2=4 base_model.0.4.0.block.1.1.bias True
# 70 3=4 base_model.0.4.0.block.1.1.bias True
# 71 1=4 base_model.0.4.0.block.2.fc1.weight True
# 71 2=4 base_model.0.4.0.block.2.fc1.weight True
# 71 3=4 base_model.0.4.0.block.2.fc1.weight True
# 72 1=4 base_model.0.4.0.block.2.fc1.bias True
# 72 2=4 base_model.0.4.0.block.2.fc1.bias True
# 72 3=4 base_model.0.4.0.block.2.fc1.bias True
# 73 1=4 base_model.0.4.0.block.2.fc2.weight True
# 73 2=4 base_model.0.4.0.block.2.fc2.weight True
# 73 3=4 base_model.0.4.0.block.2.fc2.weight True
# 74 1=4 base_model.0.4.0.block.2.fc2.bias True
# 74 2=4 base_model.0.4.0.block.2.fc2.bias True
# 74 3=4 base_model.0.4.0.block.2.fc2.bias True
# 75 1=4 base_model.0.4.0.block.3.0.weight True
# 75 2=4 base_model.0.4.0.block.3.0.weight True
# 75 3=4 base_model.0.4.0.block.3.0.weight True
# 76 1=4 base_model.0.4.0.block.3.1.weight True
# 76 2=4 base_model.0.4.0.block.3.1.weight True
# 76 3=4 base_model.0.4.0.block.3.1.weight True
# 77 1=4 base_model.0.4.0.block.3.1.bias True
# 77 2=4 base_model.0.4.0.block.3.1.bias True
# 77 3=4 base_model.0.4.0.block.3.1.bias True
# 78 1=4 base_model.0.4.1.block.0.0.weight True
# 78 2=4 base_model.0.4.1.block.0.0.weight True
# 78 3=4 base_model.0.4.1.block.0.0.weight True
# 79 1=4 base_model.0.4.1.block.0.1.weight True
# 79 2=4 base_model.0.4.1.block.0.1.weight True
# 79 3=4 base_model.0.4.1.block.0.1.weight True
# 80 1=4 base_model.0.4.1.block.0.1.bias True
# 80 2=4 base_model.0.4.1.block.0.1.bias True
# 80 3=4 base_model.0.4.1.block.0.1.bias True
# 81 1=4 base_model.0.4.1.block.1.0.weight True
# 81 2=4 base_model.0.4.1.block.1.0.weight True
# 81 3=4 base_model.0.4.1.block.1.0.weight True
# 82 1=4 base_model.0.4.1.block.1.1.weight True
# 82 2=4 base_model.0.4.1.block.1.1.weight True
# 82 3=4 base_model.0.4.1.block.1.1.weight True
# 83 1=4 base_model.0.4.1.block.1.1.bias True
# 83 2=4 base_model.0.4.1.block.1.1.bias True
# 83 3=4 base_model.0.4.1.block.1.1.bias True
# 84 1=4 base_model.0.4.1.block.2.fc1.weight True
# 84 2=4 base_model.0.4.1.block.2.fc1.weight True
# 84 3=4 base_model.0.4.1.block.2.fc1.weight True
# 85 1=4 base_model.0.4.1.block.2.fc1.bias True
# 85 2=4 base_model.0.4.1.block.2.fc1.bias True
# 85 3=4 base_model.0.4.1.block.2.fc1.bias True
# 86 1=4 base_model.0.4.1.block.2.fc2.weight True
# 86 2=4 base_model.0.4.1.block.2.fc2.weight True
# 86 3=4 base_model.0.4.1.block.2.fc2.weight True
# 87 1=4 base_model.0.4.1.block.2.fc2.bias True
# 87 2=4 base_model.0.4.1.block.2.fc2.bias True
# 87 3=4 base_model.0.4.1.block.2.fc2.bias True
# 88 1=4 base_model.0.4.1.block.3.0.weight True
# 88 2=4 base_model.0.4.1.block.3.0.weight True
# 88 3=4 base_model.0.4.1.block.3.0.weight True
# 89 1=4 base_model.0.4.1.block.3.1.weight True
# 89 2=4 base_model.0.4.1.block.3.1.weight True
# 89 3=4 base_model.0.4.1.block.3.1.weight True
# 90 1=4 base_model.0.4.1.block.3.1.bias True
# 90 2=4 base_model.0.4.1.block.3.1.bias True
# 90 3=4 base_model.0.4.1.block.3.1.bias True
# 91 1=4 base_model.0.4.2.block.0.0.weight True
# 91 2=4 base_model.0.4.2.block.0.0.weight True
# 91 3=4 base_model.0.4.2.block.0.0.weight True
# 92 1=4 base_model.0.4.2.block.0.1.weight True
# 92 2=4 base_model.0.4.2.block.0.1.weight True
# 92 3=4 base_model.0.4.2.block.0.1.weight True
# 93 1=4 base_model.0.4.2.block.0.1.bias True
# 93 2=4 base_model.0.4.2.block.0.1.bias True
# 93 3=4 base_model.0.4.2.block.0.1.bias True
# 94 1=4 base_model.0.4.2.block.1.0.weight True
# 94 2=4 base_model.0.4.2.block.1.0.weight True
# 94 3=4 base_model.0.4.2.block.1.0.weight True
# 95 1=4 base_model.0.4.2.block.1.1.weight True
# 95 2=4 base_model.0.4.2.block.1.1.weight True
# 95 3=4 base_model.0.4.2.block.1.1.weight True
# 96 1=4 base_model.0.4.2.block.1.1.bias True
# 96 2=4 base_model.0.4.2.block.1.1.bias True
# 96 3=4 base_model.0.4.2.block.1.1.bias True
# 97 1=4 base_model.0.4.2.block.2.fc1.weight True
# 97 2=4 base_model.0.4.2.block.2.fc1.weight True
# 97 3=4 base_model.0.4.2.block.2.fc1.weight True
# 98 1=4 base_model.0.4.2.block.2.fc1.bias True
# 98 2=4 base_model.0.4.2.block.2.fc1.bias True
# 98 3=4 base_model.0.4.2.block.2.fc1.bias True
# 99 1=4 base_model.0.4.2.block.2.fc2.weight True
# 99 2=4 base_model.0.4.2.block.2.fc2.weight True
# 99 3=4 base_model.0.4.2.block.2.fc2.weight True
# 100 1=4 base_model.0.4.2.block.2.fc2.bias True
# 100 2=4 base_model.0.4.2.block.2.fc2.bias True
# 100 3=4 base_model.0.4.2.block.2.fc2.bias True
# 101 1=4 base_model.0.4.2.block.3.0.weight True
# 101 2=4 base_model.0.4.2.block.3.0.weight True
# 101 3=4 base_model.0.4.2.block.3.0.weight True
# 102 1=4 base_model.0.4.2.block.3.1.weight True
# 102 2=4 base_model.0.4.2.block.3.1.weight True
# 102 3=4 base_model.0.4.2.block.3.1.weight True
# 103 1=4 base_model.0.4.2.block.3.1.bias True
# 103 2=4 base_model.0.4.2.block.3.1.bias True
# 103 3=4 base_model.0.4.2.block.3.1.bias True
# 104 1=4 base_model.0.5.0.block.0.0.weight False
# 104 2=4 base_model.0.5.0.block.0.0.weight False
# 104 3=4 base_model.0.5.0.block.0.0.weight True
# 105 1=4 base_model.0.5.0.block.0.1.weight False
# 105 2=4 base_model.0.5.0.block.0.1.weight False
# 105 3=4 base_model.0.5.0.block.0.1.weight True
# 106 1=4 base_model.0.5.0.block.0.1.bias False
# 106 2=4 base_model.0.5.0.block.0.1.bias False
# 106 3=4 base_model.0.5.0.block.0.1.bias True
# 107 1=4 base_model.0.5.0.block.1.0.weight False
# 107 2=4 base_model.0.5.0.block.1.0.weight False
# 107 3=4 base_model.0.5.0.block.1.0.weight True
# 108 1=4 base_model.0.5.0.block.1.1.weight False
# 108 2=4 base_model.0.5.0.block.1.1.weight False
# 108 3=4 base_model.0.5.0.block.1.1.weight True
# 109 1=4 base_model.0.5.0.block.1.1.bias False
# 109 2=4 base_model.0.5.0.block.1.1.bias False
# 109 3=4 base_model.0.5.0.block.1.1.bias True
# 110 1=4 base_model.0.5.0.block.2.fc1.weight False
# 110 2=4 base_model.0.5.0.block.2.fc1.weight False
# 110 3=4 base_model.0.5.0.block.2.fc1.weight True
# 111 1=4 base_model.0.5.0.block.2.fc1.bias False
# 111 2=4 base_model.0.5.0.block.2.fc1.bias False
# 111 3=4 base_model.0.5.0.block.2.fc1.bias True
# 112 1=4 base_model.0.5.0.block.2.fc2.weight False
# 112 2=4 base_model.0.5.0.block.2.fc2.weight False
# 112 3=4 base_model.0.5.0.block.2.fc2.weight True
# 113 1=4 base_model.0.5.0.block.2.fc2.bias False
# 113 2=4 base_model.0.5.0.block.2.fc2.bias False
# 113 3=4 base_model.0.5.0.block.2.fc2.bias True
# 114 1=4 base_model.0.5.0.block.3.0.weight False
# 114 2=4 base_model.0.5.0.block.3.0.weight False
# 114 3=4 base_model.0.5.0.block.3.0.weight True
# 115 1=4 base_model.0.5.0.block.3.1.weight False
# 115 2=4 base_model.0.5.0.block.3.1.weight False
# 115 3=4 base_model.0.5.0.block.3.1.weight True
# 116 1=4 base_model.0.5.0.block.3.1.bias False
# 116 2=4 base_model.0.5.0.block.3.1.bias False
# 116 3=4 base_model.0.5.0.block.3.1.bias True
# 117 1=4 base_model.0.5.1.block.0.0.weight False
# 117 2=4 base_model.0.5.1.block.0.0.weight False
# 117 3=4 base_model.0.5.1.block.0.0.weight True
# 118 1=4 base_model.0.5.1.block.0.1.weight False
# 118 2=4 base_model.0.5.1.block.0.1.weight False
# 118 3=4 base_model.0.5.1.block.0.1.weight True
# 119 1=4 base_model.0.5.1.block.0.1.bias False
# 119 2=4 base_model.0.5.1.block.0.1.bias False
# 119 3=4 base_model.0.5.1.block.0.1.bias True
# 120 1=4 base_model.0.5.1.block.1.0.weight False
# 120 2=4 base_model.0.5.1.block.1.0.weight False
# 120 3=4 base_model.0.5.1.block.1.0.weight True
# 121 1=4 base_model.0.5.1.block.1.1.weight False
# 121 2=4 base_model.0.5.1.block.1.1.weight False
# 121 3=4 base_model.0.5.1.block.1.1.weight True
# 122 1=4 base_model.0.5.1.block.1.1.bias False
# 122 2=4 base_model.0.5.1.block.1.1.bias False
# 122 3=4 base_model.0.5.1.block.1.1.bias True
# 123 1=4 base_model.0.5.1.block.2.fc1.weight False
# 123 2=4 base_model.0.5.1.block.2.fc1.weight False
# 123 3=4 base_model.0.5.1.block.2.fc1.weight True
# 124 1=4 base_model.0.5.1.block.2.fc1.bias False
# 124 2=4 base_model.0.5.1.block.2.fc1.bias False
# 124 3=4 base_model.0.5.1.block.2.fc1.bias True
# 125 1=4 base_model.0.5.1.block.2.fc2.weight False
# 125 2=4 base_model.0.5.1.block.2.fc2.weight False
# 125 3=4 base_model.0.5.1.block.2.fc2.weight True
# 126 1=4 base_model.0.5.1.block.2.fc2.bias False
# 126 2=4 base_model.0.5.1.block.2.fc2.bias False
# 126 3=4 base_model.0.5.1.block.2.fc2.bias True
# 127 1=4 base_model.0.5.1.block.3.0.weight False
# 127 2=4 base_model.0.5.1.block.3.0.weight False
# 127 3=4 base_model.0.5.1.block.3.0.weight True
# 128 1=4 base_model.0.5.1.block.3.1.weight False
# 128 2=4 base_model.0.5.1.block.3.1.weight False
# 128 3=4 base_model.0.5.1.block.3.1.weight True
# 129 1=4 base_model.0.5.1.block.3.1.bias False
# 129 2=4 base_model.0.5.1.block.3.1.bias False
# 129 3=4 base_model.0.5.1.block.3.1.bias True
# 130 1=4 base_model.0.5.2.block.0.0.weight False
# 130 2=4 base_model.0.5.2.block.0.0.weight False
# 130 3=4 base_model.0.5.2.block.0.0.weight True
# 131 1=4 base_model.0.5.2.block.0.1.weight False
# 131 2=4 base_model.0.5.2.block.0.1.weight False
# 131 3=4 base_model.0.5.2.block.0.1.weight True
# 132 1=4 base_model.0.5.2.block.0.1.bias False
# 132 2=4 base_model.0.5.2.block.0.1.bias False
# 132 3=4 base_model.0.5.2.block.0.1.bias True
# 133 1=4 base_model.0.5.2.block.1.0.weight False
# 133 2=4 base_model.0.5.2.block.1.0.weight False
# 133 3=4 base_model.0.5.2.block.1.0.weight True
# 134 1=4 base_model.0.5.2.block.1.1.weight False
# 134 2=4 base_model.0.5.2.block.1.1.weight False
# 134 3=4 base_model.0.5.2.block.1.1.weight True
# 135 1=4 base_model.0.5.2.block.1.1.bias False
# 135 2=4 base_model.0.5.2.block.1.1.bias False
# 135 3=4 base_model.0.5.2.block.1.1.bias True
# 136 1=4 base_model.0.5.2.block.2.fc1.weight False
# 136 2=4 base_model.0.5.2.block.2.fc1.weight False
# 136 3=4 base_model.0.5.2.block.2.fc1.weight True
# 137 1=4 base_model.0.5.2.block.2.fc1.bias False
# 137 2=4 base_model.0.5.2.block.2.fc1.bias False
# 137 3=4 base_model.0.5.2.block.2.fc1.bias True
# 138 1=4 base_model.0.5.2.block.2.fc2.weight False
# 138 2=4 base_model.0.5.2.block.2.fc2.weight False
# 138 3=4 base_model.0.5.2.block.2.fc2.weight True
# 139 1=4 base_model.0.5.2.block.2.fc2.bias False
# 139 2=4 base_model.0.5.2.block.2.fc2.bias False
# 139 3=4 base_model.0.5.2.block.2.fc2.bias True
# 140 1=4 base_model.0.5.2.block.3.0.weight False
# 140 2=4 base_model.0.5.2.block.3.0.weight False
# 140 3=4 base_model.0.5.2.block.3.0.weight True
# 141 1=4 base_model.0.5.2.block.3.1.weight False
# 141 2=4 base_model.0.5.2.block.3.1.weight False
# 141 3=4 base_model.0.5.2.block.3.1.weight True
# 142 1=4 base_model.0.5.2.block.3.1.bias False
# 142 2=4 base_model.0.5.2.block.3.1.bias False
# 142 3=4 base_model.0.5.2.block.3.1.bias True
# 143 1=4 base_model.0.6.0.block.0.0.weight False
# 143 2=4 base_model.0.6.0.block.0.0.weight False
# 143 3=4 base_model.0.6.0.block.0.0.weight True
# 144 1=4 base_model.0.6.0.block.0.1.weight False
# 144 2=4 base_model.0.6.0.block.0.1.weight False
# 144 3=4 base_model.0.6.0.block.0.1.weight True
# 145 1=4 base_model.0.6.0.block.0.1.bias False
# 145 2=4 base_model.0.6.0.block.0.1.bias False
# 145 3=4 base_model.0.6.0.block.0.1.bias True
# 146 1=4 base_model.0.6.0.block.1.0.weight False
# 146 2=4 base_model.0.6.0.block.1.0.weight False
# 146 3=4 base_model.0.6.0.block.1.0.weight True
# 147 1=4 base_model.0.6.0.block.1.1.weight False
# 147 2=4 base_model.0.6.0.block.1.1.weight False
# 147 3=4 base_model.0.6.0.block.1.1.weight True
# 148 1=4 base_model.0.6.0.block.1.1.bias False
# 148 2=4 base_model.0.6.0.block.1.1.bias False
# 148 3=4 base_model.0.6.0.block.1.1.bias True
# 149 1=4 base_model.0.6.0.block.2.fc1.weight False
# 149 2=4 base_model.0.6.0.block.2.fc1.weight False
# 149 3=4 base_model.0.6.0.block.2.fc1.weight True
# 150 1=4 base_model.0.6.0.block.2.fc1.bias False
# 150 2=4 base_model.0.6.0.block.2.fc1.bias False
# 150 3=4 base_model.0.6.0.block.2.fc1.bias True
# 151 1=4 base_model.0.6.0.block.2.fc2.weight False
# 151 2=4 base_model.0.6.0.block.2.fc2.weight False
# 151 3=4 base_model.0.6.0.block.2.fc2.weight True
# 152 1=4 base_model.0.6.0.block.2.fc2.bias False
# 152 2=4 base_model.0.6.0.block.2.fc2.bias False
# 152 3=4 base_model.0.6.0.block.2.fc2.bias True
# 153 1=4 base_model.0.6.0.block.3.0.weight False
# 153 2=4 base_model.0.6.0.block.3.0.weight False
# 153 3=4 base_model.0.6.0.block.3.0.weight True
# 154 1=4 base_model.0.6.0.block.3.1.weight False
# 154 2=4 base_model.0.6.0.block.3.1.weight False
# 154 3=4 base_model.0.6.0.block.3.1.weight True
# 155 1=4 base_model.0.6.0.block.3.1.bias False
# 155 2=4 base_model.0.6.0.block.3.1.bias False
# 155 3=4 base_model.0.6.0.block.3.1.bias True
# 156 1=4 base_model.0.6.1.block.0.0.weight False
# 156 2=4 base_model.0.6.1.block.0.0.weight False
# 156 3=4 base_model.0.6.1.block.0.0.weight True
# 157 1=4 base_model.0.6.1.block.0.1.weight False
# 157 2=4 base_model.0.6.1.block.0.1.weight False
# 157 3=4 base_model.0.6.1.block.0.1.weight True
# 158 1=4 base_model.0.6.1.block.0.1.bias False
# 158 2=4 base_model.0.6.1.block.0.1.bias False
# 158 3=4 base_model.0.6.1.block.0.1.bias True
# 159 1=4 base_model.0.6.1.block.1.0.weight False
# 159 2=4 base_model.0.6.1.block.1.0.weight False
# 159 3=4 base_model.0.6.1.block.1.0.weight True
# 160 1=4 base_model.0.6.1.block.1.1.weight False
# 160 2=4 base_model.0.6.1.block.1.1.weight False
# 160 3=4 base_model.0.6.1.block.1.1.weight True
# 161 1=4 base_model.0.6.1.block.1.1.bias False
# 161 2=4 base_model.0.6.1.block.1.1.bias False
# 161 3=4 base_model.0.6.1.block.1.1.bias True
# 162 1=4 base_model.0.6.1.block.2.fc1.weight False
# 162 2=4 base_model.0.6.1.block.2.fc1.weight False
# 162 3=4 base_model.0.6.1.block.2.fc1.weight True
# 163 1=4 base_model.0.6.1.block.2.fc1.bias False
# 163 2=4 base_model.0.6.1.block.2.fc1.bias False
# 163 3=4 base_model.0.6.1.block.2.fc1.bias True
# 164 1=4 base_model.0.6.1.block.2.fc2.weight False
# 164 2=4 base_model.0.6.1.block.2.fc2.weight False
# 164 3=4 base_model.0.6.1.block.2.fc2.weight True
# 165 1=4 base_model.0.6.1.block.2.fc2.bias False
# 165 2=4 base_model.0.6.1.block.2.fc2.bias False
# 165 3=4 base_model.0.6.1.block.2.fc2.bias True
# 166 1=4 base_model.0.6.1.block.3.0.weight False
# 166 2=4 base_model.0.6.1.block.3.0.weight False
# 166 3=4 base_model.0.6.1.block.3.0.weight True
# 167 1=4 base_model.0.6.1.block.3.1.weight False
# 167 2=4 base_model.0.6.1.block.3.1.weight False
# 167 3=4 base_model.0.6.1.block.3.1.weight True
# 168 1=4 base_model.0.6.1.block.3.1.bias False
# 168 2=4 base_model.0.6.1.block.3.1.bias False
# 168 3=4 base_model.0.6.1.block.3.1.bias True
# 169 1=4 base_model.0.6.2.block.0.0.weight False
# 169 2=4 base_model.0.6.2.block.0.0.weight False
# 169 3=4 base_model.0.6.2.block.0.0.weight True
# 170 1=4 base_model.0.6.2.block.0.1.weight False
# 170 2=4 base_model.0.6.2.block.0.1.weight False
# 170 3=4 base_model.0.6.2.block.0.1.weight True
# 171 1=4 base_model.0.6.2.block.0.1.bias False
# 171 2=4 base_model.0.6.2.block.0.1.bias False
# 171 3=4 base_model.0.6.2.block.0.1.bias True
# 172 1=4 base_model.0.6.2.block.1.0.weight False
# 172 2=4 base_model.0.6.2.block.1.0.weight False
# 172 3=4 base_model.0.6.2.block.1.0.weight True
# 173 1=4 base_model.0.6.2.block.1.1.weight False
# 173 2=4 base_model.0.6.2.block.1.1.weight False
# 173 3=4 base_model.0.6.2.block.1.1.weight True
# 174 1=4 base_model.0.6.2.block.1.1.bias False
# 174 2=4 base_model.0.6.2.block.1.1.bias False
# 174 3=4 base_model.0.6.2.block.1.1.bias True
# 175 1=4 base_model.0.6.2.block.2.fc1.weight False
# 175 2=4 base_model.0.6.2.block.2.fc1.weight False
# 175 3=4 base_model.0.6.2.block.2.fc1.weight True
# 176 1=4 base_model.0.6.2.block.2.fc1.bias False
# 176 2=4 base_model.0.6.2.block.2.fc1.bias False
# 176 3=4 base_model.0.6.2.block.2.fc1.bias True
# 177 1=4 base_model.0.6.2.block.2.fc2.weight False
# 177 2=4 base_model.0.6.2.block.2.fc2.weight False
# 177 3=4 base_model.0.6.2.block.2.fc2.weight True
# 178 1=4 base_model.0.6.2.block.2.fc2.bias False
# 178 2=4 base_model.0.6.2.block.2.fc2.bias False
# 178 3=4 base_model.0.6.2.block.2.fc2.bias True
# 179 1=4 base_model.0.6.2.block.3.0.weight False
# 179 2=4 base_model.0.6.2.block.3.0.weight False
# 179 3=4 base_model.0.6.2.block.3.0.weight True
# 180 1=4 base_model.0.6.2.block.3.1.weight False
# 180 2=4 base_model.0.6.2.block.3.1.weight False
# 180 3=4 base_model.0.6.2.block.3.1.weight True
# 181 1=4 base_model.0.6.2.block.3.1.bias False
# 181 2=4 base_model.0.6.2.block.3.1.bias False
# 181 3=4 base_model.0.6.2.block.3.1.bias True
# 182 1=4 base_model.0.6.3.block.0.0.weight False
# 182 2=4 base_model.0.6.3.block.0.0.weight False
# 182 3=4 base_model.0.6.3.block.0.0.weight True
# 183 1=4 base_model.0.6.3.block.0.1.weight False
# 183 2=4 base_model.0.6.3.block.0.1.weight False
# 183 3=4 base_model.0.6.3.block.0.1.weight True
# 184 1=4 base_model.0.6.3.block.0.1.bias False
# 184 2=4 base_model.0.6.3.block.0.1.bias False
# 184 3=4 base_model.0.6.3.block.0.1.bias True
# 185 1=4 base_model.0.6.3.block.1.0.weight False
# 185 2=4 base_model.0.6.3.block.1.0.weight False
# 185 3=4 base_model.0.6.3.block.1.0.weight True
# 186 1=4 base_model.0.6.3.block.1.1.weight False
# 186 2=4 base_model.0.6.3.block.1.1.weight False
# 186 3=4 base_model.0.6.3.block.1.1.weight True
# 187 1=4 base_model.0.6.3.block.1.1.bias False
# 187 2=4 base_model.0.6.3.block.1.1.bias False
# 187 3=4 base_model.0.6.3.block.1.1.bias True
# 188 1=4 base_model.0.6.3.block.2.fc1.weight False
# 188 2=4 base_model.0.6.3.block.2.fc1.weight False
# 188 3=4 base_model.0.6.3.block.2.fc1.weight True
# 189 1=4 base_model.0.6.3.block.2.fc1.bias False
# 189 2=4 base_model.0.6.3.block.2.fc1.bias False
# 189 3=4 base_model.0.6.3.block.2.fc1.bias True
# 190 1=4 base_model.0.6.3.block.2.fc2.weight False
# 190 2=4 base_model.0.6.3.block.2.fc2.weight False
# 190 3=4 base_model.0.6.3.block.2.fc2.weight True
# 191 1=4 base_model.0.6.3.block.2.fc2.bias False
# 191 2=4 base_model.0.6.3.block.2.fc2.bias False
# 191 3=4 base_model.0.6.3.block.2.fc2.bias True
# 192 1=4 base_model.0.6.3.block.3.0.weight False
# 192 2=4 base_model.0.6.3.block.3.0.weight False
# 192 3=4 base_model.0.6.3.block.3.0.weight True
# 193 1=4 base_model.0.6.3.block.3.1.weight False
# 193 2=4 base_model.0.6.3.block.3.1.weight False
# 193 3=4 base_model.0.6.3.block.3.1.weight True
# 194 1=4 base_model.0.6.3.block.3.1.bias False
# 194 2=4 base_model.0.6.3.block.3.1.bias False
# 194 3=4 base_model.0.6.3.block.3.1.bias True
# 195 1=4 base_model.0.7.0.block.0.0.weight False
# 195 2=4 base_model.0.7.0.block.0.0.weight False
# 195 3=4 base_model.0.7.0.block.0.0.weight False
# 196 1=4 base_model.0.7.0.block.0.1.weight False
# 196 2=4 base_model.0.7.0.block.0.1.weight False
# 196 3=4 base_model.0.7.0.block.0.1.weight False
# 197 1=4 base_model.0.7.0.block.0.1.bias False
# 197 2=4 base_model.0.7.0.block.0.1.bias False
# 197 3=4 base_model.0.7.0.block.0.1.bias False
# 198 1=4 base_model.0.7.0.block.1.0.weight False
# 198 2=4 base_model.0.7.0.block.1.0.weight False
# 198 3=4 base_model.0.7.0.block.1.0.weight False
# 199 1=4 base_model.0.7.0.block.1.1.weight False
# 199 2=4 base_model.0.7.0.block.1.1.weight False
# 199 3=4 base_model.0.7.0.block.1.1.weight False
# 200 1=4 base_model.0.7.0.block.1.1.bias False
# 200 2=4 base_model.0.7.0.block.1.1.bias False
# 200 3=4 base_model.0.7.0.block.1.1.bias False
# 201 1=4 base_model.0.7.0.block.2.fc1.weight False
# 201 2=4 base_model.0.7.0.block.2.fc1.weight False
# 201 3=4 base_model.0.7.0.block.2.fc1.weight False
# 202 1=4 base_model.0.7.0.block.2.fc1.bias False
# 202 2=4 base_model.0.7.0.block.2.fc1.bias False
# 202 3=4 base_model.0.7.0.block.2.fc1.bias False
# 203 1=4 base_model.0.7.0.block.2.fc2.weight False
# 203 2=4 base_model.0.7.0.block.2.fc2.weight False
# 203 3=4 base_model.0.7.0.block.2.fc2.weight False
# 204 1=4 base_model.0.7.0.block.2.fc2.bias False
# 204 2=4 base_model.0.7.0.block.2.fc2.bias False
# 204 3=4 base_model.0.7.0.block.2.fc2.bias False
# 205 1=4 base_model.0.7.0.block.3.0.weight False
# 205 2=4 base_model.0.7.0.block.3.0.weight False
# 205 3=4 base_model.0.7.0.block.3.0.weight False
# 206 1=4 base_model.0.7.0.block.3.1.weight False
# 206 2=4 base_model.0.7.0.block.3.1.weight False
# 206 3=4 base_model.0.7.0.block.3.1.weight False
# 207 1=4 base_model.0.7.0.block.3.1.bias False
# 207 2=4 base_model.0.7.0.block.3.1.bias False
# 207 3=4 base_model.0.7.0.block.3.1.bias False
# 208 1=4 base_model.0.8.0.weight False
# 208 2=4 base_model.0.8.0.weight False
# 208 3=4 base_model.0.8.0.weight False
# 209 1=4 base_model.0.8.1.weight False
# 209 2=4 base_model.0.8.1.weight False
# 209 3=4 base_model.0.8.1.weight False
# 210 1=4 base_model.0.8.1.bias False
# 210 2=4 base_model.0.8.1.bias False
# 210 3=4 base_model.0.8.1.bias False
# 211 1=4 PreHead_0.weight False
# 211 2=4 PreHead_0.weight False
# 211 3=4 PreHead_0.weight False
# 212 1=4 PreHead_0.bias False
# 212 2=4 PreHead_0.bias False
# 212 3=4 PreHead_0.bias False
# 213 1=4 PreHead_1.weight False
# 213 2=4 PreHead_1.weight False
# 213 3=4 PreHead_1.weight False
# 214 1=4 PreHead_1.bias False
# 214 2=4 PreHead_1.bias False
# 214 3=4 PreHead_1.bias False
# 215 1=4 PostHead_0.weight False
# 215 2=4 PostHead_0.weight False
# 215 3=4 PostHead_0.weight False
# 216 1=4 PostHead_0.bias False
# 216 2=4 PostHead_0.bias False
# 216 3=4 PostHead_0.bias False
# 217 1=4 Classifier_0.weight False
# 217 2=4 Classifier_0.weight False
# 217 3=4 Classifier_0.weight False
# 218 1=4 Classifier_0.bias False
# 218 2=4 Classifier_0.bias False
# 218 3=4 Classifier_0.bias False

# %%
np.all(param_1.detach().numpy() == param_2.detach().numpy()), np.all(param_1.detach().numpy() == param_3.detach().numpy()), np.all(param_2.detach().numpy() == param_3.detach().numpy())
# Out:
# (False, False, False)

# %%
np.squeeze(model_params[195][1].detach().numpy())
# Out:
# array([[-0.09176432, -0.00588252,  0.02027349, ..., -0.03092107,
#          0.06761403, -0.01461071],
#        [-0.07848272, -0.01371442, -0.07482359, ...,  0.10687242,
#         -0.04747317, -0.08791421],
#        [-0.10090791, -0.05378744, -0.04679393, ...,  0.02166761,
#         -0.05217503, -0.03194081],
#        ...,
#        [-0.02420462, -0.00365353,  0.22248024, ...,  0.01756833,
#         -0.01050397, -0.03010276],
#        [-0.06661663,  0.08000631, -0.0047844 , ..., -0.17939425,
#          0.07883891, -0.1561394 ],
#        [-0.01726327, -0.13413514,  0.12521721, ...,  0.10406896,
#         -0.07013278,  0.0010998 ]], dtype=float32)

# %%
np.squeeze(model2_params[195][1].detach().numpy())
# Out:
# array([[-0.09259737, -0.00148659,  0.02181471, ..., -0.02394226,
#          0.06473046,  0.00086494],
#        [-0.06993268, -0.02882577, -0.06502995, ...,  0.10163853,
#         -0.05011335, -0.08235805],
#        [-0.1077586 , -0.05161716, -0.04124809, ...,  0.01477882,
#         -0.03953496, -0.04590347],
#        ...,
#        [-0.02840404, -0.00700152,  0.22568905, ...,  0.00865884,
#         -0.0146779 , -0.04499444],
#        [-0.05971367,  0.08413228, -0.00977129, ..., -0.18800034,
#          0.08246574, -0.16589299],
#        [-0.02095276, -0.13889514,  0.12529647, ...,  0.09240452,
#         -0.06731603,  0.00355882]], dtype=float32)
