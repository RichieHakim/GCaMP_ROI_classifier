# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import sys
import os
import copy
import pathlib

import numpy as np
import matplotlib.pyplot as plt
import scipy

import torch
import torchvision
import torchvision.transforms as transforms

# for creating validation set
from sklearn.model_selection import train_test_split

# %matplotlib notebook
# %matplotlib notebook
# %matplotlib inline
# %matplotlib qt

# %%
import sys

sys.path.append(r'/media/rich/Home_Linux_partition/github_repos')
# sys.path.append('/Users/Josh/Documents/github_repos/')

# %load_ext autoreload
# %autoreload 2
from basic_neural_processing_modules import torch_helpers, decomposition
from GCaMP_ROI_classifier.old_stuff import util, models, training_simCLR, augmentation, training_classHead

# %% [markdown]
# ## Import training data

# %%
import pickle

# with open('/Users/Josh/Documents/Harvard/label_data/all_stat_files_20211022.pkl', 'rb') as file:
with open('/media/rich/bigSSD/for_Josh/GCAMP_ROI_Classifier_data/label_data/all_stat_files_20211022.pkl', 'rb') as file:
    statFiles_scraped = pickle.load(file)

# %%
keys_toDelete = [
    '\\\\research.files.med.harvard.edu\\Neurobio\\MICROSCOPE\\Rich\\data\\res2p\\scanimage data\\for Loic\\16x_analysis20200514\\Suite2p and MC for denoised movie\\suite2p\\plane0\\stat.npy',
    '\\\\research.files.med.harvard.edu\\Neurobio\\MICROSCOPE\\Rich\\data\\res2p\\scanimage data\\round 4 experiments\\mouse 6.28\\20201102\\suite2p_accidentally_run_on_everything\\plane0\\stat.npy',
    '\\\\research.files.med.harvard.edu\\Neurobio\\MICROSCOPE\\Rich\\data\\res2p\\scanimage data\\for Loic\\20x\\mouse 2.5\\20200306\\suite2p attemp 2 _tau 1_5\\plane0\\stat.npy',
    '\\\\research.files.med.harvard.edu\\Neurobio\\MICROSCOPE\\Rich\\data\\res2p\\scanimage data\\for Loic\\20x\\mouse 2.5\\20200306\\suite2p attempt 1 _tau 2\\plane0\\stat.npy',
    '\\\\research.files.med.harvard.edu\\Neurobio\\MICROSCOPE\\Rich\\data\\res2p\\scanimage data\\for Loic\\20x\\mouse 2.5\\20200306\\suite2p attempt 3 _tau 1\\plane0\\stat.npy',
    '\\\\research.files.med.harvard.edu\\Neurobio\\MICROSCOPE\\Rich\\data\\res2p\\scanimage data\\for Loic\\AAV\\oldBMIrampExp_20191112_mouse1013A\\ROI extraction\\suite2p\\plane0\\stat.npy',
]
for key in keys_toDelete:
    del statFiles_scraped[key]

# %%
sf_list = util.convert_multiple_stat_files(statFiles_dict=statFiles_scraped, out_height_width=[36,36], max_footprint_width=901, plot_pref=False)

# images_all = np.concatenate(sf_list, axis=0)
images_all = np.concatenate([sf_list[ii][:1000] for ii in range(len(sf_list))], axis=0)

images_all.shape
# Out:
# (83190, 36, 36)

# %%
images_all_norm = (images_all / np.sum(images_all, axis=(1,2), keepdims=True)) * 255

# %%
# create validation set
# X_train, X_val, y_train, y_val = train_test_split(images[:], labels[:], test_size = 0.15)
X_train, X_val, y_train, y_val = train_test_split(images_all_norm, np.arange(images_all.shape[0]), test_size = 0.15)
(X_train.shape, y_train.shape), (X_val.shape, y_val.shape)
# Out:
# (((70711, 36, 36), (70711,)), ((12479, 36, 36), (12479,)))

# %%
dir_folders = r'/media/rich/bigSSD/for_Josh/GCAMP_ROI_Classifier_data/label_data'
# dir_folders = r'/users/Josh/Documents/Harvard/label_data'
folders = [r'mouse 6_28 _ day 20200903/',
             r'mouse6_28 _ day20200815/']
fileNames_statFiles = [r'stat.npy']*len(folders)
paths_statFiles = [pathlib.Path(dir_folders) / folders[ii] / fileNames_statFiles[ii] for ii in range(len(folders))]

statFile_import_kwargs = {'out_height_width': [36,36],
                          'max_footprint_width': 241,
                          'plot_pref':True}

sf_all = util.import_multiple_stat_files(   paths_statFiles=paths_statFiles,
                                        fileNames_statFiles=fileNames_statFiles,
                                        out_height_width=[36,36],
                                        max_footprint_width=241,
                                        plot_pref=True)
images_labeled = np.concatenate(sf_all, axis=0) *255
print(f'concatenated images shape: {images_labeled.shape}')

fileNames_labelFiles = ['labels_posthoc_filledIn_allCells.npy',
             'labels_posthoc_all.npy']
paths_labelFiles = [pathlib.Path(dir_folders) / folders[ii] / fileNames_labelFiles[ii] for ii in range(len(folders))]

labels_all = util.import_multiple_label_files(paths_labelFiles=paths_labelFiles,
                                       plot_pref=True)
labels = np.concatenate(labels_all)

assert np.alltrue([sf_all[ii].shape[0] == labels_all[ii].shape[0] for ii in range(len(sf_all))]) , 'num images in stat files does not correspond to num labels'
# Out:
# <img src="data:image/png;base64,..." width="572.85">
# <img src="data:image/png;base64,..." width="572.85">
# concatenated images shape: (9715, 36, 36)
# <img src="data:image/png;base64,..." width="572.85">
# <img src="data:image/png;base64,..." width="572.85">

# %%
# tmpd = pd.DataFrame(labels)
# tmpd[1] = tmpd[0]
# tmpd.groupby(0).count()

# %%
#code doesn't work with multiple open number maybe (?)

# %%
def squeeze_integers(arr):
    """
    Make integers in an array consecutive numbers
     starting from 0. ie. [7,2,7,4,1] -> [3,2,3,1,0].
    Useful for removing unused class IDs from y_true
     and outputting something appropriate for softmax.
    RH 2021
    Args:
        arr (np.ndarray):
            array of integers.
    
    Returns:
        arr_squeezed (np.ndarray):
            array of integers with consecutive numbers
    """
    uniques = np.unique(arr)
    arr_squeezed = copy.deepcopy(arr)
    for val in np.arange(0, np.max(arr)+1):
        if np.isin(val, uniques):
            continue
        else:
            arr_squeezed[arr_squeezed>val] = arr_squeezed[arr_squeezed>val]-1
    return arr_squeezed

# %%
labels = squeeze_integers(labels)
images_labeled = images_labeled[labels != 2]
labels = labels[labels != 2]
labels = squeeze_integers(labels)

# %% [raw]
# images_labeled = images_labeled[labels!=3]
# labels = labels[labels!=3]

# %% [markdown]
# ## Balance classes of inputs

# %%
duplicates = 1

images_dup = np.tile(images_labeled , (duplicates , 1 , 1))
labels_dup = np.tile(labels , (duplicates))

print(images_dup.shape)
print(labels_dup.shape)

numToGetTo = np.sum(labels_dup==0)
print(numToGetTo)

print(np.sum(labels_dup==0))
print(np.sum(labels_dup==1))
print(np.sum(labels_dup==4))
print(np.sum(labels_dup==5))
print(images_dup.shape)
print(labels_dup.shape)
# Out:
# (9714, 36, 36)
# (9714,)
# 532
# 532
# 620
# 0
# 0
# (9714, 36, 36)
# (9714,)

# %% [raw]
# # create validation set
# # X_train, X_val, y_train, y_val = train_test_split(images[:], labels[:], test_size = 0.15)
# X_train, X_val, y_train, y_val = train_test_split(images_dup[:], labels_dup[:], test_size = 0.15)
# (X_train.shape, y_train.shape), (X_val.shape, y_val.shape)

# %%
# create validation set
# X_train, X_val, y_train, y_val = train_test_split(images[:], labels[:], test_size = 0.15)
X_labeled_train, X_labeled_val, y_labeled_train, y_labeled_val = train_test_split(images_dup, labels_dup, test_size = 0.15)
(X_labeled_train.shape, y_labeled_train.shape), (X_labeled_val.shape, y_labeled_val.shape)
# Out:
# (((8256, 36, 36), (8256,)), ((1458, 36, 36), (1458,)))

# %% [raw]
# # create validation set
# # X_train, X_val, y_train, y_val = train_test_split(images[:], labels[:], test_size = 0.15)
# X_labeled_train, X_labeled_val, y_labeled_train, y_labeled_val = train_test_split(images_dup[labels!=3], labels_dup[labels!=3], test_size = 0.15)
# (X_labeled_train.shape, y_labeled_train.shape), (X_labeled_val.shape, y_labeled_val.shape)

# %%
plt.figure()
plt.hist(labels_dup, 20);
# Out:
# <img src="data:image/png;base64,..." width="572.85">

# %%
def idx_to_oneHot(arr, n_classes=None):
    """
    Convert an array of class indices to matrix of
     one-hot vectors.
    RH 2021

    Args:
        arr (np.ndarray):
            1-D array of class indices.
        n_classes (int):
            Number of classes.
    
    Returns:
        oneHot (np.ndarray):
            2-D array of one-hot vectors.
    """
    if n_classes is None:
        n_classes = np.max(arr)+1
    oneHot = np.zeros((arr.size, n_classes))
    oneHot[np.arange(arr.size), arr] = 1
    return oneHot

# %%
def rh_cm(y_hat, y_true):
    """
    Compute the confusion matrix from y_hat and y_true.
    y_hat should be either predictions ().
    RH 2021

    Args:
        y_hat (np.ndarray): 
            numpy array of predictions or probabilities. 
            Either PREDICTIONS: 2-D array of booleans
             ('one hots') or 1-D array of predicted 
             class indices.
            Or PROBABILITIES: 2-D array floats ('one hot
             like')
        y_true (np.ndarray):
            1-D array of true class indices.
    """
    n_classes = np.max(y_true)+1
    if y_hat.ndim == 1:
        y_hat = idx_to_oneHot(y_hat, n_classes)
    cmat = y_hat.T @ idx_to_oneHot(y_true, n_classes)
    return cmat / np.sum(cmat, axis=0)[None,:]
#     return cmat / torch.sum(cmat, dim=0)[None,:]

# %% [raw]
# from sklearn.linear_model import LogisticRegression
# import sklearn.metrics
#
# def classification_step(X_train, y_train, X_test, model, model_device, temperature):
#     logreg = LogisticRegression()
#     features_train = model(torch.as_tensor(X_train, device=DEVICE, dtype=torch.float32)[:,None,...]).detach().cpu()
#     # features = model(torch.tensor(X_train[y_train != 3], device=DEVICE, dtype=torch.float32)[:,None,...]).detach().cpu()
#     logreg.fit(features_train, y_train)
#     # logreg.fit(features, y_train[y_train != 3])
#
#     features_test = model(torch.as_tensor(X_test, device=DEVICE, dtype=torch.float32)[:,None,...]).detach().cpu()
#     y_hat = logreg.predict_proba(features_test)
#     y_hat = torch.as_tensor(y_hat, dtype=torch.float32, device='cpu')
#
# #     print(y_hat)
#     print(f'accuracy: {logreg.score(features, y):.5}')
#
# #     # cm = sklearn.metrics.confusion_matrix(idx_to_oneHot(y_train), y_hat, normalize='true')
# #     # cm = sklearn.metrics.confusion_matrix(idx_to_oneHot(y_train[y_train != 3]), y_hat, normalize='true')
# #     cm = rh_cm(y_hat, y)
# #     # cm = rh_cm(y_hat, y_train[y_train != 3])
#
#     unc = util.loss_uncertainty(y_hat, temperature=temperature)
#
# #     plt.figure()
# #     plt.imshow(cm)
# #     return torch.tensor(unc, dtype=torch.float32, device=model_device)
#     return unc

# %% [markdown]
# ## Define augmentation pipeline

# %%
import torchvision.transforms    

transforms = torch.nn.Sequential(
    torchvision.transforms.RandomHorizontalFlip(p=0.5),
    
    torchvision.transforms.GaussianBlur(kernel_size=5,
                                        sigma=(0.0001, 0.5)),
    
    torchvision.transforms.RandomPerspective(distortion_scale=0.4, 
                                             p=0.5, 
                                             interpolation=torchvision.transforms.InterpolationMode.BILINEAR, 
                                             fill=0),
    torchvision.transforms.RandomAffine(
                                        degrees=(-180,180),
                                        translate=(0.3, 0.3),
                                        scale=(0.7, 1.7), 
                                        shear=(-20, 20, -20, 20), 
                                        interpolation=torchvision.transforms.InterpolationMode.BILINEAR, 
                                        fill=0, 
                                        fillcolor=None, 
                                        resample=None),
    
    augmentation.AddPoissonNoise(   level_bounds=(0,0.3),
                                    prob=1),

    augmentation.AddGaussianNoise(  mean=0, 
                                    std=0.2,
                                    prob=1),
)
scripted_transforms = torch.jit.script(transforms)
# scripted_transforms = transforms



dataset_train = util.dataset_simCLR(
                                    torch.tensor(X_train), 
                                    y_train, 
#                                     torch.tensor(X_train), 
#                                     y_train, 
                                    n_transforms=2, 
#                                     class_weights=[1]*4,
#                                     class_weights=[0.34, 0.33, 0.33, 0.00],
#                                     class_weights=[0.0, 0.0, 0.0, 1.00],
#                                     class_weights=np.array([0.34, 0.33, 0.33, 0.00])[y_train],
#                                     class_weights=np.array([1]*4)[np.random.randint(0,4, X_train.shape[0])],
                                    class_weights=np.array([1]*4)[np.random.randint(0,4, X_train.shape[0])],
                                    transform=scripted_transforms,
                                    DEVICE='cpu',
                                    dtype_X=torch.float32,
                                    dtype_y=torch.int64 )

dataloader_train = torch.utils.data.DataLoader( dataset_train,
                                                batch_size=4096,
            #                                     sampler=sampler,
                                                shuffle=True,
                                                drop_last=True,
                                                pin_memory=True,
#                                                 num_workers=0,
                                                num_workers=32,
#                                                 prefetch_factor=0,
#                                                 persistent_workers=True,
                                                )

# dataset_val = util.dataset_simCLR(torch.tensor(X_val), 
#                                     y_val, 
#                                     n_transforms=2, 
#                                     transform=scripted_transforms,
#                                     DEVICE='cpu',
#                                     dtype_X=torch.float32,
#                                     dtype_y=torch.int64 )

# dataloader_val = torch.utils.data.DataLoader(   dataset_val,
#                                                 batch_size=128,
#             #                                     sampler=sampler,
#                                                 shuffle=True,
#                                                 drop_last=True,
#                                                 pin_memory=True,
#                                                 num_workers=0,
#                                                 )

# %% [raw]
# for ii, im in enumerate(images_all_norm):
#     plt.figure()
#     plt.imshow(im)
#     if ii > 1:
#         break

# %% [raw]
# import torch
# from torch.utils.data import Dataset, DataLoader
#
# import ctypes
# import multiprocessing as mp
#
# import numpy as np
#
#
# class MyDataset(Dataset):
#     def __init__(self):
#         shared_array_base = mp.Array(ctypes.c_float, nb_samples)
#         shared_array = np.ctypeslib.as_array(shared_array_base.get_obj())
#         shared_array = shared_array.reshape(nb_samples)
#         self.shared_array = torch.from_numpy(shared_array)
#
# #         self.shared_array = torch.rand(4)
# #         self.use_cache = False
#
# #     def set_use_cache(self, use_cache):
# #         self.use_cache = use_cache
#
#     def __getitem__(self, index):
# #         if not self.use_cache:
# #             print('Filling cache for index {}'.format(index))
# #             # Add your loading logic here
# #             self.shared_array[index] = torch.randn(1)
#         x = self.shared_array[index]
#         return x
#
#     def __len__(self):
#         return nb_samples
#
#
# nb_samples = 4
#
# dataset = MyDataset()
# loader = DataLoader(
#                     dataset,
#                     pin_memory=True,
# #                     num_workers=0,
#                     num_workers=32,
# #                     prefetch_factor=0,
#                     persistent_workers=True,
#                     shuffle=False
# )
#
# for epoch in range(4):
#     for idx, data in enumerate(loader):
#         print('Epoch {}, idx {}, data.shape {}'.format(epoch, idx, data))
#         dataset.shared_array = torch.rand(4)+epoch*10
#
# #     if epoch==0:
# #         loader.dataset.set_use_cache(True)

# %%
import time

# %matplotlib inline
tic=time.time()
# for ii, im in enumerate(dataset_train):
for ii,idx in enumerate(np.random.randint(0,X_train.shape[0], 5)):
#     for jj in range(im[0])
#     print(time.time() - tic)
#     tic = time.time()
#     print((im[0][0]).shape)
    print(dataset_train[idx][3])
    fig, axs = plt.subplots(2)
    for jj, ax in enumerate(axs):
#         ax.imshow(im[0][j].cpu().squeeze())
        ax.imshow(dataset_train[idx][0][jj].cpu().squeeze())
#     if ii > 5:
#         break
# Out:
# 1
# 1
# 1
# 1
# 1
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/site-packages/torch/nn/modules/module.py:1051: UserWarning: torch.lstsq is deprecated in favor of torch.linalg.lstsq and will be removed in a future PyTorch release.
# torch.linalg.lstsq has reversed arguments and does not return the QR decomposition in the returned tuple (although it returns other information about the problem).
# To get the qr decomposition consider using torch.linalg.qr.
# The returned solution in torch.lstsq stored the residuals of the solution in the last m - n columns of the returned value whenever m > n. In torch.linalg.lstsq, the residuals in the field 'residuals' of the returned named tuple.
# The unpacking of the solution, as in
# X, _ = torch.lstsq(B, A).solution[:A.size(1)]
# should be replaced with
# X = torch.linalg.lstsq(A, B).solution (Triggered internally at  ../aten/src/ATen/LegacyTHFunctionsCPU.cpp:389.)
#   return forward_call(*input, **kwargs)

# %% [markdown]
# ## Train

# %%
DEVICE = torch_helpers.set_device(use_GPU=True)
# Out:
# device: 'cuda'

# %%
from torch.nn import CrossEntropyLoss
from torch.optim import Adam

import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix


model = models.LeNet1(dropout_prob=0.3, momentum_val=0, n_output_features=128)
model.train()
# criterion = CrossEntropyLoss()
criterion = CrossEntropyLoss(reduction='none')

optimizer = Adam(model.parameters(), lr=3e-3, weight_decay=0.005)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer,
                                                   gamma=1-0.0001,
#                                                    gamma=1,
                                                  )
# val_obj = training_simCLR.validation_Obj(   X_val,
#                                             y_val,
#                                             model,
#                                             criterion,
#                                             DEVICE=DEVICE,
#                                             dtype_X=torch.float32,
#                                             dtype_y=torch.int64) # Needs to take in weights

model.to(DEVICE)
criterion = criterion.to(DEVICE)

# # classHead = HeadModel(model, RandomForestClassifier)
# classHead = training_classHead.HeadModel(model, LogisticRegression)
# dataset_train.headmodel = classHead
# # dataset_train.headmodel = None

losses_train, losses_val, val_accs, acc = [], [np.nan], [], []

# %%
# %matplotlib inline

logreg = LogisticRegression(solver='liblinear')
dataset_train.classification_model = None

# scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer,
#                                                    gamma=1-0.001,
# #                                                    gamma=1,
#                                                   )
n_epochs=300000
for epoch in range(n_epochs):
    print(f'epoch: {epoch}')
    training_simCLR.epoch_step( dataloader_train, 
                                model, 
                                optimizer, 
                                criterion, 
                                scheduler=scheduler, 
                                temperature=0.5,
                                loss_rolling_train=losses_train, 
                                device=DEVICE, 
                                do_validation=False,
#                                 validation_Object=val_obj,
                                loss_rolling_val=losses_val,
                                verbose=2,
                                verbose_update_period=100,
                               )
    

    
    features_train = model(torch.as_tensor(X_labeled_train, device=DEVICE, dtype=torch.float32)[:,None,...]).detach().cpu()
    # features = model(torch.tensor(X_train[y_train != 3], device=DEVICE, dtype=torch.float32)[:,None,...]).detach().cpu()
    logreg.fit(features_train, y_labeled_train)
    acc.append(logreg.score(features_train, y_labeled_train))
    print(f'acc: {acc[-1]}')
    
    dataset_train.net_model = copy.deepcopy(model).to('cpu')
    dataset_train.classification_model = logreg
    
    
    
    # model predict
    # Update model in DS
    # get item calls model for each sample
    # output
    # X sample weights predictions
    
#     classHead.fit(X_train[:, None, :, :], y_train, solver='liblinear')
    
#     proba = classHead.predict_proba(X_train[:, None, :, :])
#     class_weights = proba.sum(axis=0)
#     total_num = class_weights.sum()
    
#     eps = 1e-4
    
#     class_weights[class_weights <= 3] = total_num
#     weightings = class_weights.sum()/class_weights
#     final_weights = weightings / weightings.sum()
#     final_weights = np.array([1/proba.shape[1] for _ in range(proba.shape[1])])
    
#     print(class_weights)

#     dataset_train.set_classweights(final_weights)
    
#     print('dataset_train.final_weights', dataset_train.class_weights)
# Out:
# epoch: 0
# Iter: 0/17, loss_train: 8.9499, loss_val: nan, lr: 0.0029997
# acc: 0.8604651162790697
# epoch: 1
# Iter: 0/17, loss_train: 7.9903, loss_val: nan, lr: 0.0029946
# acc: 0.8642199612403101
# epoch: 2
# Iter: 0/17, loss_train: 7.889, loss_val: nan, lr: 0.0029895
# acc: 0.8699127906976745
# epoch: 3
# Iter: 0/17, loss_train: 7.7925, loss_val: nan, lr: 0.0029844
# acc: 0.8706395348837209
# epoch: 4
# Iter: 0/17, loss_train: 7.7604, loss_val: nan, lr: 0.0029794
# acc: 0.8703972868217055
# epoch: 5
# Iter: 0/17, loss_train: 7.654, loss_val: nan, lr: 0.0029743
# acc: 0.8718507751937985
# epoch: 6
# Iter: 0/17, loss_train: 7.6513, loss_val: nan, lr: 0.0029693
# acc: 0.8766957364341085
# epoch: 7
# Iter: 0/17, loss_train: 7.6269, loss_val: nan, lr: 0.0029642
# acc: 0.874031007751938
# epoch: 8
# Iter: 0/17, loss_train: 7.5691, loss_val: nan, lr: 0.0029592
# acc: 0.8773013565891473
# epoch: 9
# Iter: 0/17, loss_train: 7.5722, loss_val: nan, lr: 0.0029542
# acc: 0.8777858527131783
# epoch: 10
# Iter: 0/17, loss_train: 7.5663, loss_val: nan, lr: 0.0029491
# acc: 0.8787548449612403
# epoch: 11
# Iter: 0/17, loss_train: 7.5553, loss_val: nan, lr: 0.0029441
# acc: 0.8792393410852714
# epoch: 12
# Iter: 0/17, loss_train: 7.5875, loss_val: nan, lr: 0.0029391
# acc: 0.8796027131782945
# epoch: 13
# Iter: 0/17, loss_train: 7.5373, loss_val: nan, lr: 0.0029341
# acc: 0.8782703488372093
# epoch: 14
# Iter: 0/17, loss_train: 7.5307, loss_val: nan, lr: 0.0029291
# acc: 0.8794815891472868
# epoch: 15
# Iter: 0/17, loss_train: 7.5232, loss_val: nan, lr: 0.0029242
# acc: 0.8803294573643411
# epoch: 16
# Iter: 0/17, loss_train: 7.5253, loss_val: nan, lr: 0.0029192
# acc: 0.8823885658914729
# epoch: 17
# Iter: 0/17, loss_train: 7.5569, loss_val: nan, lr: 0.0029142
# acc: 0.8810562015503876
# epoch: 18
# Iter: 0/17, loss_train: 7.5632, loss_val: nan, lr: 0.0029093
# acc: 0.8821463178294574
# epoch: 19
# Iter: 0/17, loss_train: 7.5427, loss_val: nan, lr: 0.0029044
# acc: 0.8812984496124031
# epoch: 20
# Iter: 0/17, loss_train: 7.5012, loss_val: nan, lr: 0.0028994
# acc: 0.8808139534883721
# epoch: 21
# Iter: 0/17, loss_train: 7.508, loss_val: nan, lr: 0.0028945
# acc: 0.8820251937984496
# epoch: 22
# Iter: 0/17, loss_train: 7.5301, loss_val: nan, lr: 0.0028896
# acc: 0.8805717054263565
# epoch: 23
# Iter: 0/17, loss_train: 7.5094, loss_val: nan, lr: 0.0028847
# acc: 0.8827519379844961
# epoch: 24
# Iter: 0/17, loss_train: 7.4889, loss_val: nan, lr: 0.0028798
# acc: 0.8835998062015504
# epoch: 25
# Iter: 0/17, loss_train: 7.4949, loss_val: nan, lr: 0.0028749
# acc: 0.8800872093023255
# epoch: 26
# Iter: 0/17, loss_train: 7.5026, loss_val: nan, lr: 0.00287
# acc: 0.8810562015503876
# epoch: 27
# Iter: 0/17, loss_train: 7.4961, loss_val: nan, lr: 0.0028651
# acc: 0.8800872093023255
# epoch: 28
# Iter: 0/17, loss_train: 7.5066, loss_val: nan, lr: 0.0028603
# acc: 0.8804505813953488
# epoch: 29
# Iter: 0/17, loss_train: 7.4988, loss_val: nan, lr: 0.0028554
# acc: 0.8812984496124031
# epoch: 30
# Iter: 0/17, loss_train: 7.5, loss_val: nan, lr: 0.0028505
# acc: 0.8753633720930233
# epoch: 31
# Iter: 0/17, loss_train: 7.511, loss_val: nan, lr: 0.0028457
# acc: 0.8785125968992248
# epoch: 32
# Iter: 0/17, loss_train: 7.4853, loss_val: nan, lr: 0.0028409
# acc: 0.8746366279069767
# epoch: 33
# Iter: 0/17, loss_train: 7.4958, loss_val: nan, lr: 0.002836
# acc: 0.8677325581395349
# epoch: 34
# Iter: 0/17, loss_train: 7.5011, loss_val: nan, lr: 0.0028312
# acc: 0.8677325581395349
# epoch: 35
# Iter: 0/17, loss_train: 7.4867, loss_val: nan, lr: 0.0028264
# acc: 0.8655523255813954
# epoch: 36
# Iter: 0/17, loss_train: 7.494, loss_val: nan, lr: 0.0028216
# acc: 0.8666424418604651
# epoch: 37
# Iter: 0/17, loss_train: 7.4864, loss_val: nan, lr: 0.0028168
# acc: 0.8672480620155039
# epoch: 38
# Iter: 0/17, loss_train: 7.4965, loss_val: nan, lr: 0.002812
# acc: 0.8685804263565892
# epoch: 39
# Iter: 0/17, loss_train: 7.4808, loss_val: nan, lr: 0.0028073
# acc: 0.8670058139534884
# epoch: 40
# Iter: 0/17, loss_train: 7.4876, loss_val: nan, lr: 0.0028025
# acc: 0.8667635658914729
# epoch: 41
# Iter: 0/17, loss_train: 7.4993, loss_val: nan, lr: 0.0027977
# acc: 0.8685804263565892
# epoch: 42
# Iter: 0/17, loss_train: 7.473, loss_val: nan, lr: 0.002793
# acc: 0.8679748062015504
# epoch: 43
# Iter: 0/17, loss_train: 7.4793, loss_val: nan, lr: 0.0027882
# acc: 0.8688226744186046
# epoch: 44
# Iter: 0/17, loss_train: 7.4957, loss_val: nan, lr: 0.0027835
# acc: 0.8678536821705426
# epoch: 45
# Iter: 0/17, loss_train: 7.493, loss_val: nan, lr: 0.0027788
# acc: 0.8671269379844961
# epoch: 46
# Iter: 0/17, loss_train: 7.4774, loss_val: nan, lr: 0.0027741
# acc: 0.8667635658914729
# epoch: 47
# Iter: 0/17, loss_train: 7.4805, loss_val: nan, lr: 0.0027693
# acc: 0.8682170542635659
# epoch: 48
# Iter: 0/17, loss_train: 7.4739, loss_val: nan, lr: 0.0027646
# acc: 0.8671269379844961
# epoch: 49
# Iter: 0/17, loss_train: 7.5128, loss_val: nan, lr: 0.0027599
# acc: 0.8682170542635659
# epoch: 50
# Iter: 0/17, loss_train: 7.4752, loss_val: nan, lr: 0.0027552
# acc: 0.8685804263565892
# epoch: 51
# Iter: 0/17, loss_train: 7.4791, loss_val: nan, lr: 0.0027506
# acc: 0.8677325581395349
# epoch: 52
# Iter: 0/17, loss_train: 7.4892, loss_val: nan, lr: 0.0027459
# acc: 0.8679748062015504
# epoch: 53
# Iter: 0/17, loss_train: 7.4749, loss_val: nan, lr: 0.0027412
# acc: 0.8682170542635659
# epoch: 54
# Iter: 0/17, loss_train: 7.48, loss_val: nan, lr: 0.0027366
# acc: 0.8680959302325582
# epoch: 55
# Iter: 0/17, loss_train: 7.476, loss_val: nan, lr: 0.0027319
# acc: 0.8683381782945736
# epoch: 56
# Iter: 0/17, loss_train: 7.4801, loss_val: nan, lr: 0.0027273
# acc: 0.8691860465116279
# epoch: 57
# Iter: 0/17, loss_train: 7.5242, loss_val: nan, lr: 0.0027227
# acc: 0.8667635658914729
# epoch: 58
# Iter: 0/17, loss_train: 7.4766, loss_val: nan, lr: 0.002718
# acc: 0.8680959302325582
# epoch: 59
# Iter: 0/17, loss_train: 7.4676, loss_val: nan, lr: 0.0027134
# acc: 0.8673691860465116
# epoch: 60
# Iter: 0/17, loss_train: 7.4731, loss_val: nan, lr: 0.0027088
# acc: 0.8672480620155039
# epoch: 61
# Iter: 0/17, loss_train: 7.4875, loss_val: nan, lr: 0.0027042
# acc: 0.8688226744186046
# epoch: 62
# Iter: 0/17, loss_train: 7.4725, loss_val: nan, lr: 0.0026996
# acc: 0.8680959302325582
# epoch: 63
# Iter: 0/17, loss_train: 7.484, loss_val: nan, lr: 0.002695
# acc: 0.8648255813953488
# epoch: 64
# Iter: 0/17, loss_train: 7.4852, loss_val: nan, lr: 0.0026904
# acc: 0.8682170542635659
# epoch: 65
# Iter: 0/17, loss_train: 7.4861, loss_val: nan, lr: 0.0026859
# acc: 0.8638565891472868
# epoch: 66
# Iter: 0/17, loss_train: 7.4654, loss_val: nan, lr: 0.0026813
# acc: 0.8657945736434108
# epoch: 67
# Iter: 0/17, loss_train: 7.4779, loss_val: nan, lr: 0.0026768
# acc: 0.8676114341085271
# epoch: 68
# Iter: 0/17, loss_train: 7.472, loss_val: nan, lr: 0.0026722
# acc: 0.8684593023255814
# epoch: 69
# Iter: 0/17, loss_train: 7.481, loss_val: nan, lr: 0.0026677
# acc: 0.8679748062015504
# epoch: 70
# Iter: 0/17, loss_train: 7.4706, loss_val: nan, lr: 0.0026631
# acc: 0.8676114341085271
# epoch: 71
# Iter: 0/17, loss_train: 7.4667, loss_val: nan, lr: 0.0026586
# acc: 0.8684593023255814
# epoch: 72
# Iter: 0/17, loss_train: 7.4665, loss_val: nan, lr: 0.0026541
# acc: 0.8674903100775194
# epoch: 73
# Iter: 0/17, loss_train: 7.4698, loss_val: nan, lr: 0.0026496
# acc: 0.8487160852713178
# epoch: 74
# Iter: 0/17, loss_train: 7.4691, loss_val: nan, lr: 0.0026451
# acc: 0.8661579457364341
# epoch: 75
# Iter: 0/17, loss_train: 7.4539, loss_val: nan, lr: 0.0026406
# acc: 0.8596172480620154
# epoch: 76
# Iter: 0/17, loss_train: 7.4714, loss_val: nan, lr: 0.0026361
# acc: 0.8504118217054264
# epoch: 77
# Iter: 0/17, loss_train: 7.4679, loss_val: nan, lr: 0.0026316
# acc: 0.8631298449612403
# epoch: 78
# Iter: 0/17, loss_train: 7.4688, loss_val: nan, lr: 0.0026272
# acc: 0.8672480620155039
# epoch: 79
# Iter: 0/17, loss_train: 7.4592, loss_val: nan, lr: 0.0026227
# acc: 0.8680959302325582
# epoch: 80
# Iter: 0/17, loss_train: 7.4614, loss_val: nan, lr: 0.0026182
# acc: 0.8674903100775194
# epoch: 81
# Iter: 0/17, loss_train: 7.4629, loss_val: nan, lr: 0.0026138
# acc: 0.8475048449612403
# epoch: 82
# Iter: 0/17, loss_train: 7.4544, loss_val: nan, lr: 0.0026094
# acc: 0.8567102713178295
# epoch: 83
# Iter: 0/17, loss_train: 7.492, loss_val: nan, lr: 0.0026049
# acc: 0.8690649224806202
# epoch: 84
# Iter: 0/17, loss_train: 7.471, loss_val: nan, lr: 0.0026005
# acc: 0.8672480620155039
# epoch: 85
# Iter: 0/17, loss_train: 7.4638, loss_val: nan, lr: 0.0025961
# acc: 0.8642199612403101
# epoch: 86
# Iter: 0/17, loss_train: 7.4723, loss_val: nan, lr: 0.0025917
# acc: 0.8481104651162791
# epoch: 87
# Iter: 0/17, loss_train: 7.4573, loss_val: nan, lr: 0.0025873
# acc: 0.8476259689922481
# epoch: 88
# Iter: 0/17, loss_train: 7.4611, loss_val: nan, lr: 0.0025829
# acc: 0.8478682170542635
# epoch: 89
# Iter: 0/17, loss_train: 7.4741, loss_val: nan, lr: 0.0025785
# acc: 0.8667635658914729
# epoch: 90
# Iter: 0/17, loss_train: 7.4753, loss_val: nan, lr: 0.0025741
# acc: 0.8565891472868217
# epoch: 91
# Iter: 0/17, loss_train: 7.4582, loss_val: nan, lr: 0.0025697
# acc: 0.8671269379844961
# epoch: 92
# Iter: 0/17, loss_train: 7.4757, loss_val: nan, lr: 0.0025654
# acc: 0.8475048449612403
# epoch: 93
# Iter: 0/17, loss_train: 7.4649, loss_val: nan, lr: 0.002561
# acc: 0.8472625968992248
# epoch: 94
# Iter: 0/17, loss_train: 7.4736, loss_val: nan, lr: 0.0025567
# acc: 0.8472625968992248
# epoch: 95
# Iter: 0/17, loss_train: 7.4694, loss_val: nan, lr: 0.0025523
# acc: 0.8475048449612403
# epoch: 96
# Iter: 0/17, loss_train: 7.4732, loss_val: nan, lr: 0.002548
# acc: 0.8664001937984496
# epoch: 97
# Iter: 0/17, loss_train: 7.455, loss_val: nan, lr: 0.0025437
# acc: 0.8651889534883721
# epoch: 98
# Iter: 0/17, loss_train: 7.4605, loss_val: nan, lr: 0.0025393
# acc: 0.861797480620155
# epoch: 99
# Iter: 0/17, loss_train: 7.4567, loss_val: nan, lr: 0.002535
# acc: 0.8475048449612403
# epoch: 100
# Iter: 0/17, loss_train: 7.4672, loss_val: nan, lr: 0.0025307
# acc: 0.8477470930232558
# epoch: 101
# Iter: 0/17, loss_train: 7.469, loss_val: nan, lr: 0.0025264
# acc: 0.8578003875968992
# epoch: 102
# Iter: 0/17, loss_train: 7.4584, loss_val: nan, lr: 0.0025221
# acc: 0.8477470930232558
# epoch: 103
# Iter: 0/17, loss_train: 7.4647, loss_val: nan, lr: 0.0025178
# acc: 0.8478682170542635
# epoch: 104
# Iter: 0/17, loss_train: 7.4497, loss_val: nan, lr: 0.0025136
# acc: 0.8483527131782945
# epoch: 105
# Iter: 0/17, loss_train: 7.4725, loss_val: nan, lr: 0.0025093
# acc: 0.8473837209302325
# epoch: 106
# Iter: 0/17, loss_train: 7.4501, loss_val: nan, lr: 0.002505
# acc: 0.8483527131782945
# epoch: 107
# Iter: 0/17, loss_train: 7.4697, loss_val: nan, lr: 0.0025008
# acc: 0.8476259689922481
# epoch: 108
# Iter: 0/17, loss_train: 7.4715, loss_val: nan, lr: 0.0024965
# acc: 0.8472625968992248
# epoch: 109
# Iter: 0/17, loss_train: 7.4445, loss_val: nan, lr: 0.0024923
# acc: 0.846656976744186
# epoch: 110
# Iter: 0/17, loss_train: 7.4629, loss_val: nan, lr: 0.0024881
# acc: 0.8477470930232558
# epoch: 111
# Iter: 0/17, loss_train: 7.4834, loss_val: nan, lr: 0.0024838
# acc: 0.8483527131782945
# epoch: 112
# Iter: 0/17, loss_train: 7.4586, loss_val: nan, lr: 0.0024796
# acc: 0.8482315891472868
# epoch: 113
# Iter: 0/17, loss_train: 7.4597, loss_val: nan, lr: 0.0024754
# acc: 0.8477470930232558
# epoch: 114
# Iter: 0/17, loss_train: 7.4442, loss_val: nan, lr: 0.0024712
# acc: 0.8477470930232558
# epoch: 115
# Iter: 0/17, loss_train: 7.4428, loss_val: nan, lr: 0.002467
# acc: 0.8477470930232558
# epoch: 116
# Iter: 0/17, loss_train: 7.4722, loss_val: nan, lr: 0.0024628
# acc: 0.8476259689922481
# epoch: 117
# Iter: 0/17, loss_train: 7.4618, loss_val: nan, lr: 0.0024586
# acc: 0.8476259689922481
# epoch: 118
# Iter: 0/17, loss_train: 7.4571, loss_val: nan, lr: 0.0024544
# acc: 0.8481104651162791
# epoch: 119
# Iter: 0/17, loss_train: 7.4965, loss_val: nan, lr: 0.0024503
# acc: 0.8476259689922481
# epoch: 120
# Iter: 0/17, loss_train: 7.4454, loss_val: nan, lr: 0.0024461
# acc: 0.8475048449612403
# epoch: 121
# Iter: 0/17, loss_train: 7.4445, loss_val: nan, lr: 0.002442
# acc: 0.8471414728682171
# epoch: 122
# Iter: 0/17, loss_train: 7.4747, loss_val: nan, lr: 0.0024378
# acc: 0.8470203488372093
# epoch: 123
# Iter: 0/17, loss_train: 7.4587, loss_val: nan, lr: 0.0024337
# acc: 0.8467781007751938
# epoch: 124
# Iter: 0/17, loss_train: 7.4582, loss_val: nan, lr: 0.0024295
# acc: 0.8476259689922481
# epoch: 125
# Iter: 0/17, loss_train: 7.4577, loss_val: nan, lr: 0.0024254
# acc: 0.8477470930232558
# epoch: 126
# Iter: 0/17, loss_train: 7.4604, loss_val: nan, lr: 0.0024213
# acc: 0.8473837209302325
# epoch: 127
# Iter: 0/17, loss_train: 7.4616, loss_val: nan, lr: 0.0024172
# acc: 0.8478682170542635
# epoch: 128
# Iter: 0/17, loss_train: 7.4651, loss_val: nan, lr: 0.0024131
# acc: 0.8470203488372093
# epoch: 129
# Iter: 0/17, loss_train: 7.4411, loss_val: nan, lr: 0.002409
# acc: 0.8476259689922481
# epoch: 130
# Iter: 0/17, loss_train: 7.4644, loss_val: nan, lr: 0.0024049
# acc: 0.8472625968992248
# epoch: 131
# Iter: 0/17, loss_train: 7.4377, loss_val: nan, lr: 0.0024008
# acc: 0.8476259689922481
# epoch: 132
# Iter: 0/17, loss_train: 7.4671, loss_val: nan, lr: 0.0023967
# acc: 0.8475048449612403
# epoch: 133
# Iter: 0/17, loss_train: 7.4412, loss_val: nan, lr: 0.0023926
# acc: 0.8471414728682171
# epoch: 134
# Iter: 0/17, loss_train: 7.4622, loss_val: nan, lr: 0.0023886
# acc: 0.8476259689922481
# epoch: 135
# Iter: 0/17, loss_train: 7.4617, loss_val: nan, lr: 0.0023845
# acc: 0.8479893410852714
# epoch: 136
# Iter: 0/17, loss_train: 7.4457, loss_val: nan, lr: 0.0023805
# acc: 0.8472625968992248
# epoch: 137
# Iter: 0/17, loss_train: 7.4577, loss_val: nan, lr: 0.0023764
# acc: 0.8467781007751938
# epoch: 138
# Iter: 0/17, loss_train: 7.4432, loss_val: nan, lr: 0.0023724
# acc: 0.8479893410852714
# epoch: 139
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-b99d440136e7> in <module>
#      11 for epoch in range(n_epochs):
#      12     print(f'epoch: {epoch}')
# ---> 13     training_simCLR.epoch_step( dataloader_train,
#      14                                 model,
#      15                                 optimizer,
#
# /media/rich/Home_Linux_partition/github_repos/GCaMP_ROI_classifier/old_stuff/training_simCLR.py in epoch_step(dataloader, model, optimizer, criterion, scheduler, temperature, loss_rolling_train, device, do_validation, validation_Object, loss_rolling_val, verbose, verbose_update_period)
#     132         print(f'Iter: {batch}/{n_batches}, loss_train: {loss_train:.{precis}}, loss_val: {loss_val:.{precis}}, lr: {learning_rate:.{precis}}')
#     133
# --> 134     for i_batch, (X_batch, y_batch, idx_batch, sample_weights) in enumerate(dataloader):
#     135         X_batch = torch.cat(X_batch, dim=0)
#     136         X_batch = X_batch.to(device)
#
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1184
#    1185             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1186             idx, data = self._get_data()
#    1187             self._tasks_outstanding -= 1
#    1188             if self._dataset_kind == _DatasetKind.Iterable:
#
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1140         elif self._pin_memory:
#    1141             while self._pin_memory_thread.is_alive():
# -> 1142                 success, data = self._try_get_data()
#    1143                 if success:
#    1144                     return data
#
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     988         #   (bool: whether successfully get data, any: data if successful else None)
#     989         try:
# --> 990             data = self._data_queue.get(timeout=timeout)
#     991             return (True, data)
#     992         except Exception as e:
#
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/queue.py in get(self, block, timeout)
#     177                     if remaining <= 0.0:
#     178                         raise Empty
# --> 179                     self.not_empty.wait(remaining)
#     180             item = self._get()
#     181             self.not_full.notify()
#
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/threading.py in wait(self, timeout)
#     304             else:
#     305                 if timeout > 0:
# --> 306                     gotit = waiter.acquire(True, timeout)
#     307                 else:
#     308                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
plt.figure()
plt.plot(losses_train)

# %%
# %matplotlib notebook
plt.figure()
plt.plot(losses_train)
# Out:
# <img src="data:image/png;base64,..." width="386.3666666666667">

# %%
# %matplotlib notebook
plt.figure()
plt.plot(losses_train)
# Out:
# <img src="data:image/png;base64,..." width="386.3666666666667">

# %%
# %matplotlib inline 
plt.figure()
plt.plot(np.array(acc))

# %%
features_train = model(torch.as_tensor(X_labeled_train, device=DEVICE, dtype=torch.float32)[:,None,...]).detach().cpu()
# features = model(torch.tensor(X_train[y_train != 3], device=DEVICE, dtype=torch.float32)[:,None,...]).detach().cpu()
logreg.fit(features_train, y_labeled_train)
y_hat = logreg.predict_proba(features_train)
cm = rh_cm(y_hat, y_labeled_train)

plt.figure()
plt.imshow(cm)

# %%
proba = classHead.predict_proba(dataset_train.X)

# %%
# classHead.fit(X_train[:, None, :, :], y_train)



proba = classHead.predict_proba(X_train[:, None, :, :])
final_weights = np.array([1/proba.shape[1] for _ in range(proba.shape[1])])

dataset_train.set_classweights(final_weights)

# %%
# %load_ext autoreload
# %autoreload 2

from basic_neural_processing_modules import decomposition
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
logreg = LogisticRegression(solver='liblinear')
head = classHead.get_simCLR_head(X_train[:, None, ...])
# head = classHead.norm_head(head)
# head = head[:, [_ for _ in range(64) if _ not in [7, 15, 20, 21, 36, 54, 57, 60, 61, 62, 63, 64]]]
components , scores , decomposition.explained_variance_ratio_ , stds = decomposition.simple_pca(head, n_components=None)

# logreg.fit(scores[:, :], y_train)
# logreg.predict_proba(scores[:, :])
logreg.fit(head, y_train)
logreg.predict_proba(head)
# Out:
# array([[7.38606327e-13, 9.82938418e-09, 5.31466834e-06, 9.99994676e-01],
#        [1.62968581e-01, 2.46029907e-01, 3.00199851e-01, 2.90801661e-01],
#        [2.38470334e-11, 9.68791835e-08, 2.48697816e-05, 9.99975033e-01],
#        ...,
#        [2.35114301e-10, 4.41739816e-07, 7.60582958e-05, 9.99923500e-01],
#        [3.22474556e-06, 2.38832089e-04, 6.03245991e-03, 9.93725483e-01],
#        [1.19631619e-14, 6.07571093e-10, 5.86688485e-07, 9.99999413e-01]])

# %%
prd = logreg.predict_proba(head)
# prd = logreg.predict_proba(scores[:, :2])
plt.figure()
# plt.plot(logreg.predict_proba(scores[:, :2]))
plt.plot(logreg.predict_proba(head))
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">
# [<matplotlib.lines.Line2D at 0x7f2bba745b80>,
#  <matplotlib.lines.Line2D at 0x7f2bba745bb0>,
#  <matplotlib.lines.Line2D at 0x7f2bba745c10>,
#  <matplotlib.lines.Line2D at 0x7f2bba745d30>]

# %%
# cm = confusion_matrix(y_train, np.argmax(logreg.predict_proba(scores[:, :2]), axis=1))
cm = confusion_matrix(y_train, np.argmax(logreg.predict_proba(head), axis=1))
cm = np.round(cm/cm.sum(axis=0), 2)
cm
# Out:
# array([[0.45, 0.39, 0.13, 0.  ],
#        [0.31, 0.35, 0.34, 0.01],
#        [0.2 , 0.21, 0.34, 0.03],
#        [0.03, 0.05, 0.18, 0.96]])

# %%
logreg.predict_proba(classHead.get_simCLR_head(X_val[:, None, :, :]))
# Out:
# array([[6.24413387e-04, 7.08298809e-03, 4.78895874e-02, 9.44403011e-01],
#        [1.46328821e-15, 1.52492185e-10, 2.02354552e-07, 9.99999797e-01],
#        [3.05682540e-14, 1.13200002e-09, 9.43359933e-07, 9.99999056e-01],
#        ...,
#        [9.96917403e-10, 1.15630352e-06, 1.62694854e-04, 9.99836148e-01],
#        [1.47265253e-01, 2.32845574e-01, 2.86896827e-01, 3.32992347e-01],
#        [2.41787743e-11, 9.68560866e-08, 2.39367315e-05, 9.99975966e-01]])

# %%
classHead.fit(X_train[:, None, :, :], y_train)

# %%
classHead.predict_proba(X_train[:, None, :, :])

# %%
idx_sample = 5
classHead.predict_proba(X_train[idx_sample:idx_sample+1, None, ...])

# %%
sample_weight = util.loss_uncertainty(torch.as_tensor(proba), temperature=1, class_value=dataset_train.class_weights)

# %% [markdown]
# ## Check embeddings

# %%
torch.cuda.empty_cache()

# %%
features = model(torch.tensor(images_labeled, device=DEVICE, dtype=torch.float32)[:,None,...]).detach()
# features = model(torch.tensor(images_labeled[labels != 3], device=DEVICE, dtype=torch.float32)[:,None,...]).detach()
# features = model(torch.tensor(X_val, device=DEVICE, dtype=torch.float32)[:,None,...]).detach()
# features = model(torch.tensor(X_train, device=DEVICE, dtype=torch.float32)[:,None,...]).detach()

# %%
_, features_embedded, _, _ = decomposition.torch_pca(features, device=DEVICE, return_cpu=True)

# %%
from sklearn import manifold

tsne = manifold.TSNE(n_components=2, 
                     perplexity=80.0, 
                     early_exaggeration=12.0, 
                     learning_rate=200, 
                     n_iter=1000, 
                     n_iter_without_progress=300, 
                     min_grad_norm=1e-07, 
                     metric='euclidean', 
                     init='pca', 
                     verbose=0, 
                     random_state=None, 
                     method='barnes_hut', 
                     angle=0.5, 
                     n_jobs=-1, 
#                      square_distances='legacy'
                    )
features_embedded = tsne.fit_transform(features.cpu())

# %%
import matplotlib as mpl

# mpl.rcParams['image.cmap'] = 'Set1'
# %matplotlib notebook
plt.figure()
plt.scatter(features_embedded[:,0], features_embedded[:,1], c=labels)
# plt.scatter(features_embedded[:,0], features_embedded[:,1], c=labels[labels!=3])
# plt.scatter(features_embedded[:,0], features_embedded[:,1], c=y_val)
# plt.scatter(features_embedded[:,4], features_embedded[:,5], c=y_train)
# plt.scatter(features_embedded[:,11], features[:,43].cpu(), c=y_train)
mpl.rcParams['image.cmap'] = 'viridis'
# Out:
# <img src="data:image/png;base64,..." width="386.3666666666667">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-f587a160ecb2> in <module>
#       4 get_ipython().run_line_magic('matplotlib', 'notebook')
#       5 plt.figure()
# ----> 6 plt.scatter(features_embedded[:,0], features_embedded[:,1], c=labels)
#       7 # plt.scatter(features_embedded[:,0], features_embedded[:,1], c=labels[labels!=3])
#       8 # plt.scatter(features_embedded[:,0], features_embedded[:,1], c=y_val)
#
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3035         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    3036         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 3037     __ret = gca().scatter(
#    3038         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    3039         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/site-packages/matplotlib/pyplot.py in gca(**kwargs)
#    2499 @_copy_docstring_and_deprecators(Figure.gca)
#    2500 def gca(**kwargs):
# -> 2501     return gcf().gca(**kwargs)
#    2502
#    2503
#
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/site-packages/matplotlib/figure.py in gca(self, **kwargs)
#    1520                 "plt.subplot().")
#    1521         if self._axstack.empty():
# -> 1522             return self.add_subplot(1, 1, 1, **kwargs)
#    1523         else:
#    1524             return self._axstack()
#
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#     779             projection_class, pkw = self._process_projection_requirements(
#     780                 *args, **kwargs)
# --> 781             ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     782             key = (projection_class, pkw)
#     783         return self._add_axes_internal(ax, key)
#
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      36         self._axes_class.__init__(self, fig, [0, 0, 1, 1], **kwargs)
#      37         # This will also update the axes position.
# ---> 38         self.set_subplotspec(SubplotSpec._from_subplot_args(fig, args))
#      39
#      40     def __reduce__(self):
#
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/site-packages/matplotlib/axes/_subplots.py in set_subplotspec(self, subplotspec)
#      70         """Set the `.SubplotSpec`. instance associated with the subplot."""
#      71         self._subplotspec = subplotspec
# ---> 72         self._set_position(subplotspec.get_position(self.figure))
#      73
#      74     def get_gridspec(self):
#
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/site-packages/matplotlib/gridspec.py in get_position(self, figure, return_all)
#     741             gridspec.get_grid_positions(figure)
#     742
# --> 743         fig_bottom = fig_bottoms[rows].min()
#     744         fig_top = fig_tops[rows].max()
#     745         fig_left = fig_lefts[cols].min()
#
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/site-packages/numpy/core/_methods.py in _amin(a, axis, out, keepdims, initial, where)
#      32 def _amin(a, axis=None, out=None, keepdims=False,
#      33           initial=_NoValue, where=True):
# ---> 34     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#      35
#      36 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: float() argument must be a string or a number, not '_NoValueType'

# %%
plt.figure()
plt.imshow(features.cpu().detach(), aspect='auto', interpolation='none')
# Out:
# <img src="data:image/png;base64,..." width="791.7166666666666">

# %% [markdown]
# ## Check filters

# %%
list(model.state_dict().keys())
# Out:
# ['cnn_layers.0.weight',
#  'cnn_layers.0.bias',
#  'cnn_layers.2.weight',
#  'cnn_layers.2.bias',
#  'cnn_layers.5.weight',
#  'cnn_layers.5.bias',
#  'cnn_layers.8.weight',
#  'cnn_layers.8.bias',
#  'linear_layers.0.weight',
#  'linear_layers.0.bias',
#  'linear_layers.2.weight',
#  'linear_layers.2.bias']

# %%
layer_1 = model.state_dict()['cnn_layers.0.weight'].cpu()
layer_2 = model.state_dict()['cnn_layers.2.weight'].cpu()
layer_3 = model.state_dict()['cnn_layers.5.weight'].cpu()
layer_4 = model.state_dict()['cnn_layers.8.weight'].cpu()

plt.figure()
for ii in range(layer_1.shape[1]):
    for jj in range(layer_1.shape[0]):
        plt.subplot2grid((layer_1.shape[1],layer_1.shape[0]),(ii,jj))
        fig = plt.imshow(layer_1[jj,ii,:,:] , clim=(-0.2,0.2))
        fig.axes.get_xaxis().set_visible(False)
        fig.axes.get_yaxis().set_visible(False)

plt.figure()
for ii in range(layer_2.shape[1]):
    for jj in range(layer_2.shape[0]):
        plt.subplot2grid((layer_2.shape[1],layer_2.shape[0]),(ii,jj))
        fig = plt.imshow(layer_2[jj,ii,:,:], clim=(-.05,.05))
        fig.axes.get_xaxis().set_visible(False)
        fig.axes.get_yaxis().set_visible(False)

plt.figure()
for ii in range(16):
    for jj in range(16):
        plt.subplot2grid((16,16),(ii,jj))
        fig = plt.imshow(layer_3[jj, ii,:,:])
        fig.axes.get_xaxis().set_visible(False)
        fig.axes.get_yaxis().set_visible(False)
        
plt.figure()
for ii in range(16):
    for jj in range(16):
        plt.subplot2grid((16,16),(ii,jj))
        fig = plt.imshow(layer_4[jj, ii,:,:])
        fig.axes.get_xaxis().set_visible(False)
        fig.axes.get_yaxis().set_visible(False)
# Out:
# <img src="data:image/png;base64,..." width="386.3666666666667">
# <img src="data:image/png;base64,..." width="703.5">
# <img src="data:image/png;base64,..." width="808.4666666666666">
# <img src="data:image/png;base64,..." width="386.3666666666667">

# %%
torch.save(model.state_dict(), '/media/rich/bigSSD/Net_trainedOnAug_20211031_trainingSet_allStat_simCLR.pth')

# %%
# model = Net()
# model.load_state_dict(torch.load('test_save.pth'))
# model.eval()
