# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import sys
import os
import copy
import pathlib

import numpy as np
import matplotlib.pyplot as plt
import scipy

import torch
import torchvision
import torchvision.transforms as transforms

# for creating validation set
from sklearn.model_selection import train_test_split

# %matplotlib notebook
# %matplotlib notebook
# %matplotlib inline
# %matplotlib qt

# %%
import sys

sys.path.append('/media/rich/Home_Linux_partition/github_repos/')

# %load_ext autoreload
# %autoreload 2
from basic_neural_processing_modules import torch_helpers, decomposition
from GCaMP_ROI_classifier.old_stuff import util, models, training_simCLR, augmentation

# %% [markdown]
# ## Import training data

# %%
import pickle

with open('/media/rich/bigSSD/for_Josh/GCAMP_ROI_Classifier_data/label_data/all_stat_files_20211022.pkl', 'rb') as file:
    statFiles_scraped = pickle.load(file)

# %%
keys_toDelete = [
    '\\\\research.files.med.harvard.edu\\Neurobio\\MICROSCOPE\\Rich\\data\\res2p\\scanimage data\\for Loic\\16x_analysis20200514\\Suite2p and MC for denoised movie\\suite2p\\plane0\\stat.npy',
    '\\\\research.files.med.harvard.edu\\Neurobio\\MICROSCOPE\\Rich\\data\\res2p\\scanimage data\\round 4 experiments\\mouse 6.28\\20201102\\suite2p_accidentally_run_on_everything\\plane0\\stat.npy',
    '\\\\research.files.med.harvard.edu\\Neurobio\\MICROSCOPE\\Rich\\data\\res2p\\scanimage data\\for Loic\\20x\\mouse 2.5\\20200306\\suite2p attemp 2 _tau 1_5\\plane0\\stat.npy',
    '\\\\research.files.med.harvard.edu\\Neurobio\\MICROSCOPE\\Rich\\data\\res2p\\scanimage data\\for Loic\\20x\\mouse 2.5\\20200306\\suite2p attempt 1 _tau 2\\plane0\\stat.npy',
    '\\\\research.files.med.harvard.edu\\Neurobio\\MICROSCOPE\\Rich\\data\\res2p\\scanimage data\\for Loic\\20x\\mouse 2.5\\20200306\\suite2p attempt 3 _tau 1\\plane0\\stat.npy',
    '\\\\research.files.med.harvard.edu\\Neurobio\\MICROSCOPE\\Rich\\data\\res2p\\scanimage data\\for Loic\\AAV\\oldBMIrampExp_20191112_mouse1013A\\ROI extraction\\suite2p\\plane0\\stat.npy',
]
for key in keys_toDelete:
    del statFiles_scraped[key]

# %%
sf_list = util.convert_multiple_stat_files(statFiles_dict=statFiles_scraped, out_height_width=[36,36], max_footprint_width=901, plot_pref=False)

images_all = np.concatenate(sf_list, axis=0)

images_all.shape
# Out:
# (217802, 36, 36)

# %%
images_all_norm = (images_all / np.sum(images_all, axis=(1,2), keepdims=True)) * 255

# %%
# create validation set
# X_train, X_val, y_train, y_val = train_test_split(images[:], labels[:], test_size = 0.15)
X_train, X_val, y_train, y_val = train_test_split(images_all_norm, np.arange(images_all.shape[0]), test_size = 0.15)
(X_train.shape, y_train.shape), (X_val.shape, y_val.shape)
# Out:
# (((185131, 36, 36), (185131,)), ((32671, 36, 36), (32671,)))

# %%
dir_folders = r'/media/rich/bigSSD/for_Josh/GCAMP_ROI_Classifier_data/label_data'
folders = [r'mouse 6_28 _ day 20200903/',
             r'mouse6_28 _ day20200815/']
fileNames_statFiles = [r'stat.npy']*len(folders)
paths_statFiles = [pathlib.Path(dir_folders) / folders[ii] / fileNames_statFiles[ii] for ii in range(len(folders))]

statFile_import_kwargs = {'out_height_width': [36,36],
                          'max_footprint_width': 241,
                          'plot_pref':True}

sf_all = util.import_multiple_stat_files(   paths_statFiles=paths_statFiles,
                                        fileNames_statFiles=fileNames_statFiles,
                                        out_height_width=[36,36],
                                        max_footprint_width=241,
                                        plot_pref=True)
images_labeled = np.concatenate(sf_all, axis=0) *255
print(f'concatenated images shape: {images_labeled.shape}')

fileNames_labelFiles = ['labels_posthoc_filledIn_allCells.npy',
             'labels_posthoc_all.npy']
paths_labelFiles = [pathlib.Path(dir_folders) / folders[ii] / fileNames_labelFiles[ii] for ii in range(len(folders))]

labels_all = util.import_multiple_label_files(paths_labelFiles=paths_labelFiles,
                                       plot_pref=True)
labels = np.concatenate(labels_all)

assert np.alltrue([sf_all[ii].shape[0] == labels_all[ii].shape[0] for ii in range(len(sf_all))]) , 'num images in stat files does not correspond to num labels'
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">
# <img src="data:image/png;base64,..." width="697.5833333333334">
# concatenated images shape: (9715, 36, 36)
# <img src="data:image/png;base64,..." width="697.5833333333334">
# <img src="data:image/png;base64,..." width="697.5833333333334">

# %% [markdown]
# ## Balance classes of inputs

# %% [raw]
# duplicates = 1
#
# images_dup = np.tile(images , (duplicates , 1 , 1))
# labels_dup = np.tile(labels , (duplicates))
#
# print(images_dup.shape)
# print(labels_dup.shape)
#
# numToGetTo = np.sum(labels_dup==0)
# print(numToGetTo)
# for ii in np.array([1,4,5]):
# #     idxToDelete = np.cumsum(labels_dup==ii) <= (np.sum(labels_dup==ii) - numToGetTo)
#     if ii==5:
#         numToGetTo = np.sum(labels_dup==0)/2
#     else:
#         numToGetTo = np.sum(labels_dup==0)
#
#     idxToDelete = (np.cumsum(labels_dup==ii) * (labels_dup==ii)) > numToGetTo
#     images_dup = images_dup[idxToDelete==0,:,:]
#     labels_dup = labels_dup[idxToDelete==0]
#
#
# print(np.sum(labels_dup==0))
# print(np.sum(labels_dup==1))
# print(np.sum(labels_dup==4))
# print(np.sum(labels_dup==5))
# print(images_dup.shape)
# print(labels_dup.shape)

# %% [raw]
# # create validation set
# # X_train, X_val, y_train, y_val = train_test_split(images[:], labels[:], test_size = 0.15)
# X_train, X_val, y_train, y_val = train_test_split(images_all[:], labels[:], test_size = 0.15)
# (X_train.shape, y_train.shape), (X_val.shape, y_val.shape)

# %% [raw]
# plt.figure()
# plt.hist(labels_dup, 20);

# %% [markdown]
# ## Define augmentation pipeline

# %%
import torchvision.transforms    

transforms = torch.nn.Sequential(
#     torchvision.transforms.RandomHorizontalFlip(p=0.5),
    
#     torchvision.transforms.GaussianBlur(kernel_size=5,
#                                         sigma=(0.0001, 0.5)),
    
#     torchvision.transforms.RandomPerspective(distortion_scale=0.4, 
#                                              p=0.5, 
#                                              interpolation=torchvision.transforms.InterpolationMode.BILINEAR, 
#                                              fill=0),
#     torchvision.transforms.RandomAffine(
#                                         degrees=(-180,180),
#                                         translate=(0.3, 0.3),
#                                         scale=(0.7, 1.7), 
#                                         shear=(-30, 30, -30, 30), 
#                                         interpolation=torchvision.transforms.InterpolationMode.BILINEAR, 
#                                         fill=0, 
#                                         fillcolor=None, 
#                                         resample=None),
    
#     augmentation.AddPoissonNoise(   level_bounds=(0,0.7),
#                                     prob=1),

#     augmentation.AddGaussianNoise(  mean=0, 
#                                     std=0.4,
#                                     prob=1),
)
scripted_transforms = torch.jit.script(transforms)
# scripted_transforms = transforms


dataset_train = util.dataset_simCLR(torch.tensor(X_train), 
                                    y_train, 
                                    n_transforms=2, 
                                    transform=scripted_transforms,
                                    DEVICE='cpu',
                                    dtype_X=torch.float32,
                                    dtype_y=torch.int64 )

dataloader_train = torch.utils.data.DataLoader( dataset_train,
                                                batch_size=1024,
            #                                     sampler=sampler,
                                                shuffle=True,
                                                drop_last=True,
                                                pin_memory=False,
                                                num_workers=32,
                                                prefetch_factor=3,
                                                persistent_workers=True,
                                                )

# dataset_val = util.dataset_simCLR(torch.tensor(X_val), 
#                                     y_val, 
#                                     n_transforms=2, 
#                                     transform=scripted_transforms,
#                                     DEVICE='cpu',
#                                     dtype_X=torch.float32,
#                                     dtype_y=torch.int64 )

# dataloader_val = torch.utils.data.DataLoader(   dataset_val,
#                                                 batch_size=128,
#             #                                     sampler=sampler,
#                                                 shuffle=True,
#                                                 drop_last=True,
#                                                 pin_memory=True,
#                                                 num_workers=0,
#                                                 )

# %% [raw]
# for ii, im in enumerate(images_all_norm):
#     plt.figure()
#     plt.imshow(im)
#     if ii > 1:
#         break

# %% [raw]
# import time
#
# %matplotlib notebook
# tic=time.time()
# for ii, im in enumerate(dataset_train):
# #     for jj in range(im[0])
#     print(time.time() - tic)
#     tic = time.time()
# #     print((im[0][0]).shape)
#     fig, axs = plt.subplots(len(im[0]))
#     for jj, ax in enumerate(axs):
#         ax.imshow(im[0][jj].cpu().squeeze())
#     if ii > 2:
#         break

# %% [markdown]
# ## Train

# %%
DEVICE = torch_helpers.set_device(use_GPU=True)
# Out:
# device: 'cuda'

# %%
from torch.nn import CrossEntropyLoss
from torch.optim import Adam

model = models.LeNet1(dropout_prob=0.3, momentum_val=0, n_output_features=128)
model.train()
criterion = CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=1e-3, weight_decay=0.05)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer,
                                                   gamma=1-0.0005,
#                                                    gamma=1,
                                                  )
val_obj = training_simCLR.validation_Obj(   X_val,
                                            y_val,
                                            model,
                                            criterion,
                                            DEVICE=DEVICE,
                                            dtype_X=torch.float32,
                                            dtype_y=torch.int64)

model.to(DEVICE)
criterion = criterion.to(DEVICE)

losses_train, losses_val, val_accs = [], [np.nan], []

# %%
n_epochs=300000
for epoch in range(n_epochs):
    print(f'epoch: {epoch}')
    training_simCLR.epoch_step( dataloader_train, 
                                model, 
                                optimizer, 
                                criterion, 
                                scheduler=scheduler, 
                                temperature=0.5,
                                loss_rolling_train=losses_train, 
                                device=DEVICE, 
                                do_validation=False,
                                validation_Object=val_obj,
                                loss_rolling_val=losses_val,
                                verbose=2,
                                verbose_update_period=10,
                               )
# Out:
# epoch: 0
# Iter: 0/180, loss_train: 7.4691, loss_val: nan, lr: 0.0009995
# Iter: 10/180, loss_train: 6.5399, loss_val: nan, lr: 0.00099451
# Iter: 20/180, loss_train: 6.1352, loss_val: nan, lr: 0.00098955
# Iter: 30/180, loss_train: 6.0338, loss_val: nan, lr: 0.00098462
# Iter: 40/180, loss_train: 5.9491, loss_val: nan, lr: 0.0009797
# Iter: 50/180, loss_train: 5.8904, loss_val: nan, lr: 0.00097482
# Iter: 60/180, loss_train: 5.8592, loss_val: nan, lr: 0.00096995
# Iter: 70/180, loss_train: 5.843, loss_val: nan, lr: 0.00096511
# Iter: 80/180, loss_train: 5.8336, loss_val: nan, lr: 0.0009603
# Iter: 90/180, loss_train: 5.8016, loss_val: nan, lr: 0.00095551
# Iter: 100/180, loss_train: 5.8395, loss_val: nan, lr: 0.00095074
# Iter: 110/180, loss_train: 5.7992, loss_val: nan, lr: 0.000946
# Iter: 120/180, loss_train: 5.8208, loss_val: nan, lr: 0.00094128
# Iter: 130/180, loss_train: 5.7821, loss_val: nan, lr: 0.00093658
# Iter: 140/180, loss_train: 5.7782, loss_val: nan, lr: 0.00093191
# Iter: 150/180, loss_train: 5.7776, loss_val: nan, lr: 0.00092726
# Iter: 160/180, loss_train: 5.7696, loss_val: nan, lr: 0.00092264
# Iter: 170/180, loss_train: 5.7672, loss_val: nan, lr: 0.00091803
# epoch: 1
# Iter: 0/180, loss_train: 5.7834, loss_val: nan, lr: 0.00091345
# Iter: 10/180, loss_train: 5.7567, loss_val: nan, lr: 0.0009089
# Iter: 20/180, loss_train: 5.7808, loss_val: nan, lr: 0.00090436
# Iter: 30/180, loss_train: 5.7634, loss_val: nan, lr: 0.00089985
# Iter: 40/180, loss_train: 5.7567, loss_val: nan, lr: 0.00089536
# Iter: 50/180, loss_train: 5.7555, loss_val: nan, lr: 0.00089089
# Iter: 60/180, loss_train: 5.7478, loss_val: nan, lr: 0.00088645
# Iter: 70/180, loss_train: 5.7621, loss_val: nan, lr: 0.00088203
# Iter: 80/180, loss_train: 5.7454, loss_val: nan, lr: 0.00087763
# Iter: 90/180, loss_train: 5.755, loss_val: nan, lr: 0.00087325
# Iter: 100/180, loss_train: 5.7504, loss_val: nan, lr: 0.00086889
# Iter: 110/180, loss_train: 5.7739, loss_val: nan, lr: 0.00086456
# Iter: 120/180, loss_train: 5.7364, loss_val: nan, lr: 0.00086025
# Iter: 130/180, loss_train: 5.7374, loss_val: nan, lr: 0.00085595
# Iter: 140/180, loss_train: 5.7372, loss_val: nan, lr: 0.00085168
# Iter: 150/180, loss_train: 5.7367, loss_val: nan, lr: 0.00084743
# Iter: 160/180, loss_train: 5.7642, loss_val: nan, lr: 0.00084321
# Iter: 170/180, loss_train: 5.7344, loss_val: nan, lr: 0.000839
# epoch: 2
# Iter: 0/180, loss_train: 5.7353, loss_val: nan, lr: 0.00083481
# Iter: 10/180, loss_train: 5.7348, loss_val: nan, lr: 0.00083065
# Iter: 20/180, loss_train: 5.7239, loss_val: nan, lr: 0.00082651
# Iter: 30/180, loss_train: 5.7223, loss_val: nan, lr: 0.00082238
# Iter: 40/180, loss_train: 5.7346, loss_val: nan, lr: 0.00081828
# Iter: 50/180, loss_train: 5.7546, loss_val: nan, lr: 0.0008142
# Iter: 60/180, loss_train: 5.7271, loss_val: nan, lr: 0.00081014
# Iter: 70/180, loss_train: 5.7202, loss_val: nan, lr: 0.00080609
# Iter: 80/180, loss_train: 5.7327, loss_val: nan, lr: 0.00080207
# Iter: 90/180, loss_train: 5.7273, loss_val: nan, lr: 0.00079807
# Iter: 100/180, loss_train: 5.7478, loss_val: nan, lr: 0.00079409
# Iter: 110/180, loss_train: 5.7267, loss_val: nan, lr: 0.00079013
# Iter: 120/180, loss_train: 5.7285, loss_val: nan, lr: 0.00078619
# Iter: 130/180, loss_train: 5.726, loss_val: nan, lr: 0.00078227
# Iter: 140/180, loss_train: 5.7355, loss_val: nan, lr: 0.00077836
# Iter: 150/180, loss_train: 5.7421, loss_val: nan, lr: 0.00077448
# Iter: 160/180, loss_train: 5.7288, loss_val: nan, lr: 0.00077062
# Iter: 170/180, loss_train: 5.7185, loss_val: nan, lr: 0.00076677
# epoch: 3
# Iter: 0/180, loss_train: 5.7316, loss_val: nan, lr: 0.00076295
# Iter: 10/180, loss_train: 5.7235, loss_val: nan, lr: 0.00075914
# Iter: 20/180, loss_train: 5.7221, loss_val: nan, lr: 0.00075535
# Iter: 30/180, loss_train: 5.7196, loss_val: nan, lr: 0.00075158
# Iter: 40/180, loss_train: 5.7189, loss_val: nan, lr: 0.00074784
# Iter: 50/180, loss_train: 5.7303, loss_val: nan, lr: 0.0007441
# Iter: 60/180, loss_train: 5.7195, loss_val: nan, lr: 0.00074039
# Iter: 70/180, loss_train: 5.7275, loss_val: nan, lr: 0.0007367
# Iter: 80/180, loss_train: 5.7245, loss_val: nan, lr: 0.00073302
# Iter: 90/180, loss_train: 5.7313, loss_val: nan, lr: 0.00072937
# Iter: 100/180, loss_train: 5.7218, loss_val: nan, lr: 0.00072573
# Iter: 110/180, loss_train: 5.7231, loss_val: nan, lr: 0.00072211
# Iter: 120/180, loss_train: 5.7375, loss_val: nan, lr: 0.0007185
# Iter: 130/180, loss_train: 5.7202, loss_val: nan, lr: 0.00071492
# Iter: 140/180, loss_train: 5.7243, loss_val: nan, lr: 0.00071135
# Iter: 150/180, loss_train: 5.7127, loss_val: nan, lr: 0.00070781
# Iter: 160/180, loss_train: 5.7297, loss_val: nan, lr: 0.00070427
# Iter: 170/180, loss_train: 5.7244, loss_val: nan, lr: 0.00070076
# epoch: 4
# Iter: 0/180, loss_train: 5.7237, loss_val: nan, lr: 0.00069726
# Iter: 10/180, loss_train: 5.7324, loss_val: nan, lr: 0.00069379
# Iter: 20/180, loss_train: 5.7235, loss_val: nan, lr: 0.00069033
# Iter: 30/180, loss_train: 5.7217, loss_val: nan, lr: 0.00068688
# Iter: 40/180, loss_train: 5.7135, loss_val: nan, lr: 0.00068345
# Iter: 50/180, loss_train: 5.7233, loss_val: nan, lr: 0.00068004
# Iter: 60/180, loss_train: 5.7258, loss_val: nan, lr: 0.00067665
# Iter: 70/180, loss_train: 5.7108, loss_val: nan, lr: 0.00067328
# Iter: 80/180, loss_train: 5.7332, loss_val: nan, lr: 0.00066992
# Iter: 90/180, loss_train: 5.7308, loss_val: nan, lr: 0.00066658
# Iter: 100/180, loss_train: 5.7138, loss_val: nan, lr: 0.00066325
# Iter: 110/180, loss_train: 5.7206, loss_val: nan, lr: 0.00065994
# Iter: 120/180, loss_train: 5.7122, loss_val: nan, lr: 0.00065665
# Iter: 130/180, loss_train: 5.7141, loss_val: nan, lr: 0.00065337
# Iter: 140/180, loss_train: 5.7203, loss_val: nan, lr: 0.00065011
# Iter: 150/180, loss_train: 5.7171, loss_val: nan, lr: 0.00064687
# Iter: 160/180, loss_train: 5.7073, loss_val: nan, lr: 0.00064364
# Iter: 170/180, loss_train: 5.7126, loss_val: nan, lr: 0.00064043
# epoch: 5
# Iter: 0/180, loss_train: 5.7113, loss_val: nan, lr: 0.00063724
# Iter: 10/180, loss_train: 5.7119, loss_val: nan, lr: 0.00063406
# Iter: 20/180, loss_train: 5.7374, loss_val: nan, lr: 0.0006309
# Iter: 30/180, loss_train: 5.7406, loss_val: nan, lr: 0.00062775
# Iter: 40/180, loss_train: 5.7181, loss_val: nan, lr: 0.00062462
# Iter: 50/180, loss_train: 5.7172, loss_val: nan, lr: 0.0006215
# Iter: 60/180, loss_train: 5.7123, loss_val: nan, lr: 0.0006184
# Iter: 70/180, loss_train: 5.712, loss_val: nan, lr: 0.00061531
# Iter: 80/180, loss_train: 5.7099, loss_val: nan, lr: 0.00061225
# Iter: 90/180, loss_train: 5.7142, loss_val: nan, lr: 0.00060919
# Iter: 100/180, loss_train: 5.7312, loss_val: nan, lr: 0.00060615
# Iter: 110/180, loss_train: 5.7187, loss_val: nan, lr: 0.00060313
# Iter: 120/180, loss_train: 5.7096, loss_val: nan, lr: 0.00060012
# Iter: 130/180, loss_train: 5.7098, loss_val: nan, lr: 0.00059712
# Iter: 140/180, loss_train: 5.7034, loss_val: nan, lr: 0.00059415
# Iter: 150/180, loss_train: 5.7307, loss_val: nan, lr: 0.00059118
# Iter: 160/180, loss_train: 5.7178, loss_val: nan, lr: 0.00058823
# Iter: 170/180, loss_train: 5.7046, loss_val: nan, lr: 0.0005853
# epoch: 6
# Iter: 0/180, loss_train: 5.7149, loss_val: nan, lr: 0.00058238
# Iter: 10/180, loss_train: 5.7149, loss_val: nan, lr: 0.00057947
# Iter: 20/180, loss_train: 5.707, loss_val: nan, lr: 0.00057658
# Iter: 30/180, loss_train: 5.7095, loss_val: nan, lr: 0.00057371
# Iter: 40/180, loss_train: 5.7157, loss_val: nan, lr: 0.00057084
# Iter: 50/180, loss_train: 5.7156, loss_val: nan, lr: 0.000568
# Iter: 60/180, loss_train: 5.7111, loss_val: nan, lr: 0.00056516
# Iter: 70/180, loss_train: 5.7246, loss_val: nan, lr: 0.00056234
# Iter: 80/180, loss_train: 5.7108, loss_val: nan, lr: 0.00055954
# Iter: 90/180, loss_train: 5.7136, loss_val: nan, lr: 0.00055675
# Iter: 100/180, loss_train: 5.7032, loss_val: nan, lr: 0.00055397
# Iter: 110/180, loss_train: 5.7136, loss_val: nan, lr: 0.0005512
# Iter: 120/180, loss_train: 5.7204, loss_val: nan, lr: 0.00054845
# Iter: 130/180, loss_train: 5.7082, loss_val: nan, lr: 0.00054572
# Iter: 140/180, loss_train: 5.7075, loss_val: nan, lr: 0.000543
# Iter: 150/180, loss_train: 5.7168, loss_val: nan, lr: 0.00054029
# Iter: 160/180, loss_train: 5.7105, loss_val: nan, lr: 0.00053759
# Iter: 170/180, loss_train: 5.7117, loss_val: nan, lr: 0.00053491
# epoch: 7
# Iter: 0/180, loss_train: 5.7088, loss_val: nan, lr: 0.00053224
# Iter: 10/180, loss_train: 5.7056, loss_val: nan, lr: 0.00052959
# Iter: 20/180, loss_train: 5.7109, loss_val: nan, lr: 0.00052694
# Iter: 30/180, loss_train: 5.7096, loss_val: nan, lr: 0.00052432
# Iter: 40/180, loss_train: 5.7149, loss_val: nan, lr: 0.0005217
# Iter: 50/180, loss_train: 5.7157, loss_val: nan, lr: 0.0005191
# Iter: 60/180, loss_train: 5.7167, loss_val: nan, lr: 0.00051651
# Iter: 70/180, loss_train: 5.7113, loss_val: nan, lr: 0.00051393
# Iter: 80/180, loss_train: 5.7079, loss_val: nan, lr: 0.00051137
# Iter: 90/180, loss_train: 5.706, loss_val: nan, lr: 0.00050882
# Iter: 100/180, loss_train: 5.7115, loss_val: nan, lr: 0.00050628
# Iter: 110/180, loss_train: 5.7017, loss_val: nan, lr: 0.00050375
# Iter: 120/180, loss_train: 5.7344, loss_val: nan, lr: 0.00050124
# Iter: 130/180, loss_train: 5.7172, loss_val: nan, lr: 0.00049874
# Iter: 140/180, loss_train: 5.7097, loss_val: nan, lr: 0.00049625
# Iter: 150/180, loss_train: 5.7044, loss_val: nan, lr: 0.00049377
# Iter: 160/180, loss_train: 5.7119, loss_val: nan, lr: 0.00049131
# Iter: 170/180, loss_train: 5.7044, loss_val: nan, lr: 0.00048886
# epoch: 8
# Iter: 0/180, loss_train: 5.7052, loss_val: nan, lr: 0.00048642
# Iter: 10/180, loss_train: 5.7117, loss_val: nan, lr: 0.00048399
# Iter: 20/180, loss_train: 5.7032, loss_val: nan, lr: 0.00048158
# Iter: 30/180, loss_train: 5.7058, loss_val: nan, lr: 0.00047918
# Iter: 40/180, loss_train: 5.7046, loss_val: nan, lr: 0.00047679
# Iter: 50/180, loss_train: 5.7126, loss_val: nan, lr: 0.00047441
# Iter: 60/180, loss_train: 5.7074, loss_val: nan, lr: 0.00047204
# Iter: 70/180, loss_train: 5.7074, loss_val: nan, lr: 0.00046969
# Iter: 80/180, loss_train: 5.7081, loss_val: nan, lr: 0.00046734
# Iter: 90/180, loss_train: 5.7113, loss_val: nan, lr: 0.00046501
# Iter: 100/180, loss_train: 5.7015, loss_val: nan, lr: 0.00046269
# Iter: 110/180, loss_train: 5.7036, loss_val: nan, lr: 0.00046038
# Iter: 120/180, loss_train: 5.7131, loss_val: nan, lr: 0.00045809
# Iter: 130/180, loss_train: 5.6986, loss_val: nan, lr: 0.0004558
# Iter: 140/180, loss_train: 5.7048, loss_val: nan, lr: 0.00045353
# Iter: 150/180, loss_train: 5.7063, loss_val: nan, lr: 0.00045127
# Iter: 160/180, loss_train: 5.7045, loss_val: nan, lr: 0.00044901
# Iter: 170/180, loss_train: 5.7029, loss_val: nan, lr: 0.00044677
# epoch: 9
# Iter: 0/180, loss_train: 5.7103, loss_val: nan, lr: 0.00044455
# Iter: 10/180, loss_train: 5.7156, loss_val: nan, lr: 0.00044233
# Iter: 20/180, loss_train: 5.704, loss_val: nan, lr: 0.00044012
# Iter: 30/180, loss_train: 5.7117, loss_val: nan, lr: 0.00043793
# Iter: 40/180, loss_train: 5.7078, loss_val: nan, lr: 0.00043574
# Iter: 50/180, loss_train: 5.7072, loss_val: nan, lr: 0.00043357
# Iter: 60/180, loss_train: 5.7147, loss_val: nan, lr: 0.0004314
# Iter: 70/180, loss_train: 5.7173, loss_val: nan, lr: 0.00042925
# Iter: 80/180, loss_train: 5.709, loss_val: nan, lr: 0.00042711
# Iter: 90/180, loss_train: 5.7071, loss_val: nan, lr: 0.00042498
# Iter: 100/180, loss_train: 5.7031, loss_val: nan, lr: 0.00042286
# Iter: 110/180, loss_train: 5.7049, loss_val: nan, lr: 0.00042075
# Iter: 120/180, loss_train: 5.7149, loss_val: nan, lr: 0.00041865
# Iter: 130/180, loss_train: 5.7013, loss_val: nan, lr: 0.00041656
# Iter: 140/180, loss_train: 5.7045, loss_val: nan, lr: 0.00041448
# Iter: 150/180, loss_train: 5.703, loss_val: nan, lr: 0.00041242
# Iter: 160/180, loss_train: 5.7066, loss_val: nan, lr: 0.00041036
# Iter: 170/180, loss_train: 5.704, loss_val: nan, lr: 0.00040831
# epoch: 10
# Iter: 0/180, loss_train: 5.7018, loss_val: nan, lr: 0.00040627
# Iter: 10/180, loss_train: 5.708, loss_val: nan, lr: 0.00040425
# Iter: 20/180, loss_train: 5.7116, loss_val: nan, lr: 0.00040223
# Iter: 30/180, loss_train: 5.7004, loss_val: nan, lr: 0.00040022
# Iter: 40/180, loss_train: 5.7025, loss_val: nan, lr: 0.00039823
# Iter: 50/180, loss_train: 5.696, loss_val: nan, lr: 0.00039624
# Iter: 60/180, loss_train: 5.7017, loss_val: nan, lr: 0.00039426
# Iter: 70/180, loss_train: 5.6983, loss_val: nan, lr: 0.0003923
# Iter: 80/180, loss_train: 5.7041, loss_val: nan, lr: 0.00039034
# Iter: 90/180, loss_train: 5.7017, loss_val: nan, lr: 0.00038839
# Iter: 100/180, loss_train: 5.7055, loss_val: nan, lr: 0.00038646
# Iter: 110/180, loss_train: 5.7012, loss_val: nan, lr: 0.00038453
# Iter: 120/180, loss_train: 5.7017, loss_val: nan, lr: 0.00038261
# Iter: 130/180, loss_train: 5.7146, loss_val: nan, lr: 0.0003807
# Iter: 140/180, loss_train: 5.7013, loss_val: nan, lr: 0.0003788
# Iter: 150/180, loss_train: 5.7002, loss_val: nan, lr: 0.00037691
# Iter: 160/180, loss_train: 5.7054, loss_val: nan, lr: 0.00037503
# Iter: 170/180, loss_train: 5.7035, loss_val: nan, lr: 0.00037316
# epoch: 11
# Iter: 0/180, loss_train: 5.7031, loss_val: nan, lr: 0.0003713
# Iter: 10/180, loss_train: 5.7083, loss_val: nan, lr: 0.00036945
# Iter: 20/180, loss_train: 5.6996, loss_val: nan, lr: 0.0003676
# Iter: 30/180, loss_train: 5.7035, loss_val: nan, lr: 0.00036577
# Iter: 40/180, loss_train: 5.7058, loss_val: nan, lr: 0.00036394
# Iter: 50/180, loss_train: 5.7098, loss_val: nan, lr: 0.00036213
# Iter: 60/180, loss_train: 5.701, loss_val: nan, lr: 0.00036032
# Iter: 70/180, loss_train: 5.7025, loss_val: nan, lr: 0.00035853
# Iter: 80/180, loss_train: 5.6987, loss_val: nan, lr: 0.00035674
# Iter: 90/180, loss_train: 5.7066, loss_val: nan, lr: 0.00035496
# Iter: 100/180, loss_train: 5.7034, loss_val: nan, lr: 0.00035319
# Iter: 110/180, loss_train: 5.6958, loss_val: nan, lr: 0.00035142
# Iter: 120/180, loss_train: 5.7117, loss_val: nan, lr: 0.00034967
# Iter: 130/180, loss_train: 5.7021, loss_val: nan, lr: 0.00034793
# Iter: 140/180, loss_train: 5.7036, loss_val: nan, lr: 0.00034619
# Iter: 150/180, loss_train: 5.7005, loss_val: nan, lr: 0.00034446
# Iter: 160/180, loss_train: 5.7044, loss_val: nan, lr: 0.00034275
# Iter: 170/180, loss_train: 5.7041, loss_val: nan, lr: 0.00034104
# epoch: 12
# Iter: 0/180, loss_train: 5.7022, loss_val: nan, lr: 0.00033933
# Iter: 10/180, loss_train: 5.7006, loss_val: nan, lr: 0.00033764
# Iter: 20/180, loss_train: 5.6987, loss_val: nan, lr: 0.00033596
# Iter: 30/180, loss_train: 5.7053, loss_val: nan, lr: 0.00033428
# Iter: 40/180, loss_train: 5.6981, loss_val: nan, lr: 0.00033261
# Iter: 50/180, loss_train: 5.7011, loss_val: nan, lr: 0.00033095
# Iter: 60/180, loss_train: 5.6981, loss_val: nan, lr: 0.0003293
# Iter: 70/180, loss_train: 5.7005, loss_val: nan, lr: 0.00032766
# Iter: 80/180, loss_train: 5.6961, loss_val: nan, lr: 0.00032603
# Iter: 90/180, loss_train: 5.7, loss_val: nan, lr: 0.0003244
# Iter: 100/180, loss_train: 5.7102, loss_val: nan, lr: 0.00032278
# Iter: 110/180, loss_train: 5.7108, loss_val: nan, lr: 0.00032117
# Iter: 120/180, loss_train: 5.6998, loss_val: nan, lr: 0.00031957
# Iter: 130/180, loss_train: 5.6986, loss_val: nan, lr: 0.00031797
# Iter: 140/180, loss_train: 5.6933, loss_val: nan, lr: 0.00031639
# Iter: 150/180, loss_train: 5.6956, loss_val: nan, lr: 0.00031481
# Iter: 160/180, loss_train: 5.6955, loss_val: nan, lr: 0.00031324
# Iter: 170/180, loss_train: 5.7023, loss_val: nan, lr: 0.00031168
# epoch: 13
# Iter: 0/180, loss_train: 5.697, loss_val: nan, lr: 0.00031012
# Iter: 10/180, loss_train: 5.6995, loss_val: nan, lr: 0.00030857
# Iter: 20/180, loss_train: 5.7025, loss_val: nan, lr: 0.00030703
# Iter: 30/180, loss_train: 5.697, loss_val: nan, lr: 0.0003055
# Iter: 40/180, loss_train: 5.7067, loss_val: nan, lr: 0.00030398
# Iter: 50/180, loss_train: 5.6958, loss_val: nan, lr: 0.00030246
# Iter: 60/180, loss_train: 5.6997, loss_val: nan, lr: 0.00030095
# Iter: 70/180, loss_train: 5.6952, loss_val: nan, lr: 0.00029945
# Iter: 80/180, loss_train: 5.7015, loss_val: nan, lr: 0.00029796
# Iter: 90/180, loss_train: 5.6976, loss_val: nan, lr: 0.00029647
# Iter: 100/180, loss_train: 5.6999, loss_val: nan, lr: 0.00029499
# Iter: 110/180, loss_train: 5.6957, loss_val: nan, lr: 0.00029352
# Iter: 120/180, loss_train: 5.6953, loss_val: nan, lr: 0.00029206
# Iter: 130/180, loss_train: 5.6923, loss_val: nan, lr: 0.0002906
# Iter: 140/180, loss_train: 5.7011, loss_val: nan, lr: 0.00028915
# Iter: 150/180, loss_train: 5.699, loss_val: nan, lr: 0.00028771
# Iter: 160/180, loss_train: 5.6973, loss_val: nan, lr: 0.00028627
# Iter: 170/180, loss_train: 5.6986, loss_val: nan, lr: 0.00028484
# epoch: 14
# Iter: 0/180, loss_train: 5.6963, loss_val: nan, lr: 0.00028342
# Iter: 10/180, loss_train: 5.697, loss_val: nan, lr: 0.00028201
# Iter: 20/180, loss_train: 5.6917, loss_val: nan, lr: 0.0002806
# Iter: 30/180, loss_train: 5.6956, loss_val: nan, lr: 0.0002792
# Iter: 40/180, loss_train: 5.6976, loss_val: nan, lr: 0.00027781
# Iter: 50/180, loss_train: 5.698, loss_val: nan, lr: 0.00027642
# Iter: 60/180, loss_train: 5.7023, loss_val: nan, lr: 0.00027504
# Iter: 70/180, loss_train: 5.712, loss_val: nan, lr: 0.00027367
# Iter: 80/180, loss_train: 5.6969, loss_val: nan, lr: 0.00027231
# Iter: 90/180, loss_train: 5.6906, loss_val: nan, lr: 0.00027095
# Iter: 100/180, loss_train: 5.6956, loss_val: nan, lr: 0.0002696
# Iter: 110/180, loss_train: 5.6938, loss_val: nan, lr: 0.00026825
# Iter: 120/180, loss_train: 5.6975, loss_val: nan, lr: 0.00026691
# Iter: 130/180, loss_train: 5.693, loss_val: nan, lr: 0.00026558
# Iter: 140/180, loss_train: 5.7002, loss_val: nan, lr: 0.00026426
# Iter: 150/180, loss_train: 5.6945, loss_val: nan, lr: 0.00026294
# Iter: 160/180, loss_train: 5.7048, loss_val: nan, lr: 0.00026163
# Iter: 170/180, loss_train: 5.6969, loss_val: nan, lr: 0.00026032
# epoch: 15
# Iter: 0/180, loss_train: 5.692, loss_val: nan, lr: 0.00025902
# Iter: 10/180, loss_train: 5.7005, loss_val: nan, lr: 0.00025773
# Iter: 20/180, loss_train: 5.6991, loss_val: nan, lr: 0.00025645
# Iter: 30/180, loss_train: 5.6981, loss_val: nan, lr: 0.00025517
# Iter: 40/180, loss_train: 5.6913, loss_val: nan, lr: 0.00025389
# Iter: 50/180, loss_train: 5.7038, loss_val: nan, lr: 0.00025263
# Iter: 60/180, loss_train: 5.6924, loss_val: nan, lr: 0.00025137
# Iter: 70/180, loss_train: 5.6922, loss_val: nan, lr: 0.00025011
# Iter: 80/180, loss_train: 5.6958, loss_val: nan, lr: 0.00024886
# Iter: 90/180, loss_train: 5.6978, loss_val: nan, lr: 0.00024762
# Iter: 100/180, loss_train: 5.7004, loss_val: nan, lr: 0.00024639
# Iter: 110/180, loss_train: 5.6952, loss_val: nan, lr: 0.00024516
# Iter: 120/180, loss_train: 5.6973, loss_val: nan, lr: 0.00024394
# Iter: 130/180, loss_train: 5.6946, loss_val: nan, lr: 0.00024272
# Iter: 140/180, loss_train: 5.6943, loss_val: nan, lr: 0.00024151
# Iter: 150/180, loss_train: 5.6975, loss_val: nan, lr: 0.0002403
# Iter: 160/180, loss_train: 5.6977, loss_val: nan, lr: 0.0002391
# Iter: 170/180, loss_train: 5.694, loss_val: nan, lr: 0.00023791
# epoch: 16
# Iter: 0/180, loss_train: 5.6938, loss_val: nan, lr: 0.00023672
# Iter: 10/180, loss_train: 5.6951, loss_val: nan, lr: 0.00023554
# Iter: 20/180, loss_train: 5.6947, loss_val: nan, lr: 0.00023437
# Iter: 30/180, loss_train: 5.6957, loss_val: nan, lr: 0.0002332
# Iter: 40/180, loss_train: 5.7007, loss_val: nan, lr: 0.00023204
# Iter: 50/180, loss_train: 5.6921, loss_val: nan, lr: 0.00023088
# Iter: 60/180, loss_train: 5.6954, loss_val: nan, lr: 0.00022973
# Iter: 70/180, loss_train: 5.6929, loss_val: nan, lr: 0.00022858
# Iter: 80/180, loss_train: 5.6932, loss_val: nan, lr: 0.00022744
# Iter: 90/180, loss_train: 5.6942, loss_val: nan, lr: 0.00022631
# Iter: 100/180, loss_train: 5.695, loss_val: nan, lr: 0.00022518
# Iter: 110/180, loss_train: 5.7107, loss_val: nan, lr: 0.00022405
# Iter: 120/180, loss_train: 5.7006, loss_val: nan, lr: 0.00022293
# Iter: 130/180, loss_train: 5.6936, loss_val: nan, lr: 0.00022182
# Iter: 140/180, loss_train: 5.6916, loss_val: nan, lr: 0.00022072
# Iter: 150/180, loss_train: 5.6937, loss_val: nan, lr: 0.00021962
# Iter: 160/180, loss_train: 5.6924, loss_val: nan, lr: 0.00021852
# Iter: 170/180, loss_train: 5.6939, loss_val: nan, lr: 0.00021743
# epoch: 17
# Iter: 0/180, loss_train: 5.695, loss_val: nan, lr: 0.00021634
# Iter: 10/180, loss_train: 5.6907, loss_val: nan, lr: 0.00021527
# Iter: 20/180, loss_train: 5.6906, loss_val: nan, lr: 0.00021419
# Iter: 30/180, loss_train: 5.6926, loss_val: nan, lr: 0.00021312
# Iter: 40/180, loss_train: 5.6936, loss_val: nan, lr: 0.00021206
# Iter: 50/180, loss_train: 5.6931, loss_val: nan, lr: 0.000211
# Iter: 60/180, loss_train: 5.7002, loss_val: nan, lr: 0.00020995
# Iter: 70/180, loss_train: 5.6977, loss_val: nan, lr: 0.0002089
# Iter: 80/180, loss_train: 5.7014, loss_val: nan, lr: 0.00020786
# Iter: 90/180, loss_train: 5.6928, loss_val: nan, lr: 0.00020682
# Iter: 100/180, loss_train: 5.6948, loss_val: nan, lr: 0.00020579
# Iter: 110/180, loss_train: 5.6983, loss_val: nan, lr: 0.00020476
# Iter: 120/180, loss_train: 5.6981, loss_val: nan, lr: 0.00020374
# Iter: 130/180, loss_train: 5.6957, loss_val: nan, lr: 0.00020273
# Iter: 140/180, loss_train: 5.6892, loss_val: nan, lr: 0.00020171
# Iter: 150/180, loss_train: 5.6921, loss_val: nan, lr: 0.00020071
# Iter: 160/180, loss_train: 5.6933, loss_val: nan, lr: 0.00019971
# Iter: 170/180, loss_train: 5.6909, loss_val: nan, lr: 0.00019871
# epoch: 18
# Iter: 0/180, loss_train: 5.691, loss_val: nan, lr: 0.00019772
# Iter: 10/180, loss_train: 5.6999, loss_val: nan, lr: 0.00019673
# Iter: 20/180, loss_train: 5.6962, loss_val: nan, lr: 0.00019575
# Iter: 30/180, loss_train: 5.6919, loss_val: nan, lr: 0.00019478
# Iter: 40/180, loss_train: 5.6936, loss_val: nan, lr: 0.0001938
# Iter: 50/180, loss_train: 5.6875, loss_val: nan, lr: 0.00019284
# Iter: 60/180, loss_train: 5.6872, loss_val: nan, lr: 0.00019187
# Iter: 70/180, loss_train: 5.6933, loss_val: nan, lr: 0.00019092
# Iter: 80/180, loss_train: 5.7001, loss_val: nan, lr: 0.00018997
# Iter: 90/180, loss_train: 5.692, loss_val: nan, lr: 0.00018902
# Iter: 100/180, loss_train: 5.6982, loss_val: nan, lr: 0.00018807
# Iter: 110/180, loss_train: 5.6986, loss_val: nan, lr: 0.00018714
# Iter: 120/180, loss_train: 5.6888, loss_val: nan, lr: 0.0001862
# Iter: 130/180, loss_train: 5.6924, loss_val: nan, lr: 0.00018527
# Iter: 140/180, loss_train: 5.6931, loss_val: nan, lr: 0.00018435
# Iter: 150/180, loss_train: 5.693, loss_val: nan, lr: 0.00018343
# Iter: 160/180, loss_train: 5.695, loss_val: nan, lr: 0.00018251
# Iter: 170/180, loss_train: 5.6928, loss_val: nan, lr: 0.0001816
# epoch: 19
# Iter: 0/180, loss_train: 5.6908, loss_val: nan, lr: 0.0001807
# Iter: 10/180, loss_train: 5.697, loss_val: nan, lr: 0.0001798
# Iter: 20/180, loss_train: 5.698, loss_val: nan, lr: 0.0001789
# Iter: 30/180, loss_train: 5.6909, loss_val: nan, lr: 0.00017801
# Iter: 40/180, loss_train: 5.6955, loss_val: nan, lr: 0.00017712
# Iter: 50/180, loss_train: 5.6937, loss_val: nan, lr: 0.00017624
# Iter: 60/180, loss_train: 5.6968, loss_val: nan, lr: 0.00017536
# Iter: 70/180, loss_train: 5.6917, loss_val: nan, lr: 0.00017448
# Iter: 80/180, loss_train: 5.6897, loss_val: nan, lr: 0.00017361
# Iter: 90/180, loss_train: 5.6932, loss_val: nan, lr: 0.00017274
# Iter: 100/180, loss_train: 5.6929, loss_val: nan, lr: 0.00017188
# Iter: 110/180, loss_train: 5.6904, loss_val: nan, lr: 0.00017103
# Iter: 120/180, loss_train: 5.6917, loss_val: nan, lr: 0.00017017
# Iter: 130/180, loss_train: 5.6943, loss_val: nan, lr: 0.00016932
# Iter: 140/180, loss_train: 5.6925, loss_val: nan, lr: 0.00016848
# Iter: 150/180, loss_train: 5.691, loss_val: nan, lr: 0.00016764
# Iter: 160/180, loss_train: 5.6893, loss_val: nan, lr: 0.0001668
# Iter: 170/180, loss_train: 5.6905, loss_val: nan, lr: 0.00016597
# epoch: 20
# Iter: 0/180, loss_train: 5.6885, loss_val: nan, lr: 0.00016514
# Iter: 10/180, loss_train: 5.687, loss_val: nan, lr: 0.00016432
# Iter: 20/180, loss_train: 5.6902, loss_val: nan, lr: 0.0001635
# Iter: 30/180, loss_train: 5.6969, loss_val: nan, lr: 0.00016268
# Iter: 40/180, loss_train: 5.6914, loss_val: nan, lr: 0.00016187
# Iter: 50/180, loss_train: 5.6919, loss_val: nan, lr: 0.00016106
# Iter: 60/180, loss_train: 5.6912, loss_val: nan, lr: 0.00016026
# Iter: 70/180, loss_train: 5.6928, loss_val: nan, lr: 0.00015946
# Iter: 80/180, loss_train: 5.6891, loss_val: nan, lr: 0.00015866
# Iter: 90/180, loss_train: 5.6904, loss_val: nan, lr: 0.00015787
# Iter: 100/180, loss_train: 5.6919, loss_val: nan, lr: 0.00015709
# Iter: 110/180, loss_train: 5.6887, loss_val: nan, lr: 0.0001563
# Iter: 120/180, loss_train: 5.6872, loss_val: nan, lr: 0.00015552
# Iter: 130/180, loss_train: 5.689, loss_val: nan, lr: 0.00015475
# Iter: 140/180, loss_train: 5.6915, loss_val: nan, lr: 0.00015397
# Iter: 150/180, loss_train: 5.6928, loss_val: nan, lr: 0.00015321
# Iter: 160/180, loss_train: 5.6918, loss_val: nan, lr: 0.00015244
# Iter: 170/180, loss_train: 5.6922, loss_val: nan, lr: 0.00015168
# epoch: 21
# Iter: 0/180, loss_train: 5.696, loss_val: nan, lr: 0.00015092
# Iter: 10/180, loss_train: 5.6977, loss_val: nan, lr: 0.00015017
# Iter: 20/180, loss_train: 5.6914, loss_val: nan, lr: 0.00014942
# Iter: 30/180, loss_train: 5.6879, loss_val: nan, lr: 0.00014868
# Iter: 40/180, loss_train: 5.6895, loss_val: nan, lr: 0.00014794
# Iter: 50/180, loss_train: 5.6971, loss_val: nan, lr: 0.0001472
# Iter: 60/180, loss_train: 5.6903, loss_val: nan, lr: 0.00014646
# Iter: 70/180, loss_train: 5.6939, loss_val: nan, lr: 0.00014573
# Iter: 80/180, loss_train: 5.6884, loss_val: nan, lr: 0.00014501
# Iter: 90/180, loss_train: 5.6905, loss_val: nan, lr: 0.00014428
# Iter: 100/180, loss_train: 5.6907, loss_val: nan, lr: 0.00014356
# Iter: 110/180, loss_train: 5.6902, loss_val: nan, lr: 0.00014285
# Iter: 120/180, loss_train: 5.691, loss_val: nan, lr: 0.00014213
# Iter: 130/180, loss_train: 5.6927, loss_val: nan, lr: 0.00014142
# Iter: 140/180, loss_train: 5.6904, loss_val: nan, lr: 0.00014072
# Iter: 150/180, loss_train: 5.6951, loss_val: nan, lr: 0.00014002
# Iter: 160/180, loss_train: 5.6907, loss_val: nan, lr: 0.00013932
# Iter: 170/180, loss_train: 5.6951, loss_val: nan, lr: 0.00013862
# epoch: 22
# Iter: 0/180, loss_train: 5.6944, loss_val: nan, lr: 0.00013793
# Iter: 10/180, loss_train: 5.6927, loss_val: nan, lr: 0.00013724
# Iter: 20/180, loss_train: 5.6904, loss_val: nan, lr: 0.00013656
# Iter: 30/180, loss_train: 5.6949, loss_val: nan, lr: 0.00013588
# Iter: 40/180, loss_train: 5.6862, loss_val: nan, lr: 0.0001352
# Iter: 50/180, loss_train: 5.6942, loss_val: nan, lr: 0.00013453
# Iter: 60/180, loss_train: 5.6912, loss_val: nan, lr: 0.00013385
# Iter: 70/180, loss_train: 5.6852, loss_val: nan, lr: 0.00013319
# Iter: 80/180, loss_train: 5.6937, loss_val: nan, lr: 0.00013252
# Iter: 90/180, loss_train: 5.6888, loss_val: nan, lr: 0.00013186
# Iter: 100/180, loss_train: 5.6884, loss_val: nan, lr: 0.0001312
# Iter: 110/180, loss_train: 5.6911, loss_val: nan, lr: 0.00013055
# Iter: 120/180, loss_train: 5.6891, loss_val: nan, lr: 0.0001299
# Iter: 130/180, loss_train: 5.6917, loss_val: nan, lr: 0.00012925
# Iter: 140/180, loss_train: 5.6935, loss_val: nan, lr: 0.0001286
# Iter: 150/180, loss_train: 5.695, loss_val: nan, lr: 0.00012796
# Iter: 160/180, loss_train: 5.6904, loss_val: nan, lr: 0.00012732
# Iter: 170/180, loss_train: 5.687, loss_val: nan, lr: 0.00012669
# epoch: 23
# Iter: 0/180, loss_train: 5.6961, loss_val: nan, lr: 0.00012606
# Iter: 10/180, loss_train: 5.6931, loss_val: nan, lr: 0.00012543
# Iter: 20/180, loss_train: 5.6899, loss_val: nan, lr: 0.0001248
# Iter: 30/180, loss_train: 5.6891, loss_val: nan, lr: 0.00012418
# Iter: 40/180, loss_train: 5.6864, loss_val: nan, lr: 0.00012356
# Iter: 50/180, loss_train: 5.6878, loss_val: nan, lr: 0.00012294
# Iter: 60/180, loss_train: 5.6898, loss_val: nan, lr: 0.00012233
# Iter: 70/180, loss_train: 5.693, loss_val: nan, lr: 0.00012172
# Iter: 80/180, loss_train: 5.6916, loss_val: nan, lr: 0.00012111
# Iter: 90/180, loss_train: 5.6936, loss_val: nan, lr: 0.00012051
# Iter: 100/180, loss_train: 5.6899, loss_val: nan, lr: 0.00011991
# Iter: 110/180, loss_train: 5.6866, loss_val: nan, lr: 0.00011931
# Iter: 120/180, loss_train: 5.6878, loss_val: nan, lr: 0.00011871
# Iter: 130/180, loss_train: 5.6881, loss_val: nan, lr: 0.00011812
# Iter: 140/180, loss_train: 5.6875, loss_val: nan, lr: 0.00011753
# Iter: 150/180, loss_train: 5.6854, loss_val: nan, lr: 0.00011695
# Iter: 160/180, loss_train: 5.6878, loss_val: nan, lr: 0.00011636
# Iter: 170/180, loss_train: 5.6869, loss_val: nan, lr: 0.00011578
# epoch: 24
# Iter: 0/180, loss_train: 5.6925, loss_val: nan, lr: 0.00011521
# Iter: 10/180, loss_train: 5.686, loss_val: nan, lr: 0.00011463
# Iter: 20/180, loss_train: 5.6881, loss_val: nan, lr: 0.00011406
# Iter: 30/180, loss_train: 5.6904, loss_val: nan, lr: 0.00011349
# Iter: 40/180, loss_train: 5.6908, loss_val: nan, lr: 0.00011292
# Iter: 50/180, loss_train: 5.6867, loss_val: nan, lr: 0.00011236
# Iter: 60/180, loss_train: 5.6895, loss_val: nan, lr: 0.0001118
# Iter: 70/180, loss_train: 5.6874, loss_val: nan, lr: 0.00011124
# Iter: 80/180, loss_train: 5.6898, loss_val: nan, lr: 0.00011069
# Iter: 90/180, loss_train: 5.6931, loss_val: nan, lr: 0.00011013
# Iter: 100/180, loss_train: 5.6947, loss_val: nan, lr: 0.00010959
# Iter: 110/180, loss_train: 5.6922, loss_val: nan, lr: 0.00010904
# Iter: 120/180, loss_train: 5.6885, loss_val: nan, lr: 0.00010849
# Iter: 130/180, loss_train: 5.6885, loss_val: nan, lr: 0.00010795
# Iter: 140/180, loss_train: 5.6858, loss_val: nan, lr: 0.00010741
# Iter: 150/180, loss_train: 5.6897, loss_val: nan, lr: 0.00010688
# Iter: 160/180, loss_train: 5.688, loss_val: nan, lr: 0.00010635
# Iter: 170/180, loss_train: 5.6888, loss_val: nan, lr: 0.00010582
# epoch: 25
# Iter: 0/180, loss_train: 5.6862, loss_val: nan, lr: 0.00010529
# Iter: 10/180, loss_train: 5.689, loss_val: nan, lr: 0.00010476
# Iter: 20/180, loss_train: 5.6866, loss_val: nan, lr: 0.00010424
# Iter: 30/180, loss_train: 5.6853, loss_val: nan, lr: 0.00010372
# Iter: 40/180, loss_train: 5.686, loss_val: nan, lr: 0.0001032
# Iter: 50/180, loss_train: 5.6872, loss_val: nan, lr: 0.00010269
# Iter: 60/180, loss_train: 5.688, loss_val: nan, lr: 0.00010217
# Iter: 70/180, loss_train: 5.688, loss_val: nan, lr: 0.00010167
# Iter: 80/180, loss_train: 5.6856, loss_val: nan, lr: 0.00010116
# Iter: 90/180, loss_train: 5.6876, loss_val: nan, lr: 0.00010065
# Iter: 100/180, loss_train: 5.6908, loss_val: nan, lr: 0.00010015
# Iter: 110/180, loss_train: 5.6854, loss_val: nan, lr: 9.9651e-05
# Iter: 120/180, loss_train: 5.6897, loss_val: nan, lr: 9.9154e-05
# Iter: 130/180, loss_train: 5.6905, loss_val: nan, lr: 9.866e-05
# Iter: 140/180, loss_train: 5.6876, loss_val: nan, lr: 9.8167e-05
# Iter: 150/180, loss_train: 5.6929, loss_val: nan, lr: 9.7678e-05
# Iter: 160/180, loss_train: 5.6859, loss_val: nan, lr: 9.719e-05
# Iter: 170/180, loss_train: 5.689, loss_val: nan, lr: 9.6706e-05
# epoch: 26
# Iter: 0/180, loss_train: 5.6912, loss_val: nan, lr: 9.6223e-05
# Iter: 10/180, loss_train: 5.6887, loss_val: nan, lr: 9.5743e-05
# Iter: 20/180, loss_train: 5.6852, loss_val: nan, lr: 9.5265e-05
# Iter: 30/180, loss_train: 5.6856, loss_val: nan, lr: 9.479e-05
# Iter: 40/180, loss_train: 5.6867, loss_val: nan, lr: 9.4317e-05
# Iter: 50/180, loss_train: 5.6888, loss_val: nan, lr: 9.3847e-05
# Iter: 60/180, loss_train: 5.6873, loss_val: nan, lr: 9.3379e-05
# Iter: 70/180, loss_train: 5.6871, loss_val: nan, lr: 9.2913e-05
# Iter: 80/180, loss_train: 5.6863, loss_val: nan, lr: 9.2449e-05
# Iter: 90/180, loss_train: 5.6842, loss_val: nan, lr: 9.1988e-05
# Iter: 100/180, loss_train: 5.6842, loss_val: nan, lr: 9.1529e-05
# Iter: 110/180, loss_train: 5.6848, loss_val: nan, lr: 9.1073e-05
# Iter: 120/180, loss_train: 5.6867, loss_val: nan, lr: 9.0618e-05
# Iter: 130/180, loss_train: 5.6859, loss_val: nan, lr: 9.0166e-05
# Iter: 140/180, loss_train: 5.6855, loss_val: nan, lr: 8.9716e-05
# Iter: 150/180, loss_train: 5.6865, loss_val: nan, lr: 8.9269e-05
# Iter: 160/180, loss_train: 5.688, loss_val: nan, lr: 8.8823e-05
# Iter: 170/180, loss_train: 5.6874, loss_val: nan, lr: 8.838e-05
# epoch: 27
# Iter: 0/180, loss_train: 5.6846, loss_val: nan, lr: 8.7939e-05
# Iter: 10/180, loss_train: 5.6911, loss_val: nan, lr: 8.7501e-05
# Iter: 20/180, loss_train: 5.6845, loss_val: nan, lr: 8.7064e-05
# Iter: 30/180, loss_train: 5.6874, loss_val: nan, lr: 8.663e-05
# Iter: 40/180, loss_train: 5.6854, loss_val: nan, lr: 8.6198e-05
# Iter: 50/180, loss_train: 5.6865, loss_val: nan, lr: 8.5768e-05
# Iter: 60/180, loss_train: 5.6871, loss_val: nan, lr: 8.534e-05
# Iter: 70/180, loss_train: 5.6867, loss_val: nan, lr: 8.4914e-05
# Iter: 80/180, loss_train: 5.687, loss_val: nan, lr: 8.449e-05
# Iter: 90/180, loss_train: 5.6866, loss_val: nan, lr: 8.4069e-05
# Iter: 100/180, loss_train: 5.6858, loss_val: nan, lr: 8.3649e-05
# Iter: 110/180, loss_train: 5.6882, loss_val: nan, lr: 8.3232e-05
# Iter: 120/180, loss_train: 5.6842, loss_val: nan, lr: 8.2817e-05
# Iter: 130/180, loss_train: 5.6867, loss_val: nan, lr: 8.2404e-05
# Iter: 140/180, loss_train: 5.6866, loss_val: nan, lr: 8.1993e-05
# Iter: 150/180, loss_train: 5.6847, loss_val: nan, lr: 8.1584e-05
# Iter: 160/180, loss_train: 5.6862, loss_val: nan, lr: 8.1177e-05
# Iter: 170/180, loss_train: 5.6855, loss_val: nan, lr: 8.0772e-05
# epoch: 28
# Iter: 0/180, loss_train: 5.6845, loss_val: nan, lr: 8.0369e-05
# Iter: 10/180, loss_train: 5.6852, loss_val: nan, lr: 7.9968e-05
# Iter: 20/180, loss_train: 5.6885, loss_val: nan, lr: 7.9569e-05
# Iter: 30/180, loss_train: 5.6882, loss_val: nan, lr: 7.9172e-05
# Iter: 40/180, loss_train: 5.6885, loss_val: nan, lr: 7.8777e-05
# Iter: 50/180, loss_train: 5.6905, loss_val: nan, lr: 7.8384e-05
# Iter: 60/180, loss_train: 5.6862, loss_val: nan, lr: 7.7993e-05
# Iter: 70/180, loss_train: 5.6857, loss_val: nan, lr: 7.7604e-05
# Iter: 80/180, loss_train: 5.6848, loss_val: nan, lr: 7.7217e-05
# Iter: 90/180, loss_train: 5.6835, loss_val: nan, lr: 7.6831e-05
# Iter: 100/180, loss_train: 5.6853, loss_val: nan, lr: 7.6448e-05
# Iter: 110/180, loss_train: 5.6848, loss_val: nan, lr: 7.6067e-05
# Iter: 120/180, loss_train: 5.6845, loss_val: nan, lr: 7.5687e-05
# Iter: 130/180, loss_train: 5.6853, loss_val: nan, lr: 7.531e-05
# Iter: 140/180, loss_train: 5.6842, loss_val: nan, lr: 7.4934e-05
# Iter: 150/180, loss_train: 5.687, loss_val: nan, lr: 7.456e-05
# Iter: 160/180, loss_train: 5.6833, loss_val: nan, lr: 7.4188e-05
# Iter: 170/180, loss_train: 5.6839, loss_val: nan, lr: 7.3818e-05
# epoch: 29
# Iter: 0/180, loss_train: 5.6839, loss_val: nan, lr: 7.345e-05
# Iter: 10/180, loss_train: 5.6832, loss_val: nan, lr: 7.3083e-05
# Iter: 20/180, loss_train: 5.6873, loss_val: nan, lr: 7.2719e-05
# Iter: 30/180, loss_train: 5.6853, loss_val: nan, lr: 7.2356e-05
# Iter: 40/180, loss_train: 5.6866, loss_val: nan, lr: 7.1995e-05
# Iter: 50/180, loss_train: 5.69, loss_val: nan, lr: 7.1636e-05
# Iter: 60/180, loss_train: 5.6867, loss_val: nan, lr: 7.1279e-05
# Iter: 70/180, loss_train: 5.6898, loss_val: nan, lr: 7.0923e-05
# Iter: 80/180, loss_train: 5.6849, loss_val: nan, lr: 7.0569e-05
# Iter: 90/180, loss_train: 5.6866, loss_val: nan, lr: 7.0217e-05
# Iter: 100/180, loss_train: 5.6835, loss_val: nan, lr: 6.9867e-05
# Iter: 110/180, loss_train: 5.6864, loss_val: nan, lr: 6.9518e-05
# Iter: 120/180, loss_train: 5.6867, loss_val: nan, lr: 6.9171e-05
# Iter: 130/180, loss_train: 5.6847, loss_val: nan, lr: 6.8826e-05
# Iter: 140/180, loss_train: 5.6852, loss_val: nan, lr: 6.8483e-05
# Iter: 150/180, loss_train: 5.6888, loss_val: nan, lr: 6.8141e-05
# Iter: 160/180, loss_train: 5.685, loss_val: nan, lr: 6.7801e-05
# Iter: 170/180, loss_train: 5.6829, loss_val: nan, lr: 6.7463e-05
# epoch: 30
# Iter: 0/180, loss_train: 5.6828, loss_val: nan, lr: 6.7127e-05
# Iter: 10/180, loss_train: 5.6838, loss_val: nan, lr: 6.6792e-05
# Iter: 20/180, loss_train: 5.6823, loss_val: nan, lr: 6.6458e-05
# Iter: 30/180, loss_train: 5.6868, loss_val: nan, lr: 6.6127e-05
# Iter: 40/180, loss_train: 5.6876, loss_val: nan, lr: 6.5797e-05
# Iter: 50/180, loss_train: 5.6876, loss_val: nan, lr: 6.5469e-05
# Iter: 60/180, loss_train: 5.6887, loss_val: nan, lr: 6.5142e-05
# Iter: 70/180, loss_train: 5.6867, loss_val: nan, lr: 6.4817e-05
# Iter: 80/180, loss_train: 5.6856, loss_val: nan, lr: 6.4494e-05
# Iter: 90/180, loss_train: 5.687, loss_val: nan, lr: 6.4172e-05
# Iter: 100/180, loss_train: 5.6864, loss_val: nan, lr: 6.3852e-05
# Iter: 110/180, loss_train: 5.6868, loss_val: nan, lr: 6.3533e-05
# Iter: 120/180, loss_train: 5.686, loss_val: nan, lr: 6.3216e-05
# Iter: 130/180, loss_train: 5.6868, loss_val: nan, lr: 6.2901e-05
# Iter: 140/180, loss_train: 5.685, loss_val: nan, lr: 6.2587e-05
# Iter: 150/180, loss_train: 5.6838, loss_val: nan, lr: 6.2275e-05
# Iter: 160/180, loss_train: 5.684, loss_val: nan, lr: 6.1964e-05
# Iter: 170/180, loss_train: 5.6855, loss_val: nan, lr: 6.1655e-05
# epoch: 31
# Iter: 0/180, loss_train: 5.6847, loss_val: nan, lr: 6.1348e-05
# Iter: 10/180, loss_train: 5.6858, loss_val: nan, lr: 6.1042e-05
# Iter: 20/180, loss_train: 5.6836, loss_val: nan, lr: 6.0737e-05
# Iter: 30/180, loss_train: 5.686, loss_val: nan, lr: 6.0434e-05
# Iter: 40/180, loss_train: 5.6818, loss_val: nan, lr: 6.0133e-05
# Iter: 50/180, loss_train: 5.682, loss_val: nan, lr: 5.9833e-05
# Iter: 60/180, loss_train: 5.6841, loss_val: nan, lr: 5.9534e-05
# Iter: 70/180, loss_train: 5.6838, loss_val: nan, lr: 5.9237e-05
# Iter: 80/180, loss_train: 5.6868, loss_val: nan, lr: 5.8942e-05
# Iter: 90/180, loss_train: 5.6841, loss_val: nan, lr: 5.8648e-05
# Iter: 100/180, loss_train: 5.6866, loss_val: nan, lr: 5.8355e-05
# Iter: 110/180, loss_train: 5.6872, loss_val: nan, lr: 5.8064e-05
# Iter: 120/180, loss_train: 5.685, loss_val: nan, lr: 5.7774e-05
# Iter: 130/180, loss_train: 5.6837, loss_val: nan, lr: 5.7486e-05
# Iter: 140/180, loss_train: 5.6836, loss_val: nan, lr: 5.7199e-05
# Iter: 150/180, loss_train: 5.6883, loss_val: nan, lr: 5.6914e-05
# Iter: 160/180, loss_train: 5.6832, loss_val: nan, lr: 5.663e-05
# Iter: 170/180, loss_train: 5.6829, loss_val: nan, lr: 5.6347e-05
# epoch: 32
# Iter: 0/180, loss_train: 5.6823, loss_val: nan, lr: 5.6066e-05
# Iter: 10/180, loss_train: 5.6869, loss_val: nan, lr: 5.5787e-05
# Iter: 20/180, loss_train: 5.6862, loss_val: nan, lr: 5.5508e-05
# Iter: 30/180, loss_train: 5.6853, loss_val: nan, lr: 5.5231e-05
# Iter: 40/180, loss_train: 5.6821, loss_val: nan, lr: 5.4956e-05
# Iter: 50/180, loss_train: 5.6836, loss_val: nan, lr: 5.4682e-05
# Iter: 60/180, loss_train: 5.6812, loss_val: nan, lr: 5.4409e-05
# Iter: 70/180, loss_train: 5.684, loss_val: nan, lr: 5.4137e-05
# Iter: 80/180, loss_train: 5.6826, loss_val: nan, lr: 5.3867e-05
# Iter: 90/180, loss_train: 5.6846, loss_val: nan, lr: 5.3599e-05
# Iter: 100/180, loss_train: 5.6854, loss_val: nan, lr: 5.3331e-05
# Iter: 110/180, loss_train: 5.6839, loss_val: nan, lr: 5.3065e-05
# Iter: 120/180, loss_train: 5.6863, loss_val: nan, lr: 5.28e-05
# Iter: 130/180, loss_train: 5.6848, loss_val: nan, lr: 5.2537e-05
# Iter: 140/180, loss_train: 5.6834, loss_val: nan, lr: 5.2275e-05
# Iter: 150/180, loss_train: 5.6832, loss_val: nan, lr: 5.2014e-05
# Iter: 160/180, loss_train: 5.6838, loss_val: nan, lr: 5.1755e-05
# Iter: 170/180, loss_train: 5.6823, loss_val: nan, lr: 5.1496e-05
# epoch: 33
# Iter: 0/180, loss_train: 5.6842, loss_val: nan, lr: 5.124e-05
# Iter: 10/180, loss_train: 5.684, loss_val: nan, lr: 5.0984e-05
# Iter: 20/180, loss_train: 5.683, loss_val: nan, lr: 5.073e-05
# Iter: 30/180, loss_train: 5.685, loss_val: nan, lr: 5.0477e-05
# Iter: 40/180, loss_train: 5.6838, loss_val: nan, lr: 5.0225e-05
# Iter: 50/180, loss_train: 5.6829, loss_val: nan, lr: 4.9974e-05
# Iter: 60/180, loss_train: 5.6832, loss_val: nan, lr: 4.9725e-05
# Iter: 70/180, loss_train: 5.6852, loss_val: nan, lr: 4.9477e-05
# Iter: 80/180, loss_train: 5.6855, loss_val: nan, lr: 4.923e-05
# Iter: 90/180, loss_train: 5.6827, loss_val: nan, lr: 4.8984e-05
# Iter: 100/180, loss_train: 5.6845, loss_val: nan, lr: 4.874e-05
# Iter: 110/180, loss_train: 5.6819, loss_val: nan, lr: 4.8497e-05
# Iter: 120/180, loss_train: 5.6872, loss_val: nan, lr: 4.8255e-05
# Iter: 130/180, loss_train: 5.6838, loss_val: nan, lr: 4.8014e-05
# Iter: 140/180, loss_train: 5.6828, loss_val: nan, lr: 4.7775e-05
# Iter: 150/180, loss_train: 5.6832, loss_val: nan, lr: 4.7536e-05
# Iter: 160/180, loss_train: 5.6832, loss_val: nan, lr: 4.7299e-05
# Iter: 170/180, loss_train: 5.6809, loss_val: nan, lr: 4.7063e-05
# epoch: 34
# Iter: 0/180, loss_train: 5.6828, loss_val: nan, lr: 4.6828e-05
# Iter: 10/180, loss_train: 5.681, loss_val: nan, lr: 4.6595e-05
# Iter: 20/180, loss_train: 5.6817, loss_val: nan, lr: 4.6362e-05
# Iter: 30/180, loss_train: 5.6826, loss_val: nan, lr: 4.6131e-05
# Iter: 40/180, loss_train: 5.6827, loss_val: nan, lr: 4.5901e-05
# Iter: 50/180, loss_train: 5.6834, loss_val: nan, lr: 4.5672e-05
# Iter: 60/180, loss_train: 5.6851, loss_val: nan, lr: 4.5444e-05
# Iter: 70/180, loss_train: 5.6833, loss_val: nan, lr: 4.5217e-05
# Iter: 80/180, loss_train: 5.6816, loss_val: nan, lr: 4.4992e-05
# Iter: 90/180, loss_train: 5.6836, loss_val: nan, lr: 4.4767e-05
# Iter: 100/180, loss_train: 5.6807, loss_val: nan, lr: 4.4544e-05
# Iter: 110/180, loss_train: 5.6856, loss_val: nan, lr: 4.4322e-05
# Iter: 120/180, loss_train: 5.683, loss_val: nan, lr: 4.4101e-05
# Iter: 130/180, loss_train: 5.6828, loss_val: nan, lr: 4.3881e-05
# Iter: 140/180, loss_train: 5.682, loss_val: nan, lr: 4.3662e-05
# Iter: 150/180, loss_train: 5.6828, loss_val: nan, lr: 4.3444e-05
# Iter: 160/180, loss_train: 5.6817, loss_val: nan, lr: 4.3227e-05
# Iter: 170/180, loss_train: 5.6831, loss_val: nan, lr: 4.3012e-05
# epoch: 35
# Iter: 0/180, loss_train: 5.6834, loss_val: nan, lr: 4.2797e-05
# Iter: 10/180, loss_train: 5.6821, loss_val: nan, lr: 4.2583e-05
# Iter: 20/180, loss_train: 5.6827, loss_val: nan, lr: 4.2371e-05
# Iter: 30/180, loss_train: 5.6863, loss_val: nan, lr: 4.216e-05
# Iter: 40/180, loss_train: 5.684, loss_val: nan, lr: 4.1949e-05
# Iter: 50/180, loss_train: 5.6839, loss_val: nan, lr: 4.174e-05
# Iter: 60/180, loss_train: 5.6837, loss_val: nan, lr: 4.1532e-05
# Iter: 70/180, loss_train: 5.6831, loss_val: nan, lr: 4.1325e-05
# Iter: 80/180, loss_train: 5.6806, loss_val: nan, lr: 4.1118e-05
# Iter: 90/180, loss_train: 5.6834, loss_val: nan, lr: 4.0913e-05
# Iter: 100/180, loss_train: 5.6838, loss_val: nan, lr: 4.0709e-05
# Iter: 110/180, loss_train: 5.6831, loss_val: nan, lr: 4.0506e-05
# Iter: 120/180, loss_train: 5.683, loss_val: nan, lr: 4.0304e-05
# Iter: 130/180, loss_train: 5.6844, loss_val: nan, lr: 4.0103e-05
# Iter: 140/180, loss_train: 5.6844, loss_val: nan, lr: 3.9903e-05
# Iter: 150/180, loss_train: 5.6847, loss_val: nan, lr: 3.9704e-05
# Iter: 160/180, loss_train: 5.6832, loss_val: nan, lr: 3.9506e-05
# Iter: 170/180, loss_train: 5.681, loss_val: nan, lr: 3.9309e-05
# epoch: 36
# Iter: 0/180, loss_train: 5.682, loss_val: nan, lr: 3.9113e-05
# Iter: 10/180, loss_train: 5.6821, loss_val: nan, lr: 3.8917e-05
# Iter: 20/180, loss_train: 5.6833, loss_val: nan, lr: 3.8723e-05
# Iter: 30/180, loss_train: 5.6799, loss_val: nan, lr: 3.853e-05
# Iter: 40/180, loss_train: 5.6805, loss_val: nan, lr: 3.8338e-05
# Iter: 50/180, loss_train: 5.6802, loss_val: nan, lr: 3.8147e-05
# Iter: 60/180, loss_train: 5.6818, loss_val: nan, lr: 3.7956e-05
# Iter: 70/180, loss_train: 5.6848, loss_val: nan, lr: 3.7767e-05
# Iter: 80/180, loss_train: 5.6815, loss_val: nan, lr: 3.7579e-05
# Iter: 90/180, loss_train: 5.6823, loss_val: nan, lr: 3.7391e-05
# Iter: 100/180, loss_train: 5.6812, loss_val: nan, lr: 3.7205e-05
# Iter: 110/180, loss_train: 5.682, loss_val: nan, lr: 3.7019e-05
# Iter: 120/180, loss_train: 5.6819, loss_val: nan, lr: 3.6834e-05
# Iter: 130/180, loss_train: 5.6815, loss_val: nan, lr: 3.6651e-05
# Iter: 140/180, loss_train: 5.6801, loss_val: nan, lr: 3.6468e-05
# Iter: 150/180, loss_train: 5.6839, loss_val: nan, lr: 3.6286e-05
# Iter: 160/180, loss_train: 5.6854, loss_val: nan, lr: 3.6105e-05
# Iter: 170/180, loss_train: 5.683, loss_val: nan, lr: 3.5925e-05
# epoch: 37
# Iter: 0/180, loss_train: 5.6837, loss_val: nan, lr: 3.5745e-05
# Iter: 10/180, loss_train: 5.6824, loss_val: nan, lr: 3.5567e-05
# Iter: 20/180, loss_train: 5.6828, loss_val: nan, lr: 3.539e-05
# Iter: 30/180, loss_train: 5.6823, loss_val: nan, lr: 3.5213e-05
# Iter: 40/180, loss_train: 5.6819, loss_val: nan, lr: 3.5037e-05
# Iter: 50/180, loss_train: 5.6815, loss_val: nan, lr: 3.4863e-05
# Iter: 60/180, loss_train: 5.6816, loss_val: nan, lr: 3.4689e-05
# Iter: 70/180, loss_train: 5.6822, loss_val: nan, lr: 3.4516e-05
# Iter: 80/180, loss_train: 5.6823, loss_val: nan, lr: 3.4343e-05
# Iter: 90/180, loss_train: 5.681, loss_val: nan, lr: 3.4172e-05
# Iter: 100/180, loss_train: 5.6812, loss_val: nan, lr: 3.4002e-05
# Iter: 110/180, loss_train: 5.6821, loss_val: nan, lr: 3.3832e-05
# Iter: 120/180, loss_train: 5.6836, loss_val: nan, lr: 3.3663e-05
# Iter: 130/180, loss_train: 5.6814, loss_val: nan, lr: 3.3495e-05
# Iter: 140/180, loss_train: 5.682, loss_val: nan, lr: 3.3328e-05
# Iter: 150/180, loss_train: 5.6823, loss_val: nan, lr: 3.3162e-05
# Iter: 160/180, loss_train: 5.6816, loss_val: nan, lr: 3.2997e-05
# Iter: 170/180, loss_train: 5.6825, loss_val: nan, lr: 3.2832e-05
# epoch: 38
# Iter: 0/180, loss_train: 5.6803, loss_val: nan, lr: 3.2668e-05
# Iter: 10/180, loss_train: 5.6814, loss_val: nan, lr: 3.2505e-05
# Iter: 20/180, loss_train: 5.6814, loss_val: nan, lr: 3.2343e-05
# Iter: 30/180, loss_train: 5.6814, loss_val: nan, lr: 3.2182e-05
# Iter: 40/180, loss_train: 5.6831, loss_val: nan, lr: 3.2021e-05
# Iter: 50/180, loss_train: 5.6801, loss_val: nan, lr: 3.1861e-05
# Iter: 60/180, loss_train: 5.6826, loss_val: nan, lr: 3.1702e-05
# Iter: 70/180, loss_train: 5.6817, loss_val: nan, lr: 3.1544e-05
# Iter: 80/180, loss_train: 5.6807, loss_val: nan, lr: 3.1387e-05
# Iter: 90/180, loss_train: 5.6793, loss_val: nan, lr: 3.123e-05
# Iter: 100/180, loss_train: 5.6865, loss_val: nan, lr: 3.1074e-05
# Iter: 110/180, loss_train: 5.6828, loss_val: nan, lr: 3.0919e-05
# Iter: 120/180, loss_train: 5.6813, loss_val: nan, lr: 3.0765e-05
# Iter: 130/180, loss_train: 5.6802, loss_val: nan, lr: 3.0612e-05
# Iter: 140/180, loss_train: 5.682, loss_val: nan, lr: 3.0459e-05
# Iter: 150/180, loss_train: 5.6799, loss_val: nan, lr: 3.0307e-05
# Iter: 160/180, loss_train: 5.6827, loss_val: nan, lr: 3.0156e-05
# Iter: 170/180, loss_train: 5.6816, loss_val: nan, lr: 3.0005e-05
# epoch: 39
# Iter: 0/180, loss_train: 5.6811, loss_val: nan, lr: 2.9856e-05
# Iter: 10/180, loss_train: 5.6808, loss_val: nan, lr: 2.9707e-05
# Iter: 20/180, loss_train: 5.6823, loss_val: nan, lr: 2.9559e-05
# Iter: 30/180, loss_train: 5.6795, loss_val: nan, lr: 2.9411e-05
# Iter: 40/180, loss_train: 5.6817, loss_val: nan, lr: 2.9264e-05
# Iter: 50/180, loss_train: 5.6819, loss_val: nan, lr: 2.9118e-05
# Iter: 60/180, loss_train: 5.6833, loss_val: nan, lr: 2.8973e-05
# Iter: 70/180, loss_train: 5.6804, loss_val: nan, lr: 2.8829e-05
# Iter: 80/180, loss_train: 5.6814, loss_val: nan, lr: 2.8685e-05
# Iter: 90/180, loss_train: 5.6794, loss_val: nan, lr: 2.8542e-05
# Iter: 100/180, loss_train: 5.6813, loss_val: nan, lr: 2.8399e-05
# Iter: 110/180, loss_train: 5.6802, loss_val: nan, lr: 2.8258e-05
# Iter: 120/180, loss_train: 5.6796, loss_val: nan, lr: 2.8117e-05
# Iter: 130/180, loss_train: 5.6827, loss_val: nan, lr: 2.7976e-05
# Iter: 140/180, loss_train: 5.6806, loss_val: nan, lr: 2.7837e-05
# Iter: 150/180, loss_train: 5.6813, loss_val: nan, lr: 2.7698e-05
# Iter: 160/180, loss_train: 5.6821, loss_val: nan, lr: 2.756e-05
# Iter: 170/180, loss_train: 5.6819, loss_val: nan, lr: 2.7422e-05
# epoch: 40
# Iter: 0/180, loss_train: 5.6812, loss_val: nan, lr: 2.7285e-05
# Iter: 10/180, loss_train: 5.6825, loss_val: nan, lr: 2.7149e-05
# Iter: 20/180, loss_train: 5.6825, loss_val: nan, lr: 2.7014e-05
# Iter: 30/180, loss_train: 5.6806, loss_val: nan, lr: 2.6879e-05
# Iter: 40/180, loss_train: 5.6819, loss_val: nan, lr: 2.6745e-05
# Iter: 50/180, loss_train: 5.6813, loss_val: nan, lr: 2.6612e-05
# Iter: 60/180, loss_train: 5.6823, loss_val: nan, lr: 2.6479e-05
# Iter: 70/180, loss_train: 5.6815, loss_val: nan, lr: 2.6347e-05
# Iter: 80/180, loss_train: 5.6823, loss_val: nan, lr: 2.6215e-05
# Iter: 90/180, loss_train: 5.6809, loss_val: nan, lr: 2.6085e-05
# Iter: 100/180, loss_train: 5.6804, loss_val: nan, lr: 2.5954e-05
# Iter: 110/180, loss_train: 5.6845, loss_val: nan, lr: 2.5825e-05
# Iter: 120/180, loss_train: 5.6815, loss_val: nan, lr: 2.5696e-05
# Iter: 130/180, loss_train: 5.6812, loss_val: nan, lr: 2.5568e-05
# Iter: 140/180, loss_train: 5.683, loss_val: nan, lr: 2.544e-05
# Iter: 150/180, loss_train: 5.6813, loss_val: nan, lr: 2.5313e-05
# Iter: 160/180, loss_train: 5.6794, loss_val: nan, lr: 2.5187e-05
# Iter: 170/180, loss_train: 5.6807, loss_val: nan, lr: 2.5062e-05
# epoch: 41
# Iter: 0/180, loss_train: 5.6818, loss_val: nan, lr: 2.4936e-05
# Iter: 10/180, loss_train: 5.6804, loss_val: nan, lr: 2.4812e-05
# Iter: 20/180, loss_train: 5.6798, loss_val: nan, lr: 2.4688e-05
# Iter: 30/180, loss_train: 5.683, loss_val: nan, lr: 2.4565e-05
# Iter: 40/180, loss_train: 5.68, loss_val: nan, lr: 2.4443e-05
# Iter: 50/180, loss_train: 5.6813, loss_val: nan, lr: 2.4321e-05
# Iter: 60/180, loss_train: 5.6803, loss_val: nan, lr: 2.4199e-05
# Iter: 70/180, loss_train: 5.6836, loss_val: nan, lr: 2.4079e-05
# Iter: 80/180, loss_train: 5.6797, loss_val: nan, lr: 2.3958e-05
# Iter: 90/180, loss_train: 5.6812, loss_val: nan, lr: 2.3839e-05
# Iter: 100/180, loss_train: 5.68, loss_val: nan, lr: 2.372e-05
# Iter: 110/180, loss_train: 5.6815, loss_val: nan, lr: 2.3602e-05
# Iter: 120/180, loss_train: 5.6805, loss_val: nan, lr: 2.3484e-05
# Iter: 130/180, loss_train: 5.6801, loss_val: nan, lr: 2.3367e-05
# Iter: 140/180, loss_train: 5.6813, loss_val: nan, lr: 2.325e-05
# Iter: 150/180, loss_train: 5.6813, loss_val: nan, lr: 2.3134e-05
# Iter: 160/180, loss_train: 5.6808, loss_val: nan, lr: 2.3019e-05
# Iter: 170/180, loss_train: 5.6816, loss_val: nan, lr: 2.2904e-05
# epoch: 42
# Iter: 0/180, loss_train: 5.6811, loss_val: nan, lr: 2.279e-05
# Iter: 10/180, loss_train: 5.6801, loss_val: nan, lr: 2.2676e-05
# Iter: 20/180, loss_train: 5.6802, loss_val: nan, lr: 2.2563e-05
# Iter: 30/180, loss_train: 5.6793, loss_val: nan, lr: 2.245e-05
# Iter: 40/180, loss_train: 5.6794, loss_val: nan, lr: 2.2338e-05
# Iter: 50/180, loss_train: 5.6798, loss_val: nan, lr: 2.2227e-05
# Iter: 60/180, loss_train: 5.6827, loss_val: nan, lr: 2.2116e-05
# Iter: 70/180, loss_train: 5.6798, loss_val: nan, lr: 2.2006e-05
# Iter: 80/180, loss_train: 5.6797, loss_val: nan, lr: 2.1896e-05
# Iter: 90/180, loss_train: 5.6808, loss_val: nan, lr: 2.1787e-05
# Iter: 100/180, loss_train: 5.6807, loss_val: nan, lr: 2.1678e-05
# Iter: 110/180, loss_train: 5.6809, loss_val: nan, lr: 2.157e-05
# Iter: 120/180, loss_train: 5.6793, loss_val: nan, lr: 2.1462e-05
# Iter: 130/180, loss_train: 5.6836, loss_val: nan, lr: 2.1355e-05
# Iter: 140/180, loss_train: 5.6804, loss_val: nan, lr: 2.1249e-05
# Iter: 150/180, loss_train: 5.6808, loss_val: nan, lr: 2.1143e-05
# Iter: 160/180, loss_train: 5.683, loss_val: nan, lr: 2.1037e-05
# Iter: 170/180, loss_train: 5.6803, loss_val: nan, lr: 2.0932e-05
# epoch: 43
# Iter: 0/180, loss_train: 5.6808, loss_val: nan, lr: 2.0828e-05
# Iter: 10/180, loss_train: 5.6798, loss_val: nan, lr: 2.0724e-05
# Iter: 20/180, loss_train: 5.6807, loss_val: nan, lr: 2.062e-05
# Iter: 30/180, loss_train: 5.6796, loss_val: nan, lr: 2.0518e-05
# Iter: 40/180, loss_train: 5.6791, loss_val: nan, lr: 2.0415e-05
# Iter: 50/180, loss_train: 5.6789, loss_val: nan, lr: 2.0313e-05
# Iter: 60/180, loss_train: 5.6797, loss_val: nan, lr: 2.0212e-05
# Iter: 70/180, loss_train: 5.6817, loss_val: nan, lr: 2.0111e-05
# Iter: 80/180, loss_train: 5.6812, loss_val: nan, lr: 2.0011e-05
# Iter: 90/180, loss_train: 5.6806, loss_val: nan, lr: 1.9911e-05
# Iter: 100/180, loss_train: 5.6808, loss_val: nan, lr: 1.9812e-05
# Iter: 110/180, loss_train: 5.6792, loss_val: nan, lr: 1.9713e-05
# Iter: 120/180, loss_train: 5.6803, loss_val: nan, lr: 1.9615e-05
# Iter: 130/180, loss_train: 5.6789, loss_val: nan, lr: 1.9517e-05
# Iter: 140/180, loss_train: 5.6788, loss_val: nan, lr: 1.9419e-05
# Iter: 150/180, loss_train: 5.6805, loss_val: nan, lr: 1.9322e-05
# Iter: 160/180, loss_train: 5.6798, loss_val: nan, lr: 1.9226e-05
# Iter: 170/180, loss_train: 5.6792, loss_val: nan, lr: 1.913e-05
# epoch: 44
# Iter: 0/180, loss_train: 5.6801, loss_val: nan, lr: 1.9035e-05
# Iter: 10/180, loss_train: 5.6802, loss_val: nan, lr: 1.894e-05
# Iter: 20/180, loss_train: 5.6802, loss_val: nan, lr: 1.8845e-05
# Iter: 30/180, loss_train: 5.6809, loss_val: nan, lr: 1.8751e-05
# Iter: 40/180, loss_train: 5.6802, loss_val: nan, lr: 1.8658e-05
# Iter: 50/180, loss_train: 5.6811, loss_val: nan, lr: 1.8565e-05
# Iter: 60/180, loss_train: 5.6806, loss_val: nan, lr: 1.8472e-05
# Iter: 70/180, loss_train: 5.6781, loss_val: nan, lr: 1.838e-05
# Iter: 80/180, loss_train: 5.6807, loss_val: nan, lr: 1.8288e-05
# Iter: 90/180, loss_train: 5.6803, loss_val: nan, lr: 1.8197e-05
# Iter: 100/180, loss_train: 5.6799, loss_val: nan, lr: 1.8106e-05
# Iter: 110/180, loss_train: 5.679, loss_val: nan, lr: 1.8016e-05
# Iter: 120/180, loss_train: 5.6799, loss_val: nan, lr: 1.7926e-05
# Iter: 130/180, loss_train: 5.679, loss_val: nan, lr: 1.7837e-05
# Iter: 140/180, loss_train: 5.6802, loss_val: nan, lr: 1.7748e-05
# Iter: 150/180, loss_train: 5.6801, loss_val: nan, lr: 1.7659e-05
# Iter: 160/180, loss_train: 5.6803, loss_val: nan, lr: 1.7571e-05
# Iter: 170/180, loss_train: 5.68, loss_val: nan, lr: 1.7483e-05
# epoch: 45
# Iter: 0/180, loss_train: 5.6789, loss_val: nan, lr: 1.7396e-05
# Iter: 10/180, loss_train: 5.6798, loss_val: nan, lr: 1.7309e-05
# Iter: 20/180, loss_train: 5.6802, loss_val: nan, lr: 1.7223e-05
# Iter: 30/180, loss_train: 5.6819, loss_val: nan, lr: 1.7137e-05
# Iter: 40/180, loss_train: 5.6799, loss_val: nan, lr: 1.7051e-05
# Iter: 50/180, loss_train: 5.6792, loss_val: nan, lr: 1.6966e-05
# Iter: 60/180, loss_train: 5.6799, loss_val: nan, lr: 1.6882e-05
# Iter: 70/180, loss_train: 5.6801, loss_val: nan, lr: 1.6798e-05
# Iter: 80/180, loss_train: 5.6804, loss_val: nan, lr: 1.6714e-05
# Iter: 90/180, loss_train: 5.6809, loss_val: nan, lr: 1.663e-05
# Iter: 100/180, loss_train: 5.6797, loss_val: nan, lr: 1.6547e-05
# Iter: 110/180, loss_train: 5.6779, loss_val: nan, lr: 1.6465e-05
# Iter: 120/180, loss_train: 5.6795, loss_val: nan, lr: 1.6383e-05
# Iter: 130/180, loss_train: 5.6794, loss_val: nan, lr: 1.6301e-05
# Iter: 140/180, loss_train: 5.6807, loss_val: nan, lr: 1.622e-05
# Iter: 150/180, loss_train: 5.6802, loss_val: nan, lr: 1.6139e-05
# Iter: 160/180, loss_train: 5.6798, loss_val: nan, lr: 1.6058e-05
# Iter: 170/180, loss_train: 5.6796, loss_val: nan, lr: 1.5978e-05
# epoch: 46
# Iter: 0/180, loss_train: 5.6789, loss_val: nan, lr: 1.5898e-05
# Iter: 10/180, loss_train: 5.6781, loss_val: nan, lr: 1.5819e-05
# Iter: 20/180, loss_train: 5.6788, loss_val: nan, lr: 1.574e-05
# Iter: 30/180, loss_train: 5.6804, loss_val: nan, lr: 1.5662e-05
# Iter: 40/180, loss_train: 5.6792, loss_val: nan, lr: 1.5584e-05
# Iter: 50/180, loss_train: 5.6793, loss_val: nan, lr: 1.5506e-05
# Iter: 60/180, loss_train: 5.681, loss_val: nan, lr: 1.5428e-05
# Iter: 70/180, loss_train: 5.6796, loss_val: nan, lr: 1.5351e-05
# Iter: 80/180, loss_train: 5.6789, loss_val: nan, lr: 1.5275e-05
# Iter: 90/180, loss_train: 5.6803, loss_val: nan, lr: 1.5199e-05
# Iter: 100/180, loss_train: 5.6784, loss_val: nan, lr: 1.5123e-05
# Iter: 110/180, loss_train: 5.6812, loss_val: nan, lr: 1.5047e-05
# Iter: 120/180, loss_train: 5.6797, loss_val: nan, lr: 1.4972e-05
# Iter: 130/180, loss_train: 5.6799, loss_val: nan, lr: 1.4898e-05
# Iter: 140/180, loss_train: 5.6788, loss_val: nan, lr: 1.4823e-05
# Iter: 150/180, loss_train: 5.6803, loss_val: nan, lr: 1.4749e-05
# Iter: 160/180, loss_train: 5.6802, loss_val: nan, lr: 1.4676e-05
# Iter: 170/180, loss_train: 5.6792, loss_val: nan, lr: 1.4603e-05
# epoch: 47
# Iter: 0/180, loss_train: 5.6782, loss_val: nan, lr: 1.453e-05
# Iter: 10/180, loss_train: 5.6794, loss_val: nan, lr: 1.4457e-05
# Iter: 20/180, loss_train: 5.6788, loss_val: nan, lr: 1.4385e-05
# Iter: 30/180, loss_train: 5.679, loss_val: nan, lr: 1.4313e-05
# Iter: 40/180, loss_train: 5.6792, loss_val: nan, lr: 1.4242e-05
# Iter: 50/180, loss_train: 5.6786, loss_val: nan, lr: 1.4171e-05
# Iter: 60/180, loss_train: 5.6804, loss_val: nan, lr: 1.41e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-038ce45bca59> in <module>
#       2 for epoch in range(n_epochs):
#       3     print(f'epoch: {epoch}')
# ----> 4     training_simCLR.epoch_step( dataloader_train,
#       5                                 model,
#       6                                 optimizer,
#
# /media/rich/Home_Linux_partition/github_repos/GCaMP_ROI_classifier/old_stuff/training_simCLR.py in epoch_step(dataloader, model, optimizer, criterion, scheduler, temperature, loss_rolling_train, device, do_validation, validation_Object, loss_rolling_val, verbose, verbose_update_period)
#     118         y_batch = y_batch.to(device)
#     119         # for i_transform in range(X_batch.shape[1]): # X_batch.shape[1] = number of transforms
# --> 120         loss = train_step(X_batch, y_batch, model, optimizer, criterion, scheduler, temperature)
#     121         loss_rolling_train.append(loss)
#     122         if do_validation:
#
# /media/rich/Home_Linux_partition/github_repos/GCaMP_ROI_classifier/old_stuff/training_simCLR.py in train_step(X_train_batch, y_train_batch, model, optimizer, criterion, scheduler, temperature)
#      44     features = model(X_train_batch)
#      45
# ---> 46     logits, labels = info_nce_loss(features, batch_size=X_train_batch.shape[0]/2, n_views=2, temperature=temperature, DEVICE=X_train_batch.device)
#      47     loss_train = criterion(logits, labels)
#      48
#
# /media/rich/Home_Linux_partition/github_repos/GCaMP_ROI_classifier/old_stuff/training_simCLR.py in info_nce_loss(features, batch_size, n_views, temperature, DEVICE)
#     223     labels = torch.cat([torch.arange(batch_size) for i in range(n_views)], dim=0)
#     224     labels = (labels.unsqueeze(0) == labels.unsqueeze(1)).float()
# --> 225     labels = labels.to(DEVICE)
#     226
#     227     # normalize to unit hypersphere
#
# KeyboardInterrupt:

# %%
plt.figure()
plt.plot(losses_train)
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">

# %% [markdown]
# ## Check embeddings

# %%
torch.cuda.empty_cache()

# %%
features = model(torch.tensor(images_labeled, device=DEVICE, dtype=torch.float32)[:,None,...]).detach()
# features = model(torch.tensor(X_val, device=DEVICE, dtype=torch.float32)[:,None,...]).detach()
# features = model(torch.tensor(X_train, device=DEVICE, dtype=torch.float32)[:,None,...]).detach()

# %%
_, features_embedded, _, _ = decomposition.torch_pca(features, device=DEVICE, return_cpu=True)

# %%
from sklearn import manifold

tsne = manifold.TSNE(n_components=2, 
                     perplexity=90.0, 
                     early_exaggeration=12.0, 
                     learning_rate=200, 
                     n_iter=1000, 
                     n_iter_without_progress=300, 
                     min_grad_norm=1e-07, 
                     metric='euclidean', 
                     init='pca', 
                     verbose=0, 
                     random_state=None, 
                     method='barnes_hut', 
                     angle=0.5, 
                     n_jobs=-1, 
                     square_distances='legacy'
                    )
features_embedded = tsne.fit_transform(features.cpu())

# %%
import matplotlib as mpl

mpl.rcParams['image.cmap'] = 'Set1'
# %matplotlib notebook
plt.figure()
plt.scatter(features_embedded[:,0], features_embedded[:,1], c=labels)
# plt.scatter(features_embedded[:,0], features_embedded[:,1], c=y_val)
# plt.scatter(features_embedded[:,4], features_embedded[:,5], c=y_train)
# plt.scatter(features_embedded[:,11], features[:,43].cpu(), c=y_train)
mpl.rcParams['image.cmap'] = 'viridis'
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">

# %% [markdown]
# ## Check filters

# %%
list(model.state_dict().keys())
# Out:
# ['cnn_layers.0.weight',
#  'cnn_layers.0.bias',
#  'cnn_layers.2.weight',
#  'cnn_layers.2.bias',
#  'cnn_layers.5.weight',
#  'cnn_layers.5.bias',
#  'cnn_layers.8.weight',
#  'cnn_layers.8.bias',
#  'linear_layers.0.weight',
#  'linear_layers.0.bias',
#  'linear_layers.2.weight',
#  'linear_layers.2.bias']

# %%
layer_1 = model.state_dict()['cnn_layers.0.weight'].cpu()
layer_2 = model.state_dict()['cnn_layers.2.weight'].cpu()
layer_3 = model.state_dict()['cnn_layers.5.weight'].cpu()
layer_4 = model.state_dict()['cnn_layers.8.weight'].cpu()

plt.figure()
for ii in range(layer_1.shape[1]):
    for jj in range(layer_1.shape[0]):
        plt.subplot2grid((layer_1.shape[1],layer_1.shape[0]),(ii,jj))
        fig = plt.imshow(layer_1[jj,ii,:,:] , clim=(-0.2,0.2))
        fig.axes.get_xaxis().set_visible(False)
        fig.axes.get_yaxis().set_visible(False)

plt.figure()
for ii in range(layer_2.shape[1]):
    for jj in range(layer_2.shape[0]):
        plt.subplot2grid((layer_2.shape[1],layer_2.shape[0]),(ii,jj))
        fig = plt.imshow(layer_2[jj,ii,:,:], clim=(-.05,.05))
        fig.axes.get_xaxis().set_visible(False)
        fig.axes.get_yaxis().set_visible(False)

plt.figure()
for ii in range(16):
    for jj in range(16):
        plt.subplot2grid((16,16),(ii,jj))
        fig = plt.imshow(layer_3[jj, ii,:,:])
        fig.axes.get_xaxis().set_visible(False)
        fig.axes.get_yaxis().set_visible(False)
        
plt.figure()
for ii in range(16):
    for jj in range(16):
        plt.subplot2grid((16,16),(ii,jj))
        fig = plt.imshow(layer_4[jj, ii,:,:])
        fig.axes.get_xaxis().set_visible(False)
        fig.axes.get_yaxis().set_visible(False)
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">
# <img src="data:image/png;base64,..." width="697.5833333333334">
# <img src="data:image/png;base64,..." width="697.5833333333334">
# <img src="data:image/png;base64,..." width="697.5833333333334">

# %%
torch.save(model.state_dict(), '/media/rich/bigSSD/Net_trainedOnAug_20211025_trainingSet_mouse628_20200903and20200815_simCLR.pth')

# %%
model = Net()
model.load_state_dict(torch.load('test_save.pth'))
model.eval()
