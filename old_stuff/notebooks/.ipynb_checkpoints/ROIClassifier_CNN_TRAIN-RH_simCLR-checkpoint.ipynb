# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import sys
import copy

import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy.io import savemat
import scipy.signal

import torch
import torchvision
import torchvision.transforms as transforms

import os

# for reading and displaying images
from skimage.io import imread
# for creating validation set
from sklearn.model_selection import train_test_split
# for evaluating the model
from sklearn.metrics import accuracy_score

import pathlib
from imgaug import augmenters as iaa


# %matplotlib notebook
# %matplotlib notebook
# %matplotlib inline
# %matplotlib qt

# %%
import sys
sys.path.append(r'/media/rich/Home_Linux_partition/github_repos/GCaMP_ROI_classifier')

# %%
import sys

sys.path.append('/media/rich/Home_Linux_partition/github_repos/')

# %load_ext autoreload
# %autoreload 2
from basic_neural_processing_modules import torch_helpers, decomposition
from GCaMP_ROI_classifier.old_stuff import util, models, training_simCLR, augmentation

# %%
dir_folders = r'/media/rich/bigSSD/for_Josh/GCAMP_ROI_Classifier_data/label_data'
folders = [r'mouse 6_28 _ day 20200903/',
             r'mouse6_28 _ day20200815/']
fileNames_statFiles = [r'stat.npy']*len(folders)
paths_statFiles = [pathlib.Path(dir_folders) / folders[ii] / fileNames_statFiles[ii] for ii in range(len(folders))]

statFile_import_kwargs = {'out_height_width': [36,36],
                          'max_footprint_width': 241,
                          'plot_pref':True}

sf_all = util.import_multiple_stat_files(   paths_statFiles=paths_statFiles,
                                        fileNames_statFiles=fileNames_statFiles,
                                        out_height_width=[36,36],
                                        max_footprint_width=241,
                                        plot_pref=True)
images = np.concatenate(sf_all, axis=0) *255
print(f'concatenated images shape: {images.shape}')

fileNames_labelFiles = ['labels_posthoc_filledIn_allCells.npy',
             'labels_posthoc_all.npy']
paths_labelFiles = [pathlib.Path(dir_folders) / folders[ii] / fileNames_labelFiles[ii] for ii in range(len(folders))]

labels_all = util.import_multiple_label_files(paths_labelFiles=paths_labelFiles,
                                       plot_pref=True)
labels = np.concatenate(labels_all)

assert np.alltrue([sf_all[ii].shape[0] == labels_all[ii].shape[0] for ii in range(len(sf_all))]) , 'num images in stat files does not correspond to num labels'
# Out:
# concatenated images shape: (9715, 36, 36)

# %%
duplicates = 1

images_dup = np.tile(images , (duplicates , 1 , 1))
labels_dup = np.tile(labels , (duplicates))

print(images_dup.shape)
print(labels_dup.shape)

numToGetTo = np.sum(labels_dup==0)
print(numToGetTo)
for ii in np.array([1,4,5]):
#     idxToDelete = np.cumsum(labels_dup==ii) <= (np.sum(labels_dup==ii) - numToGetTo)
    if ii==5:
        numToGetTo = np.sum(labels_dup==0)/2
    else:
        numToGetTo = np.sum(labels_dup==0)

    idxToDelete = (np.cumsum(labels_dup==ii) * (labels_dup==ii)) > numToGetTo
    images_dup = images_dup[idxToDelete==0,:,:]
    labels_dup = labels_dup[idxToDelete==0]


print(np.sum(labels_dup==0))
print(np.sum(labels_dup==1))
print(np.sum(labels_dup==4))
print(np.sum(labels_dup==5))
print(images_dup.shape)
print(labels_dup.shape)
# Out:
# (9715, 36, 36)
# (9715,)
# 532
# 532
# 532
# 532
# 266
# (1863, 36, 36)
# (1863,)

# %%
# create validation set
# X_train, X_val, y_train, y_val = train_test_split(images[:], labels[:], test_size = 0.15)
X_train, X_val, y_train, y_val = train_test_split(images_dup[:], labels_dup[:], test_size = 0.15)
(X_train.shape, y_train.shape), (X_val.shape, y_val.shape)
# Out:
# (((1583, 36, 36), (1583,)), ((280, 36, 36), (280,)))

# %%
plt.figure()
plt.hist(labels_dup, 20);
# Out:
# <img src="data:image/png;base64,..." width="431.75000000000006">

# %%
import torchvision.transforms    

transforms = torch.nn.Sequential(
    torchvision.transforms.RandomHorizontalFlip(p=0.5),
    
    torchvision.transforms.GaussianBlur(kernel_size=5,
                                        sigma=(0.0001, 1.)),
    
    torchvision.transforms.RandomPerspective(distortion_scale=0.4, 
                                             p=0.5, 
                                             interpolation=torchvision.transforms.InterpolationMode.BILINEAR, 
                                             fill=0),
    torchvision.transforms.RandomAffine(
                                        degrees=(-180,180),
                                        translate=(0.3, 0.3),
                                        scale=(0.7, 1.7), 
                                        shear=(-20, 20, -20, 20), 
                                        interpolation=torchvision.transforms.InterpolationMode.BILINEAR, 
                                        fill=0, 
                                        fillcolor=None, 
                                        resample=None),
    
    augmentation.AddPoissonNoise(   level_bounds=(0,0.4),
                                    prob=1),

    augmentation.AddGaussianNoise(  mean=0, 
                                    std=0.2,
                                    prob=1),
)
# scripted_transforms = torch.jit.script(transforms)
scripted_transforms = transforms


dataset_train = util.dataset_simCLR(torch.tensor(X_train), 
                                    y_train, 
                                    n_transforms=2, 
                                    transform=scripted_transforms,
                                    DEVICE='cpu',
                                    dtype_X=torch.float32,
                                    dtype_y=torch.int64 )

dataloader_train = torch.utils.data.DataLoader( dataset_train,
                                                batch_size=64,
            #                                     sampler=sampler,
                                                shuffle=True,
                                                drop_last=True,
                                                pin_memory=True,
                                                num_workers=32,
                                                )

# dataset_val = util.dataset_simCLR(torch.tensor(X_val), 
#                                     y_val, 
#                                     n_transforms=2, 
#                                     transform=scripted_transforms,
#                                     DEVICE='cpu',
#                                     dtype_X=torch.float32,
#                                     dtype_y=torch.int64 )

# dataloader_val = torch.utils.data.DataLoader(   dataset_val,
#                                                 batch_size=128,
#             #                                     sampler=sampler,
#                                                 shuffle=True,
#                                                 drop_last=True,
#                                                 pin_memory=True,
#                                                 num_workers=0,
#                                                 )

# %%
import time

# %matplotlib notebook
tic=time.time()
for ii, im in enumerate(dataset_train):
#     for jj in range(im[0])
    print(time.time() - tic)
    tic = time.time()
#     print((im[0][0]).shape)
    fig, axs = plt.subplots(len(im[0]))
    for jj, ax in enumerate(axs):
        ax.imshow(im[0][jj].cpu().squeeze())
    if ii > 2:
        break
# Out:
# 0.0035085678100585938
# <img src="data:image/png;base64,..." width="431.75000000000006">
# 0.03125357627868652
# <img src="data:image/png;base64,..." width="431.75000000000006">
# 0.031585693359375
# <img src="data:image/png;base64,..." width="431.75000000000006">
# 0.23209881782531738
# <img src="data:image/png;base64,..." width="431.75000000000006">

# %%
DEVICE = torch_helpers.set_device(use_GPU=True)
# Out:
# device: 'cuda'

# %%
from torch.nn import CrossEntropyLoss
from torch.optim import Adam

model = models.LeNet1(dropout_prob=0.3, momentum_val=0, n_output_features=64)
model.train()
criterion = CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=1e-3, weight_decay=0.01)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer,
                                                   gamma=1-0.001,
#                                                    gamma=1,
                                                  )
val_obj = training_simCLR.validation_Obj(   X_val,
                                            y_val,
                                            model,
                                            criterion,
                                            DEVICE=DEVICE,
                                            dtype_X=torch.float32,
                                            dtype_y=torch.int64)

model.to(DEVICE)
criterion = criterion.to(DEVICE)

losses_train, losses_val, val_accs = [], [np.nan], []
n_epochs=300
for epoch in range(n_epochs):
    print(f'epoch: {epoch}')
    training_simCLR.epoch_step( dataloader_train, 
                                model, 
                                optimizer, 
                                criterion, 
                                scheduler=scheduler, 
                                temperature=0.5,
                                loss_rolling_train=losses_train, 
                                device=DEVICE, 
                                do_validation=False,
                                validation_Object=val_obj,
                                loss_rolling_val=losses_val,
                                verbose=2,
                                verbose_update_period=10,
                               )
# Out:
# epoch: 0
# Iter: 0/24, loss_train: 4.8028, loss_val: nan, lr: 0.000999
# Iter: 10/24, loss_train: 4.3511, loss_val: nan, lr: 0.00098905
# Iter: 20/24, loss_train: 4.5417, loss_val: nan, lr: 0.00097921
# epoch: 1
# Iter: 0/24, loss_train: 4.4311, loss_val: nan, lr: 0.0009753
# Iter: 10/24, loss_train: 4.371, loss_val: nan, lr: 0.00096559
# Iter: 20/24, loss_train: 4.315, loss_val: nan, lr: 0.00095598
# epoch: 2
# Iter: 0/24, loss_train: 4.2587, loss_val: nan, lr: 0.00095216
# Iter: 10/24, loss_train: 4.2245, loss_val: nan, lr: 0.00094268
# Iter: 20/24, loss_train: 4.2231, loss_val: nan, lr: 0.00093329
# epoch: 3
# Iter: 0/24, loss_train: 4.1987, loss_val: nan, lr: 0.00092957
# Iter: 10/24, loss_train: 4.0973, loss_val: nan, lr: 0.00092031
# Iter: 20/24, loss_train: 4.2909, loss_val: nan, lr: 0.00091115
# epoch: 4
# Iter: 0/24, loss_train: 4.06, loss_val: nan, lr: 0.00090751
# Iter: 10/24, loss_train: 3.9654, loss_val: nan, lr: 0.00089848
# Iter: 20/24, loss_train: 4.0231, loss_val: nan, lr: 0.00088953
# epoch: 5
# Iter: 0/24, loss_train: 4.0879, loss_val: nan, lr: 0.00088598
# Iter: 10/24, loss_train: 3.9847, loss_val: nan, lr: 0.00087716
# Iter: 20/24, loss_train: 3.9668, loss_val: nan, lr: 0.00086843
# epoch: 6
# Iter: 0/24, loss_train: 4.0544, loss_val: nan, lr: 0.00086496
# Iter: 10/24, loss_train: 4.0185, loss_val: nan, lr: 0.00085635
# Iter: 20/24, loss_train: 4.049, loss_val: nan, lr: 0.00084782
# epoch: 7
# Iter: 0/24, loss_train: 4.0449, loss_val: nan, lr: 0.00084444
# Iter: 10/24, loss_train: 3.8456, loss_val: nan, lr: 0.00083603
# Iter: 20/24, loss_train: 3.9614, loss_val: nan, lr: 0.00082771
# epoch: 8
# Iter: 0/24, loss_train: 3.9225, loss_val: nan, lr: 0.0008244
# Iter: 10/24, loss_train: 3.934, loss_val: nan, lr: 0.0008162
# Iter: 20/24, loss_train: 3.8871, loss_val: nan, lr: 0.00080807
# epoch: 9
# Iter: 0/24, loss_train: 4.0766, loss_val: nan, lr: 0.00080484
# Iter: 10/24, loss_train: 3.8868, loss_val: nan, lr: 0.00079683
# Iter: 20/24, loss_train: 3.8874, loss_val: nan, lr: 0.0007889
# epoch: 10
# Iter: 0/24, loss_train: 4.0499, loss_val: nan, lr: 0.00078575
# Iter: 10/24, loss_train: 3.9955, loss_val: nan, lr: 0.00077792
# Iter: 20/24, loss_train: 3.9337, loss_val: nan, lr: 0.00077018
# epoch: 11
# Iter: 0/24, loss_train: 3.9927, loss_val: nan, lr: 0.0007671
# Iter: 10/24, loss_train: 3.8825, loss_val: nan, lr: 0.00075947
# Iter: 20/24, loss_train: 3.9113, loss_val: nan, lr: 0.00075191
# epoch: 12
# Iter: 0/24, loss_train: 3.8481, loss_val: nan, lr: 0.0007489
# Iter: 10/24, loss_train: 3.9262, loss_val: nan, lr: 0.00074145
# Iter: 20/24, loss_train: 3.9694, loss_val: nan, lr: 0.00073407
# epoch: 13
# Iter: 0/24, loss_train: 3.8475, loss_val: nan, lr: 0.00073114
# Iter: 10/24, loss_train: 3.9363, loss_val: nan, lr: 0.00072386
# Iter: 20/24, loss_train: 3.8321, loss_val: nan, lr: 0.00071665
# epoch: 14
# Iter: 0/24, loss_train: 3.8249, loss_val: nan, lr: 0.00071379
# Iter: 10/24, loss_train: 3.9304, loss_val: nan, lr: 0.00070668
# Iter: 20/24, loss_train: 3.9709, loss_val: nan, lr: 0.00069965
# epoch: 15
# Iter: 0/24, loss_train: 4.0051, loss_val: nan, lr: 0.00069685
# Iter: 10/24, loss_train: 3.9229, loss_val: nan, lr: 0.00068992
# Iter: 20/24, loss_train: 3.7779, loss_val: nan, lr: 0.00068305
# epoch: 16
# Iter: 0/24, loss_train: 3.8996, loss_val: nan, lr: 0.00068032
# Iter: 10/24, loss_train: 3.9597, loss_val: nan, lr: 0.00067355
# Iter: 20/24, loss_train: 3.8662, loss_val: nan, lr: 0.00066684
# epoch: 17
# Iter: 0/24, loss_train: 3.9301, loss_val: nan, lr: 0.00066418
# Iter: 10/24, loss_train: 3.7646, loss_val: nan, lr: 0.00065757
# Iter: 20/24, loss_train: 3.9096, loss_val: nan, lr: 0.00065102
# epoch: 18
# Iter: 0/24, loss_train: 3.8853, loss_val: nan, lr: 0.00064842
# Iter: 10/24, loss_train: 3.8153, loss_val: nan, lr: 0.00064196
# Iter: 20/24, loss_train: 3.862, loss_val: nan, lr: 0.00063557
# epoch: 19
# Iter: 0/24, loss_train: 3.8952, loss_val: nan, lr: 0.00063304
# Iter: 10/24, loss_train: 3.9961, loss_val: nan, lr: 0.00062673
# Iter: 20/24, loss_train: 3.8513, loss_val: nan, lr: 0.00062049
# epoch: 20
# Iter: 0/24, loss_train: 3.8352, loss_val: nan, lr: 0.00061802
# Iter: 10/24, loss_train: 3.834, loss_val: nan, lr: 0.00061186
# Iter: 20/24, loss_train: 3.9509, loss_val: nan, lr: 0.00060577
# epoch: 21
# Iter: 0/24, loss_train: 3.7761, loss_val: nan, lr: 0.00060335
# Iter: 10/24, loss_train: 3.7639, loss_val: nan, lr: 0.00059735
# Iter: 20/24, loss_train: 3.8624, loss_val: nan, lr: 0.0005914
# epoch: 22
# Iter: 0/24, loss_train: 3.853, loss_val: nan, lr: 0.00058904
# Iter: 10/24, loss_train: 3.8011, loss_val: nan, lr: 0.00058317
# Iter: 20/24, loss_train: 3.8191, loss_val: nan, lr: 0.00057737
# epoch: 23
# Iter: 0/24, loss_train: 3.7855, loss_val: nan, lr: 0.00057506
# Iter: 10/24, loss_train: 3.8914, loss_val: nan, lr: 0.00056934
# Iter: 20/24, loss_train: 3.8116, loss_val: nan, lr: 0.00056367
# epoch: 24
# Iter: 0/24, loss_train: 3.8058, loss_val: nan, lr: 0.00056142
# Iter: 10/24, loss_train: 3.8752, loss_val: nan, lr: 0.00055583
# Iter: 20/24, loss_train: 3.9601, loss_val: nan, lr: 0.0005503
# epoch: 25
# Iter: 0/24, loss_train: 3.9383, loss_val: nan, lr: 0.0005481
# Iter: 10/24, loss_train: 3.8397, loss_val: nan, lr: 0.00054264
# Iter: 20/24, loss_train: 3.7454, loss_val: nan, lr: 0.00053724
# epoch: 26
# Iter: 0/24, loss_train: 3.776, loss_val: nan, lr: 0.00053509
# Iter: 10/24, loss_train: 3.8279, loss_val: nan, lr: 0.00052977
# Iter: 20/24, loss_train: 3.7366, loss_val: nan, lr: 0.00052449
# epoch: 27
# Iter: 0/24, loss_train: 3.9108, loss_val: nan, lr: 0.0005224
# Iter: 10/24, loss_train: 3.8287, loss_val: nan, lr: 0.0005172
# Iter: 20/24, loss_train: 3.7771, loss_val: nan, lr: 0.00051205
# epoch: 28
# Iter: 0/24, loss_train: 3.7461, loss_val: nan, lr: 0.00051
# Iter: 10/24, loss_train: 3.7803, loss_val: nan, lr: 0.00050493
# Iter: 20/24, loss_train: 3.7499, loss_val: nan, lr: 0.0004999
# epoch: 29
# Iter: 0/24, loss_train: 3.7925, loss_val: nan, lr: 0.0004979
# Iter: 10/24, loss_train: 3.8701, loss_val: nan, lr: 0.00049295
# Iter: 20/24, loss_train: 3.7547, loss_val: nan, lr: 0.00048804
# epoch: 30
# Iter: 0/24, loss_train: 3.8673, loss_val: nan, lr: 0.00048609
# Iter: 10/24, loss_train: 3.8444, loss_val: nan, lr: 0.00048125
# Iter: 20/24, loss_train: 3.7832, loss_val: nan, lr: 0.00047646
# epoch: 31
# Iter: 0/24, loss_train: 3.754, loss_val: nan, lr: 0.00047456
# Iter: 10/24, loss_train: 3.9203, loss_val: nan, lr: 0.00046983
# Iter: 20/24, loss_train: 3.8433, loss_val: nan, lr: 0.00046516
# epoch: 32
# Iter: 0/24, loss_train: 3.8515, loss_val: nan, lr: 0.0004633
# Iter: 10/24, loss_train: 3.8212, loss_val: nan, lr: 0.00045869
# Iter: 20/24, loss_train: 3.7808, loss_val: nan, lr: 0.00045412
# epoch: 33
# Iter: 0/24, loss_train: 3.7632, loss_val: nan, lr: 0.00045231
# Iter: 10/24, loss_train: 3.747, loss_val: nan, lr: 0.0004478
# Iter: 20/24, loss_train: 3.8531, loss_val: nan, lr: 0.00044335
# epoch: 34
# Iter: 0/24, loss_train: 3.7261, loss_val: nan, lr: 0.00044157
# Iter: 10/24, loss_train: 3.8837, loss_val: nan, lr: 0.00043718
# Iter: 20/24, loss_train: 3.7041, loss_val: nan, lr: 0.00043283
# epoch: 35
# Iter: 0/24, loss_train: 3.6844, loss_val: nan, lr: 0.0004311
# Iter: 10/24, loss_train: 3.7546, loss_val: nan, lr: 0.00042681
# Iter: 20/24, loss_train: 3.6911, loss_val: nan, lr: 0.00042256
# epoch: 36
# Iter: 0/24, loss_train: 3.7368, loss_val: nan, lr: 0.00042087
# Iter: 10/24, loss_train: 3.7359, loss_val: nan, lr: 0.00041668
# Iter: 20/24, loss_train: 3.6872, loss_val: nan, lr: 0.00041253
# epoch: 37
# Iter: 0/24, loss_train: 3.8327, loss_val: nan, lr: 0.00041088
# Iter: 10/24, loss_train: 3.7299, loss_val: nan, lr: 0.00040679
# Iter: 20/24, loss_train: 3.8791, loss_val: nan, lr: 0.00040274
# epoch: 38
# Iter: 0/24, loss_train: 3.8933, loss_val: nan, lr: 0.00040114
# Iter: 10/24, loss_train: 3.769, loss_val: nan, lr: 0.00039714
# Iter: 20/24, loss_train: 3.6595, loss_val: nan, lr: 0.00039319
# epoch: 39
# Iter: 0/24, loss_train: 3.7692, loss_val: nan, lr: 0.00039162
# Iter: 10/24, loss_train: 3.7921, loss_val: nan, lr: 0.00038772
# Iter: 20/24, loss_train: 3.7058, loss_val: nan, lr: 0.00038386
# epoch: 40
# Iter: 0/24, loss_train: 3.9209, loss_val: nan, lr: 0.00038233
# Iter: 10/24, loss_train: 3.8448, loss_val: nan, lr: 0.00037852
# Iter: 20/24, loss_train: 3.8289, loss_val: nan, lr: 0.00037475
# epoch: 41
# Iter: 0/24, loss_train: 3.7751, loss_val: nan, lr: 0.00037326
# Iter: 10/24, loss_train: 3.6894, loss_val: nan, lr: 0.00036954
# Iter: 20/24, loss_train: 3.6499, loss_val: nan, lr: 0.00036586
# epoch: 42
# Iter: 0/24, loss_train: 3.7705, loss_val: nan, lr: 0.0003644
# Iter: 10/24, loss_train: 3.7168, loss_val: nan, lr: 0.00036077
# Iter: 20/24, loss_train: 3.8021, loss_val: nan, lr: 0.00035718
# epoch: 43
# Iter: 0/24, loss_train: 3.8535, loss_val: nan, lr: 0.00035575
# Iter: 10/24, loss_train: 3.8187, loss_val: nan, lr: 0.00035221
# Iter: 20/24, loss_train: 3.6966, loss_val: nan, lr: 0.00034871
# epoch: 44
# Iter: 0/24, loss_train: 3.8027, loss_val: nan, lr: 0.00034731
# Iter: 10/24, loss_train: 3.7517, loss_val: nan, lr: 0.00034386
# Iter: 20/24, loss_train: 3.8084, loss_val: nan, lr: 0.00034043
# epoch: 45
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-191-46e5a3f458cd> in <module>
#      25 for epoch in range(n_epochs):
#      26     print(f'epoch: {epoch}')
# ---> 27     training_simCLR.epoch_step( dataloader_train,
#      28                                 model,
#      29                                 optimizer,
#
# /media/rich/Home_Linux_partition/github_repos/GCaMP_ROI_classifier/old_stuff/training_simCLR.py in epoch_step(dataloader, model, optimizer, criterion, scheduler, temperature, loss_rolling_train, device, do_validation, validation_Object, loss_rolling_val, verbose, verbose_update_period)
#     114         print(f'Iter: {batch}/{n_batches}, loss_train: {loss_train:.{precis}}, loss_val: {loss_val:.{precis}}, lr: {learning_rate:.{precis}}')
#     115
# --> 116     for i_batch, (X_batch, y_batch, idx_batch) in enumerate(dataloader):
#     117         X_batch = torch.cat(X_batch, dim=0)
#     118         X_batch = X_batch.to(device)
#
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1184
#    1185             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1186             idx, data = self._get_data()
#    1187             self._tasks_outstanding -= 1
#    1188             if self._dataset_kind == _DatasetKind.Iterable:
#
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1140         elif self._pin_memory:
#    1141             while self._pin_memory_thread.is_alive():
# -> 1142                 success, data = self._try_get_data()
#    1143                 if success:
#    1144                     return data
#
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     988         #   (bool: whether successfully get data, any: data if successful else None)
#     989         try:
# --> 990             data = self._data_queue.get(timeout=timeout)
#     991             return (True, data)
#     992         except Exception as e:
#
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/queue.py in get(self, block, timeout)
#     177                     if remaining <= 0.0:
#     178                         raise Empty
# --> 179                     self.not_empty.wait(remaining)
#     180             item = self._get()
#     181             self.not_full.notify()
#
# /media/rich/OS/Users/Richard/Linux_stuff_on_OS/conda_envs/envs/rapids-0.19/lib/python3.8/threading.py in wait(self, timeout)
#     304             else:
#     305                 if timeout > 0:
# --> 306                     gotit = waiter.acquire(True, timeout)
#     307                 else:
#     308                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
plt.figure()
plt.plot(losses_train)
# Out:
# <img src="data:image/png;base64,..." width="431.75000000000006">

# %%
features = model(torch.tensor(X_val, device=DEVICE, dtype=torch.float32)[:,None,...]).detach()

# %%
_, features_embedded, _, _ = decomposition.torch_pca(features, device=DEVICE, return_cpu=True)

# %%
from sklearn import manifold

tsne = manifold.TSNE(n_components=2, 
                     perplexity=30.0, 
                     early_exaggeration=12.0, 
                     learning_rate=200, 
                     n_iter=1000, 
                     n_iter_without_progress=300, 
                     min_grad_norm=1e-07, 
                     metric='euclidean', 
                     init='pca', 
                     verbose=0, 
                     random_state=None, 
                     method='barnes_hut', 
                     angle=0.5, 
                     n_jobs=-1, 
                     square_distances='legacy'
                    )
features_embedded = tsne.fit_transform(features.cpu())

# %%
# %matplotlib notebook
plt.figure()
plt.scatter(features_embedded[:,0], features_embedded[:,1], c=y_val)
# Out:
# <img src="data:image/png;base64,..." width="451.9166666666667">

# %%
list(model.state_dict().keys())
# Out:
# ['cnn_layers.0.weight',
#  'cnn_layers.0.bias',
#  'cnn_layers.2.weight',
#  'cnn_layers.2.bias',
#  'cnn_layers.5.weight',
#  'cnn_layers.5.bias',
#  'cnn_layers.8.weight',
#  'cnn_layers.8.bias',
#  'linear_layers.0.weight',
#  'linear_layers.0.bias',
#  'linear_layers.2.weight',
#  'linear_layers.2.bias']

# %%
layer_1 = model.state_dict()['cnn_layers.0.weight'].cpu()
layer_2 = model.state_dict()['cnn_layers.2.weight'].cpu()
layer_3 = model.state_dict()['cnn_layers.5.weight'].cpu()
# layer_4 = model.state_dict()['cnn_layers.11.weight'].cpu()

plt.figure()
for ii in range(layer_1.shape[1]):
    for jj in range(layer_1.shape[0]):
        plt.subplot2grid((layer_1.shape[1],layer_1.shape[0]),(ii,jj))
# for ii in range(1):
#     for jj in range(6):
#         plt.subplot2grid((1,6),(ii,jj))
        fig = plt.imshow(layer_1[jj,ii,:,:] , clim=(-0.2,0.2))
        fig.axes.get_xaxis().set_visible(False)
        fig.axes.get_yaxis().set_visible(False)
        #         im = plt.gca().get_images()
#         im.set_clim(0,1)
plt.figure()
for ii in range(layer_2.shape[1]):
    for jj in range(layer_2.shape[0]):
        plt.subplot2grid((layer_2.shape[1],layer_2.shape[0]),(ii,jj))
# for ii in range(12):
#     for jj in range(12):
#         plt.subplot2grid((12,12),(ii,jj))
        #         plt.imshow(layer_2[ii*jj + jj,0,:,:])
        fig = plt.imshow(layer_2[jj,ii,:,:], clim=(-.05,.05))
        fig.axes.get_xaxis().set_visible(False)
        fig.axes.get_yaxis().set_visible(False)

plt.figure()
for ii in range(16):
    for jj in range(16):
        plt.subplot2grid((16,16),(ii,jj))
# #         fig = plt.imshow(layer_3[jj*ii + jj,0,:,:], clim=(-.01,.01))
# #         fig.axes.get_xaxis().set_visible(False)
# #         fig.axes.get_yaxis().set_visible(False)
# plt.figure()
# for ii in range(layer_3.shape[1]):
#     for jj in range(layer_3.shape[0]):
#         plt.subplot2grid((layer_3.shape[1],layer_3.shape[0]),(ii,jj))
#         fig = plt.imshow(layer_3[jj, ii,:,:], clim=(-.4,.4))
        fig = plt.imshow(layer_3[jj, ii,:,:])
        fig.axes.get_xaxis().set_visible(False)
        fig.axes.get_yaxis().set_visible(False)
        
        
        
        
        
# plt.figure()
# for ii in range(layer_4.shape[1]):
#     for jj in range(layer_4.shape[0]):
#         plt.subplot2grid((layer_4.shape[1],layer_4.shape[0]),(ii,jj))
#         fig = plt.imshow(layer_4[jj, ii,:,:], clim=(-.2,.2))
#         fig.axes.get_xaxis().set_visible(False)
#         fig.axes.get_yaxis().set_visible(False)
# # model.state_dict()['cnn_layers.1.weight'].shape
# Out:
# <img src="data:image/png;base64,..." width="431.75000000000006">
# <img src="data:image/png;base64,..." width="431.75000000000006">
# <img src="data:image/png;base64,..." width="431.75000000000006">
